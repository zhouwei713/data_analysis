# %%
import pandas as pd

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie, Bar

# %%
gdp = pd.read_csv('GDP_data.csv')

# %%
country = pd.read_csv('Country_data.csv')

# %%
country_data = country.dropna(subset=['Income_Group'])

# %%
country_data
# Out:
#     Country Name Country Code             Region Income_Group  Unnamed: 4
# 0            阿鲁巴          ABW                NaN        高收入国家         NaN
# 1            阿富汗          AFG                 南亚        低收入国家         NaN
# 2            安哥拉          AGO  撒哈拉以南非洲地区（不包括高收入）      中低等收入国家         NaN
# 3          阿尔巴尼亚          ALB    欧洲与中亚地区（不包括高收入）      中高等收入国家         NaN
# 4         安道尔共和国          AND                NaN        高收入国家         NaN
# ..           ...          ...                ...          ...         ...
# 259          科索沃          XKX    欧洲与中亚地区（不包括高收入）      中高等收入国家         NaN
# 260        也门共和国          YEM    中东与北非地区（不包括高收入）        低收入国家         NaN
# 261           南非          ZAF  撒哈拉以南非洲地区（不包括高收入）      中高等收入国家         NaN
# 262          赞比亚          ZMB  撒哈拉以南非洲地区（不包括高收入）      中低等收入国家         NaN
# 263         津巴布韦          ZWE  撒哈拉以南非洲地区（不包括高收入）      中低等收入国家         NaN
#
# [217 rows x 5 columns]

# %%
rank_cuntry = country_data.groupby('Income_Group').size()

# %%
country_data.groupby('Income_Group').size().values.tolist()
# Out:
# [47, 60, 31, 79]

# %%
# 各个收入等级分布
pie = Pie()
pie.add("", [list(z) for z in zip(rank_cuntry.index.tolist(), rank_cuntry.values.tolist())],
       radius=["30%", "75%"], center=["45%", "50%"], rosetype="radius",
       )
pie.set_global_opts(title_opts=opts.TitleOpts(title="各个收入等级分布"))
pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}, {d}%"))
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="0f444b723d034eb9ba8cca5c33fc2087" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_0f444b723d034eb9ba8cca5c33fc2087 = echarts.init(
#             document.getElementById('0f444b723d034eb9ba8cca5c33fc2087'), 'white', {renderer: 'canvas'});
#         var option_0f444b723d034eb9ba8cca5c33fc2087 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u4e2d\u4f4e\u7b49\u6536\u5165\u56fd\u5bb6",
#                     "value": 47
#                 },
#                 {
#                     "name": "\u4e2d\u9ad8\u7b49\u6536\u5165\u56fd\u5bb6",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u4f4e\u6536\u5165\u56fd\u5bb6",
#                     "value": 31
#                 },
#                 {
#                     "name": "\u9ad8\u6536\u5165\u56fd\u5bb6",
#                     "value": 79
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "45%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}, {d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e2d\u4f4e\u7b49\u6536\u5165\u56fd\u5bb6",
#                 "\u4e2d\u9ad8\u7b49\u6536\u5165\u56fd\u5bb6",
#                 "\u4f4e\u6536\u5165\u56fd\u5bb6",
#                 "\u9ad8\u6536\u5165\u56fd\u5bb6"
#             ],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5404\u4e2a\u6536\u5165\u7b49\u7ea7\u5206\u5e03"
#         }
#     ]
# };
#         chart_0f444b723d034eb9ba8cca5c33fc2087.setOption(option_0f444b723d034eb9ba8cca5c33fc2087);
#     });
# </script>

# %%
high = country_data[country_data['Income_Group'] == '高收入国家']

# %%
# 高收入国家2018年的GDP
high_gdp = pd.merge(high, gdp, how='inner')
high_gdp['2018'] = high_gdp['2018'].apply(lambda x: x/1000000000000)
high_gdp_top10 = high_gdp[['Country Name', 'Country Code', '2018']].sort_values(by='2018', ascending=False)[:10]

# %%
bar = Bar()
bar.add_xaxis(high_gdp_top10['Country Name'].values.tolist())
bar.add_yaxis("", high_gdp_top10['2018'].values.tolist())
bar.reversal_axis()
bar.set_series_opts(label_opts=opts.LabelOpts(position="right"))
bar.set_global_opts(title_opts=opts.TitleOpts(title="高收入国家GDP Top10", subtitle=""),
                   xaxis_opts=opts.AxisOpts(
                axislabel_opts=opts.LabelOpts(formatter="{value} /万亿")
            ),)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="51954642e06643b390b119465829c58a" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_51954642e06643b390b119465829c58a = echarts.init(
#             document.getElementById('51954642e06643b390b119465829c58a'), 'white', {renderer: 'canvas'});
#         var option_51954642e06643b390b119465829c58a = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 20.4941,
#                 4.97091555663888,
#                 3.9967592910578102,
#                 2.8252079475029,
#                 2.77753523927798,
#                 2.07390198887823,
#                 1.7125100300340501,
#                 1.61942370116963,
#                 1.43219517866832,
#                 1.42618913759658
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} /\u4e07\u4ebf"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u7f8e\u56fd",
#                 "\u65e5\u672c",
#                 "\u5fb7\u56fd",
#                 "\u82f1\u56fd",
#                 "\u6cd5\u56fd",
#                 "\u610f\u5927\u5229",
#                 "\u52a0\u62ff\u5927",
#                 "\u5927\u97e9\u6c11\u56fd",
#                 "\u6fb3\u5927\u5229\u4e9a",
#                 "\u897f\u73ed\u7259"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u9ad8\u6536\u5165\u56fd\u5bb6GDP Top10"
#         }
#     ]
# };
#         chart_51954642e06643b390b119465829c58a.setOption(option_51954642e06643b390b119465829c58a);
#     });
# </script>

# %%
high_gdp_top20 = high_gdp[['Country Name', 'Country Code', '2018']].sort_values(by='2018', ascending=False)[:20]

bar = Bar()
bar.add_xaxis(high_gdp_top20['Country Name'].values.tolist())
bar.add_yaxis("", high_gdp_top20['2018'].values.tolist())
bar.reversal_axis()
bar.set_series_opts(label_opts=opts.LabelOpts(position="right"))
bar.set_global_opts(title_opts=opts.TitleOpts(title="高收入国家GDP Top20", subtitle=""),
                   xaxis_opts=opts.AxisOpts(
                axislabel_opts=opts.LabelOpts(formatter="{value} /万亿")
            ),)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="bf4b2d4411d74bd1af09d3d7b58d53b7" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_bf4b2d4411d74bd1af09d3d7b58d53b7 = echarts.init(
#             document.getElementById('bf4b2d4411d74bd1af09d3d7b58d53b7'), 'white', {renderer: 'canvas'});
#         var option_bf4b2d4411d74bd1af09d3d7b58d53b7 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 20.4941,
#                 4.97091555663888,
#                 3.9967592910578102,
#                 2.8252079475029,
#                 2.77753523927798,
#                 2.07390198887823,
#                 1.7125100300340501,
#                 1.61942370116963,
#                 1.43219517866832,
#                 1.42618913759658,
#                 0.913658465709125,
#                 0.782483466666667,
#                 0.7055013046886991,
#                 0.585782872331589,
#                 0.551031682226344,
#                 0.531766935070733,
#                 0.455736580716185,
#                 0.434750937596065,
#                 0.41417889720898604,
#                 0.382487490532479
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} /\u4e07\u4ebf"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u7f8e\u56fd",
#                 "\u65e5\u672c",
#                 "\u5fb7\u56fd",
#                 "\u82f1\u56fd",
#                 "\u6cd5\u56fd",
#                 "\u610f\u5927\u5229",
#                 "\u52a0\u62ff\u5927",
#                 "\u5927\u97e9\u6c11\u56fd",
#                 "\u6fb3\u5927\u5229\u4e9a",
#                 "\u897f\u73ed\u7259",
#                 "\u8377\u5170",
#                 "\u6c99\u7279\u963f\u62c9\u4f2f",
#                 "\u745e\u58eb",
#                 "\u6ce2\u5170",
#                 "\u745e\u5178",
#                 "\u6bd4\u5229\u65f6",
#                 "\u5965\u5730\u5229",
#                 "\u632a\u5a01",
#                 "\u963f\u62c9\u4f2f\u8054\u5408\u914b\u957f\u56fd",
#                 "\u7231\u5c14\u5170"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u9ad8\u6536\u5165\u56fd\u5bb6GDP Top20"
#         }
#     ]
# };
#         chart_bf4b2d4411d74bd1af09d3d7b58d53b7.setOption(option_bf4b2d4411d74bd1af09d3d7b58d53b7);
#     });
# </script>

# %%
# 中高等收入国家
mid_high = country_data[country_data['Income_Group'] == '中高等收入国家']
mid_high_gdp = pd.merge(mid_high, gdp, how='inner')
mid_high_gdp['2018'] = mid_high_gdp['2018'].apply(lambda x: x/1000000000000)
mid_high_gdp_top10 = mid_high_gdp[['Country Name', 'Country Code', '2018']].sort_values(by='2018', ascending=False)[:10]
mid_high_gdp_top20 = mid_high_gdp[['Country Name', 'Country Code', '2018']].sort_values(by='2018', ascending=False)[:20]

# %%
bar = Bar()
bar.add_xaxis(mid_high_gdp_top10['Country Name'].values.tolist())
bar.add_yaxis("", mid_high_gdp_top10['2018'].values.tolist())
bar.reversal_axis()
bar.set_series_opts(label_opts=opts.LabelOpts(position="right"))
bar.set_global_opts(title_opts=opts.TitleOpts(title="中高等收入国家GDP Top10", subtitle=""),
                   xaxis_opts=opts.AxisOpts(
                axislabel_opts=opts.LabelOpts(formatter="{value} /万亿")
            ),)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="fa99eef2c1d4401582aa518bf058e581" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_fa99eef2c1d4401582aa518bf058e581 = echarts.init(
#             document.getElementById('fa99eef2c1d4401582aa518bf058e581'), 'white', {renderer: 'canvas'});
#         var option_fa99eef2c1d4401582aa518bf058e581 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 13.6081518646379,
#                 1.86862608790848,
#                 1.65755376558067,
#                 1.2238088855856102,
#                 0.7665090888375791,
#                 0.5184751340843571,
#                 0.504992757704997,
#                 0.36828820308663,
#                 0.354348422831193,
#                 0.33022786623332395
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} /\u4e07\u4ebf"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4e2d\u56fd",
#                 "\u5df4\u897f",
#                 "\u4fc4\u7f57\u65af\u8054\u90a6",
#                 "\u58a8\u897f\u54e5",
#                 "\u571f\u8033\u5176",
#                 "\u963f\u6839\u5ef7",
#                 "\u6cf0\u56fd",
#                 "\u5357\u975e",
#                 "\u9a6c\u6765\u897f\u4e9a",
#                 "\u54e5\u4f26\u6bd4\u4e9a"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e2d\u9ad8\u7b49\u6536\u5165\u56fd\u5bb6GDP Top10"
#         }
#     ]
# };
#         chart_fa99eef2c1d4401582aa518bf058e581.setOption(option_fa99eef2c1d4401582aa518bf058e581);
#     });
# </script>

# %%
bar = Bar()
bar.add_xaxis(mid_high_gdp_top20['Country Name'].values.tolist())
bar.add_yaxis("", mid_high_gdp_top20['2018'].values.tolist())
bar.reversal_axis()
bar.set_series_opts(label_opts=opts.LabelOpts(position="right"))
bar.set_global_opts(title_opts=opts.TitleOpts(title="中高等收入国家GDP Top20", subtitle=""),
                   xaxis_opts=opts.AxisOpts(
                axislabel_opts=opts.LabelOpts(formatter="{value} /万亿")
            ),)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="67112b8f44ab4c459fc49e8c17f13aaa" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_67112b8f44ab4c459fc49e8c17f13aaa = echarts.init(
#             document.getElementById('67112b8f44ab4c459fc49e8c17f13aaa'), 'white', {renderer: 'canvas'});
#         var option_67112b8f44ab4c459fc49e8c17f13aaa = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 13.6081518646379,
#                 1.86862608790848,
#                 1.65755376558067,
#                 1.2238088855856102,
#                 0.7665090888375791,
#                 0.5184751340843571,
#                 0.504992757704997,
#                 0.36828820308663,
#                 0.354348422831193,
#                 0.33022786623332395,
#                 0.239552516744469,
#                 0.22591418304798103,
#                 0.22223757074179998,
#                 0.18068911594068499,
#                 0.170538870248194,
#                 0.108398058,
#                 0.0889007708576351,
#                 0.0812985854033004,
#                 0.0784604479199915,
#                 0.0651329511164756
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} /\u4e07\u4ebf"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4e2d\u56fd",
#                 "\u5df4\u897f",
#                 "\u4fc4\u7f57\u65af\u8054\u90a6",
#                 "\u58a8\u897f\u54e5",
#                 "\u571f\u8033\u5176",
#                 "\u963f\u6839\u5ef7",
#                 "\u6cf0\u56fd",
#                 "\u5357\u975e",
#                 "\u9a6c\u6765\u897f\u4e9a",
#                 "\u54e5\u4f26\u6bd4\u4e9a",
#                 "\u7f57\u9a6c\u5c3c\u4e9a",
#                 "\u4f0a\u62c9\u514b",
#                 "\u79d8\u9c81",
#                 "\u963f\u5c14\u53ca\u5229\u4e9a",
#                 "\u54c8\u8428\u514b\u65af\u5766",
#                 "\u5384\u74dc\u591a\u5c14",
#                 "\u65af\u91cc\u5170\u5361",
#                 "\u591a\u7c73\u5c3c\u52a0\u5171\u548c\u56fd",
#                 "\u5371\u5730\u9a6c\u62c9",
#                 "\u4fdd\u52a0\u5229\u4e9a"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e2d\u9ad8\u7b49\u6536\u5165\u56fd\u5bb6GDP Top20"
#         }
#     ]
# };
#         chart_67112b8f44ab4c459fc49e8c17f13aaa.setOption(option_67112b8f44ab4c459fc49e8c17f13aaa);
#     });
# </script>

# %%
# 中低等收入国家
mid_low = country_data[country_data['Income_Group'] == '中低等收入国家']
mid_low_gdp = pd.merge(mid_low, gdp, how='inner')
mid_low_gdp['2018'] = mid_low_gdp['2018'].apply(lambda x: x/1000000000000)
mid_low_gdp_top10 = mid_low_gdp[['Country Name', 'Country Code', '2018']].sort_values(by='2018', ascending=False)[:10]
mid_low_gdp_top20 = mid_low_gdp[['Country Name', 'Country Code', '2018']].sort_values(by='2018', ascending=False)[:20]

# %%
bar = Bar()
bar.add_xaxis(mid_low_gdp_top10['Country Name'].values.tolist())
bar.add_yaxis("", mid_low_gdp_top10['2018'].values.tolist())
bar.reversal_axis()
bar.set_series_opts(label_opts=opts.LabelOpts(position="right"))
bar.set_global_opts(title_opts=opts.TitleOpts(title="中低等收入国家GDP Top10", subtitle=""),
                   xaxis_opts=opts.AxisOpts(
                axislabel_opts=opts.LabelOpts(formatter="{value} /万亿")
            ),)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="b1855d00ce4b49c6b1aa4cda71e85c6f" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_b1855d00ce4b49c6b1aa4cda71e85c6f = echarts.init(
#             document.getElementById('b1855d00ce4b49c6b1aa4cda71e85c6f'), 'white', {renderer: 'canvas'});
#         var option_b1855d00ce4b49c6b1aa4cda71e85c6f = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 2.72632261682131,
#                 1.04217330062555,
#                 0.39726961608090794,
#                 0.330910343610956,
#                 0.312570060548453,
#                 0.274024958965892,
#                 0.250895469644498,
#                 0.244948445308883,
#                 0.130832374404882,
#                 0.11849532819808001
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} /\u4e07\u4ebf"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5370\u5ea6",
#                 "\u5370\u5ea6\u5c3c\u897f\u4e9a",
#                 "\u5c3c\u65e5\u5229\u4e9a",
#                 "\u83f2\u5f8b\u5bbe",
#                 "\u5df4\u57fa\u65af\u5766",
#                 "\u5b5f\u52a0\u62c9\u56fd",
#                 "\u963f\u62c9\u4f2f\u57c3\u53ca\u5171\u548c\u56fd",
#                 "\u8d8a\u5357",
#                 "\u4e4c\u514b\u5170",
#                 "\u6469\u6d1b\u54e5"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e2d\u4f4e\u7b49\u6536\u5165\u56fd\u5bb6GDP Top10"
#         }
#     ]
# };
#         chart_b1855d00ce4b49c6b1aa4cda71e85c6f.setOption(option_b1855d00ce4b49c6b1aa4cda71e85c6f);
#     });
# </script>

# %%
bar = Bar()
bar.add_xaxis(mid_low_gdp_top20['Country Name'].values.tolist())
bar.add_yaxis("", mid_low_gdp_top20['2018'].values.tolist())
bar.reversal_axis()
bar.set_series_opts(label_opts=opts.LabelOpts(position="right"))
bar.set_global_opts(title_opts=opts.TitleOpts(title="中低等收入国家GDP Top20", subtitle=""),
                   xaxis_opts=opts.AxisOpts(
                axislabel_opts=opts.LabelOpts(formatter="{value} /万亿")
            ),)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="2f10a78864684c54bc0906ce36f952d7" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_2f10a78864684c54bc0906ce36f952d7 = echarts.init(
#             document.getElementById('2f10a78864684c54bc0906ce36f952d7'), 'white', {renderer: 'canvas'});
#         var option_2f10a78864684c54bc0906ce36f952d7 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 2.72632261682131,
#                 1.04217330062555,
#                 0.39726961608090794,
#                 0.330910343610956,
#                 0.312570060548453,
#                 0.274024958965892,
#                 0.250895469644498,
#                 0.244948445308883,
#                 0.130832374404882,
#                 0.11849532819808001,
#                 0.10575098761863,
#                 0.0879082625202133,
#                 0.0712148033778188,
#                 0.0655564640564301,
#                 0.050499920318292604,
#                 0.0430070454663406,
#                 0.040851536133764195,
#                 0.0402876477568741,
#                 0.0398607158144238,
#                 0.0385020598584389
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} /\u4e07\u4ebf"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5370\u5ea6",
#                 "\u5370\u5ea6\u5c3c\u897f\u4e9a",
#                 "\u5c3c\u65e5\u5229\u4e9a",
#                 "\u83f2\u5f8b\u5bbe",
#                 "\u5df4\u57fa\u65af\u5766",
#                 "\u5b5f\u52a0\u62c9\u56fd",
#                 "\u963f\u62c9\u4f2f\u57c3\u53ca\u5171\u548c\u56fd",
#                 "\u8d8a\u5357",
#                 "\u4e4c\u514b\u5170",
#                 "\u6469\u6d1b\u54e5",
#                 "\u5b89\u54e5\u62c9",
#                 "\u80af\u5c3c\u4e9a",
#                 "\u7f05\u7538",
#                 "\u52a0\u7eb3",
#                 "\u4e4c\u5179\u522b\u514b\u65af\u5766",
#                 "\u79d1\u7279\u8fea\u74e6",
#                 "\u82cf\u4e39",
#                 "\u73bb\u5229\u7ef4\u4e9a",
#                 "\u7a81\u5c3c\u65af",
#                 "\u5580\u9ea6\u9686"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e2d\u4f4e\u7b49\u6536\u5165\u56fd\u5bb6GDP Top20"
#         }
#     ]
# };
#         chart_2f10a78864684c54bc0906ce36f952d7.setOption(option_2f10a78864684c54bc0906ce36f952d7);
#     });
# </script>

# %%
# 低等收入国家
low = country_data[country_data['Income_Group'] == '低收入国家']
low_gdp = pd.merge(low, gdp, how='inner')
low_gdp['2018'] = low_gdp['2018'].apply(lambda x: x/1000000000000)
low_gdp_top10 = low_gdp[['Country Name', 'Country Code', '2018']].sort_values(by='2018', ascending=False)[:10]
low_gdp_top20 = low_gdp[['Country Name', 'Country Code', '2018']].sort_values(by='2018', ascending=False)[:20]

# %%
bar = Bar()
bar.add_xaxis(low_gdp_top10['Country Name'].values.tolist())
bar.add_yaxis("", low_gdp_top10['2018'].values.tolist())
bar.reversal_axis()
bar.set_series_opts(label_opts=opts.LabelOpts(position="right"))
bar.set_global_opts(title_opts=opts.TitleOpts(title="低等收入国家GDP Top10", subtitle=""),
                   xaxis_opts=opts.AxisOpts(
                axislabel_opts=opts.LabelOpts(formatter="{value} /万亿")
            ),)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="43f44ae0e5b5402a8e0ac3c9d9556934" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_43f44ae0e5b5402a8e0ac3c9d9556934 = echarts.init(
#             document.getElementById('43f44ae0e5b5402a8e0ac3c9d9556934'), 'white', {renderer: 'canvas'});
#         var option_43f44ae0e5b5402a8e0ac3c9d9556934 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 0.0843554624940837,
#                 0.0574370739271796,
#                 0.047227535290940495,
#                 0.0288124918915812,
#                 0.027476945526012996,
#                 0.0269144022237828,
#                 0.0193629695823643,
#                 0.0171966889199878,
#                 0.0144579643808548,
#                 0.0144417637586919
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} /\u4e07\u4ebf"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u57c3\u585e\u4fc4\u6bd4\u4e9a",
#                 "\u5766\u6851\u5c3c\u4e9a",
#                 "\u521a\u679c\uff08\u91d1\uff09",
#                 "\u5c3c\u6cca\u5c14",
#                 "\u4e4c\u5e72\u8fbe",
#                 "\u4e5f\u95e8\u5171\u548c\u56fd",
#                 "\u963f\u5bcc\u6c57",
#                 "\u9a6c\u91cc",
#                 "\u83ab\u6851\u6bd4\u514b",
#                 "\u5e03\u57fa\u7eb3\u6cd5\u7d22"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4f4e\u7b49\u6536\u5165\u56fd\u5bb6GDP Top10"
#         }
#     ]
# };
#         chart_43f44ae0e5b5402a8e0ac3c9d9556934.setOption(option_43f44ae0e5b5402a8e0ac3c9d9556934);
#     });
# </script>

# %%
bar = Bar()
bar.add_xaxis(low_gdp_top20['Country Name'].values.tolist())
bar.add_yaxis("", low_gdp_top20['2018'].values.tolist())
bar.reversal_axis()
bar.set_series_opts(label_opts=opts.LabelOpts(position="right"))
bar.set_global_opts(title_opts=opts.TitleOpts(title="低等收入国家GDP Top20", subtitle=""),
                   xaxis_opts=opts.AxisOpts(
                axislabel_opts=opts.LabelOpts(formatter="{value} /万亿")
            ),)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="3118542018a54e5b8aa373b73d9bc16d" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_3118542018a54e5b8aa373b73d9bc16d = echarts.init(
#             document.getElementById('3118542018a54e5b8aa373b73d9bc16d'), 'white', {renderer: 'canvas'});
#         var option_3118542018a54e5b8aa373b73d9bc16d = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 0.0843554624940837,
#                 0.0574370739271796,
#                 0.047227535290940495,
#                 0.0288124918915812,
#                 0.027476945526012996,
#                 0.0269144022237828,
#                 0.0193629695823643,
#                 0.0171966889199878,
#                 0.0144579643808548,
#                 0.0144417637586919,
#                 0.0121004590872532,
#                 0.0113025442049904,
#                 0.0109897902563533,
#                 0.010358985583235001,
#                 0.009658084644227958,
#                 0.00950900319673999,
#                 0.00923951352965905,
#                 0.00752294781012326,
#                 0.00706497117634408,
#                 0.00530021433717579
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} /\u4e07\u4ebf"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u57c3\u585e\u4fc4\u6bd4\u4e9a",
#                 "\u5766\u6851\u5c3c\u4e9a",
#                 "\u521a\u679c\uff08\u91d1\uff09",
#                 "\u5c3c\u6cca\u5c14",
#                 "\u4e4c\u5e72\u8fbe",
#                 "\u4e5f\u95e8\u5171\u548c\u56fd",
#                 "\u963f\u5bcc\u6c57",
#                 "\u9a6c\u91cc",
#                 "\u83ab\u6851\u6bd4\u514b",
#                 "\u5e03\u57fa\u7eb3\u6cd5\u7d22",
#                 "\u9a6c\u8fbe\u52a0\u65af\u52a0",
#                 "\u4e4d\u5f97",
#                 "\u51e0\u5185\u4e9a",
#                 "\u8d1d\u5b81",
#                 "\u6d77\u5730",
#                 "\u5362\u65fa\u8fbe",
#                 "\u5c3c\u65e5\u5c14",
#                 "\u5854\u5409\u514b\u65af\u5766",
#                 "\u9a6c\u62c9\u7ef4",
#                 "\u591a\u54e5"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4f4e\u7b49\u6536\u5165\u56fd\u5bb6GDP Top20"
#         }
#     ]
# };
#         chart_3118542018a54e5b8aa373b73d9bc16d.setOption(option_3118542018a54e5b8aa373b73d9bc16d);
#     });
# </script>

# %%
high_gdp
# Out:
#    Country Name Country Code Region Income_Group  Unnamed: 4 Indicator Name  \
# 0           阿鲁巴          ABW    NaN        高收入国家         NaN      GDP（现价美元）
# 1        安道尔共和国          AND    NaN        高收入国家         NaN      GDP（现价美元）
# 2      阿拉伯联合酋长国          ARE    NaN        高收入国家         NaN      GDP（现价美元）
# 3       安提瓜和巴布达          ATG    NaN        高收入国家         NaN      GDP（现价美元）
# 4          澳大利亚          AUS    NaN        高收入国家         NaN      GDP（现价美元）
# ..          ...          ...    ...          ...         ...            ...
# 74     特立尼达和多巴哥          TTO    NaN        高收入国家         NaN      GDP（现价美元）
# 75          乌拉圭          URY    NaN        高收入国家         NaN      GDP（现价美元）
# 76           美国          USA    NaN        高收入国家         NaN      GDP（现价美元）
# 77      英屬維爾京群島          VGB    NaN        高收入国家         NaN      GDP（现价美元）
# 78       美属维京群岛          VIR    NaN        高收入国家         NaN      GDP（现价美元）
#
#     Indicator Code          1960          1961          1962  ...  \
# 0   NY.GDP.MKTP.CD           NaN           NaN           NaN  ...
# 1   NY.GDP.MKTP.CD           NaN           NaN           NaN  ...
# 2   NY.GDP.MKTP.CD           NaN           NaN           NaN  ...
# 3   NY.GDP.MKTP.CD           NaN           NaN           NaN  ...
# 4   NY.GDP.MKTP.CD  1.857767e+10  1.965394e+10  1.989249e+10  ...
# ..             ...           ...           ...           ...  ...
# 74  NY.GDP.MKTP.CD  5.356701e+08  5.849612e+08  6.193192e+08  ...
# 75  NY.GDP.MKTP.CD  1.242289e+09  1.547389e+09  1.710004e+09  ...
# 76  NY.GDP.MKTP.CD  5.433000e+11  5.633000e+11  6.051000e+11  ...
# 77  NY.GDP.MKTP.CD           NaN           NaN           NaN  ...
# 78  NY.GDP.MKTP.CD           NaN           NaN           NaN  ...
#
#             2011          2012          2013          2014          2015  \
# 0   2.549721e+09  2.534637e+09  2.581564e+09  2.649721e+09  2.691620e+09
# 1   3.442063e+09  3.164615e+09  3.281585e+09  3.350736e+09  2.811489e+09
# 2   3.506660e+11  3.745906e+11  3.901076e+11  4.031371e+11  3.581351e+11
# 3   1.142043e+09  1.211412e+09  1.192920e+09  1.275577e+09  1.359195e+09
# 4   1.396650e+12  1.546152e+12  1.576184e+12  1.467484e+12  1.351520e+12
# ..           ...           ...           ...           ...           ...
# 74  2.543301e+10  2.576933e+10  2.711026e+10  2.747797e+10  2.512152e+10
# 75  4.796244e+10  5.126439e+10  5.753123e+10  5.723601e+10  5.327430e+10
# 76  1.554258e+13  1.619701e+13  1.678485e+13  1.752175e+13  1.821930e+13
# 77           NaN           NaN           NaN           NaN           NaN
# 78  4.239000e+09  4.095000e+09  3.762000e+09  3.622000e+09  3.748000e+09
#
#             2016          2017          2018  2019  Unnamed: 64
# 0   2.646927e+09  2.700559e+09           NaN   NaN          NaN
# 1   2.877312e+09  3.013387e+09  3.236544e+09   NaN          NaN
# 2   3.570451e+11  3.825751e+11  4.141789e+11   NaN          NaN
# 3   1.464630e+09  1.510085e+09  1.623804e+09   NaN          NaN
# 4   1.210028e+12  1.330803e+12  1.432195e+12   NaN          NaN
# ..           ...           ...           ...   ...          ...
# 74  2.174639e+10  2.225046e+10  2.341035e+10   NaN          NaN
# 75  5.268761e+10  5.648899e+10  5.959689e+10   NaN          NaN
# 76  1.870719e+13  1.948539e+13  2.049410e+13   NaN          NaN
# 77           NaN           NaN           NaN   NaN          NaN
# 78  3.863000e+09  3.855000e+09           NaN   NaN          NaN
#
# [79 rows x 68 columns]

# %%
gdp
# Out:
#     Country Name Country Code Indicator Name  Indicator Code          1960  \
# 0            阿鲁巴          ABW      GDP（现价美元）  NY.GDP.MKTP.CD           NaN
# 1            阿富汗          AFG      GDP（现价美元）  NY.GDP.MKTP.CD  5.377778e+08
# 2            安哥拉          AGO      GDP（现价美元）  NY.GDP.MKTP.CD           NaN
# 3          阿尔巴尼亚          ALB      GDP（现价美元）  NY.GDP.MKTP.CD           NaN
# 4         安道尔共和国          AND      GDP（现价美元）  NY.GDP.MKTP.CD           NaN
# ..           ...          ...            ...             ...           ...
# 259          科索沃          XKX      GDP（现价美元）  NY.GDP.MKTP.CD           NaN
# 260        也门共和国          YEM      GDP（现价美元）  NY.GDP.MKTP.CD           NaN
# 261           南非          ZAF      GDP（现价美元）  NY.GDP.MKTP.CD  7.575397e+09
# 262          赞比亚          ZMB      GDP（现价美元）  NY.GDP.MKTP.CD  7.130000e+08
# 263         津巴布韦          ZWE      GDP（现价美元）  NY.GDP.MKTP.CD  1.052990e+09
#
#              1961          1962          1963          1964          1965  \
# 0             NaN           NaN           NaN           NaN           NaN
# 1    5.488889e+08  5.466667e+08  7.511112e+08  8.000000e+08  1.006667e+09
# 2             NaN           NaN           NaN           NaN           NaN
# 3             NaN           NaN           NaN           NaN           NaN
# 4             NaN           NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...           ...
# 259           NaN           NaN           NaN           NaN           NaN
# 260           NaN           NaN           NaN           NaN           NaN
# 261  7.972997e+09  8.497997e+09  9.423396e+09  1.037400e+10  1.133440e+10
# 262  6.962857e+08  6.931429e+08  7.187143e+08  8.394286e+08  1.082857e+09
# 263  1.096647e+09  1.117602e+09  1.159512e+09  1.217138e+09  1.311436e+09
#
#      ...          2011          2012          2013          2014  \
# 0    ...  2.549721e+09  2.534637e+09  2.581564e+09  2.649721e+09
# 1    ...  1.780428e+10  2.000162e+10  2.056105e+10  2.048487e+10
# 2    ...  1.117897e+11  1.280529e+11  1.367099e+11  1.457122e+11
# 3    ...  1.289087e+10  1.231978e+10  1.277628e+10  1.322825e+10
# 4    ...  3.442063e+09  3.164615e+09  3.281585e+09  3.350736e+09
# ..   ...           ...           ...           ...           ...
# 259  ...  6.691827e+09  6.499936e+09  7.071960e+09  7.386891e+09
# 260  ...  3.272642e+10  3.540134e+10  4.041523e+10  4.322859e+10
# 261  ...  4.164170e+11  3.963294e+11  3.666449e+11  3.506376e+11
# 262  ...  2.346010e+10  2.550337e+10  2.804546e+10  2.715063e+10
# 263  ...  1.410192e+10  1.711485e+10  1.909102e+10  1.949552e+10
#
#              2015          2016          2017          2018  2019  Unnamed: 64
# 0    2.691620e+09  2.646927e+09  2.700559e+09           NaN   NaN          NaN
# 1    1.990711e+10  1.936264e+10  2.019176e+10  1.936297e+10   NaN          NaN
# 2    1.161936e+11  1.011239e+11  1.221238e+11  1.057510e+11   NaN          NaN
# 3    1.138693e+10  1.186135e+10  1.302506e+10  1.505888e+10   NaN          NaN
# 4    2.811489e+09  2.877312e+09  3.013387e+09  3.236544e+09   NaN          NaN
# ..            ...           ...           ...           ...   ...          ...
# 259  6.440612e+09  6.714712e+09  7.227765e+09  7.900269e+09   NaN          NaN
# 260  4.262833e+10  3.096824e+10  2.681870e+10  2.691440e+10   NaN          NaN
# 261  3.174156e+11  2.963409e+11  3.492681e+11  3.682882e+11   NaN          NaN
# 262  2.115439e+10  2.095475e+10  2.586814e+10  2.672007e+10   NaN          NaN
# 263  1.996312e+10  2.054868e+10  2.281301e+10  3.100052e+10   NaN          NaN
#
# [264 rows x 65 columns]

# %%
country_gdp = pd.merge(country_data, gdp, how='inner')

# %%
country_gdp
# Out:
#     Country Name Country Code             Region Income_Group  Unnamed: 4  \
# 0            阿鲁巴          ABW                NaN        高收入国家         NaN
# 1            阿富汗          AFG                 南亚        低收入国家         NaN
# 2            安哥拉          AGO  撒哈拉以南非洲地区（不包括高收入）      中低等收入国家         NaN
# 3          阿尔巴尼亚          ALB    欧洲与中亚地区（不包括高收入）      中高等收入国家         NaN
# 4         安道尔共和国          AND                NaN        高收入国家         NaN
# ..           ...          ...                ...          ...         ...
# 211          科索沃          XKX    欧洲与中亚地区（不包括高收入）      中高等收入国家         NaN
# 212        也门共和国          YEM    中东与北非地区（不包括高收入）        低收入国家         NaN
# 213           南非          ZAF  撒哈拉以南非洲地区（不包括高收入）      中高等收入国家         NaN
# 214          赞比亚          ZMB  撒哈拉以南非洲地区（不包括高收入）      中低等收入国家         NaN
# 215         津巴布韦          ZWE  撒哈拉以南非洲地区（不包括高收入）      中低等收入国家         NaN
#
#     Indicator Name  Indicator Code          1960          1961          1962  \
# 0        GDP（现价美元）  NY.GDP.MKTP.CD           NaN           NaN           NaN
# 1        GDP（现价美元）  NY.GDP.MKTP.CD  5.377778e+08  5.488889e+08  5.466667e+08
# 2        GDP（现价美元）  NY.GDP.MKTP.CD           NaN           NaN           NaN
# 3        GDP（现价美元）  NY.GDP.MKTP.CD           NaN           NaN           NaN
# 4        GDP（现价美元）  NY.GDP.MKTP.CD           NaN           NaN           NaN
# ..             ...             ...           ...           ...           ...
# 211      GDP（现价美元）  NY.GDP.MKTP.CD           NaN           NaN           NaN
# 212      GDP（现价美元）  NY.GDP.MKTP.CD           NaN           NaN           NaN
# 213      GDP（现价美元）  NY.GDP.MKTP.CD  7.575397e+09  7.972997e+09  8.497997e+09
# 214      GDP（现价美元）  NY.GDP.MKTP.CD  7.130000e+08  6.962857e+08  6.931429e+08
# 215      GDP（现价美元）  NY.GDP.MKTP.CD  1.052990e+09  1.096647e+09  1.117602e+09
#
#      ...          2011          2012          2013          2014  \
# 0    ...  2.549721e+09  2.534637e+09  2.581564e+09  2.649721e+09
# 1    ...  1.780428e+10  2.000162e+10  2.056105e+10  2.048487e+10
# 2    ...  1.117897e+11  1.280529e+11  1.367099e+11  1.457122e+11
# 3    ...  1.289087e+10  1.231978e+10  1.277628e+10  1.322825e+10
# 4    ...  3.442063e+09  3.164615e+09  3.281585e+09  3.350736e+09
# ..   ...           ...           ...           ...           ...
# 211  ...  6.691827e+09  6.499936e+09  7.071960e+09  7.386891e+09
# 212  ...  3.272642e+10  3.540134e+10  4.041523e+10  4.322859e+10
# 213  ...  4.164170e+11  3.963294e+11  3.666449e+11  3.506376e+11
# 214  ...  2.346010e+10  2.550337e+10  2.804546e+10  2.715063e+10
# 215  ...  1.410192e+10  1.711485e+10  1.909102e+10  1.949552e+10
#
#              2015          2016          2017          2018  2019  Unnamed: 64
# 0    2.691620e+09  2.646927e+09  2.700559e+09           NaN   NaN          NaN
# 1    1.990711e+10  1.936264e+10  2.019176e+10  1.936297e+10   NaN          NaN
# 2    1.161936e+11  1.011239e+11  1.221238e+11  1.057510e+11   NaN          NaN
# 3    1.138693e+10  1.186135e+10  1.302506e+10  1.505888e+10   NaN          NaN
# 4    2.811489e+09  2.877312e+09  3.013387e+09  3.236544e+09   NaN          NaN
# ..            ...           ...           ...           ...   ...          ...
# 211  6.440612e+09  6.714712e+09  7.227765e+09  7.900269e+09   NaN          NaN
# 212  4.262833e+10  3.096824e+10  2.681870e+10  2.691440e+10   NaN          NaN
# 213  3.174156e+11  2.963409e+11  3.492681e+11  3.682882e+11   NaN          NaN
# 214  2.115439e+10  2.095475e+10  2.586814e+10  2.672007e+10   NaN          NaN
# 215  1.996312e+10  2.054868e+10  2.281301e+10  3.100052e+10   NaN          NaN
#
# [216 rows x 68 columns]

# %%
# country_gdp['2018'] = country_gdp['2018'].apply(lambda x: x/1000000000000)

# %%
country_gdp[['Country Name', 'Country Code', '2018']].sort_values(by='2018', ascending=False)[:60]
# Out:
#     Country Name Country Code       2018
# 202           美国          USA  20.494100
# 36            中国          CHN  13.608152
# 97            日本          JPN   4.970916
# 50            德国          DEU   3.996759
# 68            英国          GBR   2.825208
# 64            法国          FRA   2.777535
# 89            印度          IND   2.726323
# 94           意大利          ITA   2.073902
# 26            巴西          BRA   1.868626
# 32           加拿大          CAN   1.712510
# 164        俄罗斯联邦          RUS   1.657554
# 104         大韩民国          KOR   1.619424
# 10          澳大利亚          AUS   1.432195
# 59           西班牙          ESP   1.426189
# 124          墨西哥          MEX   1.223809
# 87         印度尼西亚          IDN   1.042173
# 143           荷兰          NLD   0.913658
# 166        沙特阿拉伯          SAU   0.782483
# 196          土耳其          TUR   0.766509
# 33            瑞士          CHE   0.705501
# 155           波兰          POL   0.585783
# 181           瑞典          SWE   0.551032
# 14           比利时          BEL   0.531767
# 6            阿根廷          ARG   0.518475
# 189           泰国          THA   0.504993
# 11           奥地利          AUT   0.455737
# 144           挪威          NOR   0.434751
# 5       阿拉伯联合酋长国          ARE   0.414179
# 141         尼日利亚          NGA   0.397270
# 90           爱尔兰          IRL   0.382487
# 93           以色列          ISR   0.369690
# 213           南非          ZAF   0.368288
# 169          新加坡          SGP   0.364157
# 82     中国香港特别行政区          HKG   0.362993
# 137         马来西亚          MYS   0.354348
# 53            丹麦          DNK   0.352058
# 152          菲律宾          PHL   0.330910
# 41          哥伦比亚          COL   0.330228
# 149         巴基斯坦          PAK   0.312570
# 35            智利          CHL   0.298231
# 17          孟加拉国          BGD   0.274025
# 62            芬兰          FIN   0.273961
# 57      阿拉伯埃及共和国          EGY   0.250895
# 49         捷克共和国          CZE   0.245226
# 208           越南          VNM   0.244948
# 163         罗马尼亚          ROU   0.239553
# 158          葡萄牙          PRT   0.237979
# 91           伊拉克          IRQ   0.225914
# 151           秘鲁          PER   0.222238
# 76            希腊          GRC   0.218032
# 147          新西兰          NZL   0.205025
# 162          卡塔尔          QAT   0.192009
# 55         阿尔及利亚          DZA   0.180689
# 98         哈萨克斯坦          KAZ   0.170539
# 86           匈牙利          HUN   0.155703
# 105          科威特          KWT   0.141678
# 200          乌克兰          UKR   0.130832
# 119          摩洛哥          MAR   0.118495
# 56          厄瓜多尔          ECU   0.108398
# 179      斯洛伐克共和国          SVK   0.106472

# %%
#############################
# 历年GDP分析

# %%
df_china = country_gdp[country_gdp['Country Name']=='中国']

# %%
for i in range(1960, 2019):
    df_china[str(i)] = df_china[str(i)].apply(lambda x: x/1000000000000)
# Out:
# c:\users\wei.zhou\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_usa = country_gdp[country_gdp['Country Name']=='美国']
for i in range(1960, 2019):
    df_usa[str(i)] = df_usa[str(i)].apply(lambda x: x/1000000000000)
df_usa
# Out:
# c:\users\wei.zhou\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#     Country Name Country Code Region Income_Group  Unnamed: 4 Indicator Name  \
# 202           美国          USA    NaN        高收入国家         NaN      GDP（现价美元）
#
#      Indicator Code    1960    1961    1962  ...       2011       2012  \
# 202  NY.GDP.MKTP.CD  0.5433  0.5633  0.6051  ...  15.542581  16.197007
#
#           2013       2014       2015       2016       2017     2018  2019  \
# 202  16.784849  17.521747  18.219298  18.707188  19.485394  20.4941   NaN
#
#      Unnamed: 64
# 202          NaN
#
# [1 rows x 68 columns]

# %%
df_jpn = country_gdp[country_gdp['Country Name']=='日本']
for i in range(1960, 2019):
    df_jpn[str(i)] = df_jpn[str(i)].apply(lambda x: x/1000000000000)
df_jpn
# Out:
# c:\users\wei.zhou\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Country Name Country Code Region Income_Group  Unnamed: 4 Indicator Name  \
# 97           日本          JPN    NaN        高收入国家         NaN      GDP（现价美元）
#
#     Indicator Code      1960      1961      1962  ...     2011      2012  \
# 97  NY.GDP.MKTP.CD  0.044307  0.053509  0.060723  ...  6.15746  6.203213
#
#         2013      2014      2015      2016      2017      2018  2019  \
# 97  5.155717  4.850414  4.389476  4.926667  4.859951  4.970916   NaN
#
#     Unnamed: 64
# 97          NaN
#
# [1 rows x 68 columns]

# %%
df_de = country_gdp[country_gdp['Country Name']=='德国']
for i in range(1960, 2019):
    df_de[str(i)] = df_de[str(i)].apply(lambda x: x/1000000000000)
df_de
# Out:
# c:\users\wei.zhou\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Country Name Country Code Region Income_Group  Unnamed: 4 Indicator Name  \
# 50           德国          DEU    NaN        高收入国家         NaN      GDP（现价美元）
#
#     Indicator Code  1960  1961  1962  ...      2011      2012      2013  \
# 50  NY.GDP.MKTP.CD   NaN   NaN   NaN  ...  3.757698  3.543984  3.752514
#
#         2014      2015      2016      2017      2018  2019  Unnamed: 64
# 50  3.898727  3.381389  3.495163  3.693204  3.996759   NaN          NaN
#
# [1 rows x 68 columns]

# %%
df_uk = country_gdp[country_gdp['Country Name']=='英国']
for i in range(1960, 2019):
    df_uk[str(i)] = df_uk[str(i)].apply(lambda x: x/1000000000000)
df_uk
# Out:
# c:\users\wei.zhou\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Country Name Country Code Region Income_Group  Unnamed: 4 Indicator Name  \
# 68           英国          GBR    NaN        高收入国家         NaN      GDP（现价美元）
#
#     Indicator Code      1960      1961      1962  ...      2011      2012  \
# 68  NY.GDP.MKTP.CD  0.072328  0.076694  0.080602  ...  2.634896  2.676605
#
#         2013      2014      2015      2016      2017      2018  2019  \
# 68  2.753565  3.034729  2.896421  2.659239  2.637866  2.825208   NaN
#
#     Unnamed: 64
# 68          NaN
#
# [1 rows x 68 columns]

# %%
year_str = [str(i) for i in range(1960, 2019)]

china_gdp = df_china[year_str].values.tolist()[0]
usa_gdp = df_usa[year_str].values.tolist()[0]
jpn_gdp = df_jpn[year_str].values.tolist()[0]
de_gdp = df_de[year_str].values.tolist()[0]
uk_gdp = df_uk[year_str].values.tolist()[0]

# %%
df_china
# Out:
#    Country Name Country Code            Region Income_Group  Unnamed: 4  \
# 36           中国          CHN  东亚与太平洋地区（不包括高收入）      中高等收入国家         NaN
#
#    Indicator Name  Indicator Code      1960      1961      1962  ...    2011  \
# 36      GDP（现价美元）  NY.GDP.MKTP.CD  0.059716  0.050057  0.047209  ...  7.5515
#
#         2012      2013       2014       2015       2016       2017       2018  \
# 36  8.532231  9.570406  10.438529  11.015542  11.137946  12.143491  13.608152
#
#     2019  Unnamed: 64
# 36   NaN          NaN
#
# [1 rows x 68 columns]

# %%
from pyecharts.charts import Scatter

def scatter_base(choose, values, country) -> Scatter:
    c = (
        Scatter()
        .add_xaxis(choose)
        .add_yaxis("%s历年GDP" % country, values)
        .set_global_opts(title_opts=opts.TitleOpts(title=""),
                        # datazoom_opts=opts.DataZoomOpts(),
                         yaxis_opts=opts.AxisOpts(
                axislabel_opts=opts.LabelOpts(formatter="{value} /万亿")
            )
                        )
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    )
    return c

# %%
scatter_base(year_str, china_gdp, '中国').render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="221e5f4854f541b085c0c53614cc4622" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_221e5f4854f541b085c0c53614cc4622 = echarts.init(
#             document.getElementById('221e5f4854f541b085c0c53614cc4622'), 'white', {renderer: 'canvas'});
#         var option_221e5f4854f541b085c0c53614cc4622 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u4e2d\u56fd\u5386\u5e74GDP",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "1960",
#                     0.059716467625314795
#                 ],
#                 [
#                     "1961",
#                     0.0500568689576732
#                 ],
#                 [
#                     "1962",
#                     0.0472093590056056
#                 ],
#                 [
#                     "1963",
#                     0.0507067999025103
#                 ],
#                 [
#                     "1964",
#                     0.059708343488504304
#                 ],
#                 [
#                     "1965",
#                     0.0704362661467219
#                 ],
#                 [
#                     "1966",
#                     0.0767202859696157
#                 ],
#                 [
#                     "1967",
#                     0.0728816313266715
#                 ],
#                 [
#                     "1968",
#                     0.0708465350556503
#                 ],
#                 [
#                     "1969",
#                     0.0797059062474612
#                 ],
#                 [
#                     "1970",
#                     0.0926029734340726
#                 ],
#                 [
#                     "1971",
#                     0.0998009586481436
#                 ],
#                 [
#                     "1972",
#                     0.113687586299051
#                 ],
#                 [
#                     "1973",
#                     0.138544284708957
#                 ],
#                 [
#                     "1974",
#                     0.14418213338772198
#                 ],
#                 [
#                     "1975",
#                     0.163431551779761
#                 ],
#                 [
#                     "1976",
#                     0.153940455341506
#                 ],
#                 [
#                     "1977",
#                     0.174938098826569
#                 ],
#                 [
#                     "1978",
#                     0.14954075282926801
#                 ],
#                 [
#                     "1979",
#                     0.178280594413043
#                 ],
#                 [
#                     "1980",
#                     0.191149211575
#                 ],
#                 [
#                     "1981",
#                     0.19586638243254
#                 ],
#                 [
#                     "1982",
#                     0.20508969985877898
#                 ],
#                 [
#                     "1983",
#                     0.230686747153257
#                 ],
#                 [
#                     "1984",
#                     0.259946510957143
#                 ],
#                 [
#                     "1985",
#                     0.309488028132653
#                 ],
#                 [
#                     "1986",
#                     0.300758100107246
#                 ],
#                 [
#                     "1987",
#                     0.272972974764574
#                 ],
#                 [
#                     "1988",
#                     0.31235363120781895
#                 ],
#                 [
#                     "1989",
#                     0.34776805131174104
#                 ],
#                 [
#                     "1990",
#                     0.360857912565966
#                 ],
#                 [
#                     "1991",
#                     0.38337331808362396
#                 ],
#                 [
#                     "1992",
#                     0.426915712711146
#                 ],
#                 [
#                     "1993",
#                     0.444731282436762
#                 ],
#                 [
#                     "1994",
#                     0.564324670005917
#                 ],
#                 [
#                     "1995",
#                     0.7345478982205079
#                 ],
#                 [
#                     "1996",
#                     0.8637467175037891
#                 ],
#                 [
#                     "1997",
#                     0.96160395295182
#                 ],
#                 [
#                     "1998",
#                     1.0290430975540799
#                 ],
#                 [
#                     "1999",
#                     1.09399726727106
#                 ],
#                 [
#                     "2000",
#                     1.21134686960524
#                 ],
#                 [
#                     "2001",
#                     1.3393957188653
#                 ],
#                 [
#                     "2002",
#                     1.47055001508155
#                 ],
#                 [
#                     "2003",
#                     1.6602879656626799
#                 ],
#                 [
#                     "2004",
#                     1.95534700496327
#                 ],
#                 [
#                     "2005",
#                     2.28596589236054
#                 ],
#                 [
#                     "2006",
#                     2.7521317733551602
#                 ],
#                 [
#                     "2007",
#                     3.55034242523825
#                 ],
#                 [
#                     "2008",
#                     4.59430684876308
#                 ],
#                 [
#                     "2009",
#                     5.10170243288345
#                 ],
#                 [
#                     "2010",
#                     6.0871645274212405
#                 ],
#                 [
#                     "2011",
#                     7.551500425597769
#                 ],
#                 [
#                     "2012",
#                     8.53223072414176
#                 ],
#                 [
#                     "2013",
#                     9.570405758739788
#                 ],
#                 [
#                     "2014",
#                     10.4385291532376
#                 ],
#                 [
#                     "2015",
#                     11.0155423524689
#                 ],
#                 [
#                     "2016",
#                     11.1379456693506
#                 ],
#                 [
#                     "2017",
#                     12.143491448186099
#                 ],
#                 [
#                     "2018",
#                     13.6081518646379
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e2d\u56fd\u5386\u5e74GDP"
#             ],
#             "selected": {
#                 "\u4e2d\u56fd\u5386\u5e74GDP": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },

# %%
scatter_base(year_str, usa_gdp, '美国').render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="f8aa6497470d4900b88661e737fb16f0" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_f8aa6497470d4900b88661e737fb16f0 = echarts.init(
#             document.getElementById('f8aa6497470d4900b88661e737fb16f0'), 'white', {renderer: 'canvas'});
#         var option_f8aa6497470d4900b88661e737fb16f0 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u7f8e\u56fd\u5386\u5e74GDP",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "1960",
#                     0.5433
#                 ],
#                 [
#                     "1961",
#                     0.5633
#                 ],
#                 [
#                     "1962",
#                     0.6051
#                 ],
#                 [
#                     "1963",
#                     0.6386
#                 ],
#                 [
#                     "1964",
#                     0.6858
#                 ],
#                 [
#                     "1965",
#                     0.7437
#                 ],
#                 [
#                     "1966",
#                     0.815
#                 ],
#                 [
#                     "1967",
#                     0.8617
#                 ],
#                 [
#                     "1968",
#                     0.9425
#                 ],
#                 [
#                     "1969",
#                     1.0199
#                 ],
#                 [
#                     "1970",
#                     1.073303
#                 ],
#                 [
#                     "1971",
#                     1.16485
#                 ],
#                 [
#                     "1972",
#                     1.27911
#                 ],
#                 [
#                     "1973",
#                     1.425376
#                 ],
#                 [
#                     "1974",
#                     1.545243
#                 ],
#                 [
#                     "1975",
#                     1.684904
#                 ],
#                 [
#                     "1976",
#                     1.873412
#                 ],
#                 [
#                     "1977",
#                     2.081826
#                 ],
#                 [
#                     "1978",
#                     2.351599
#                 ],
#                 [
#                     "1979",
#                     2.627334
#                 ],
#                 [
#                     "1980",
#                     2.857307
#                 ],
#                 [
#                     "1981",
#                     3.207042
#                 ],
#                 [
#                     "1982",
#                     3.343789
#                 ],
#                 [
#                     "1983",
#                     3.634038
#                 ],
#                 [
#                     "1984",
#                     4.037613
#                 ],
#                 [
#                     "1985",
#                     4.338979
#                 ],
#                 [
#                     "1986",
#                     4.579631
#                 ],
#                 [
#                     "1987",
#                     4.855215
#                 ],
#                 [
#                     "1988",
#                     5.236438
#                 ],
#                 [
#                     "1989",
#                     5.64158
#                 ],
#                 [
#                     "1990",
#                     5.963144
#                 ],
#                 [
#                     "1991",
#                     6.158129
#                 ],
#                 [
#                     "1992",
#                     6.520327
#                 ],
#                 [
#                     "1993",
#                     6.858559
#                 ],
#                 [
#                     "1994",
#                     7.287236
#                 ],
#                 [
#                     "1995",
#                     7.639749
#                 ],
#                 [
#                     "1996",
#                     8.073122
#                 ],
#                 [
#                     "1997",
#                     8.577554463
#                 ],
#                 [
#                     "1998",
#                     9.062818211
#                 ],
#                 [
#                     "1999",
#                     9.630664202
#                 ],
#                 [
#                     "2000",
#                     10.252345464
#                 ],
#                 [
#                     "2001",
#                     10.581821399
#                 ],
#                 [
#                     "2002",
#                     10.936419054
#                 ],
#                 [
#                     "2003",
#                     11.458243878
#                 ],
#                 [
#                     "2004",
#                     12.213729147
#                 ],
#                 [
#                     "2005",
#                     13.036640229
#                 ],
#                 [
#                     "2006",
#                     13.814611414
#                 ],
#                 [
#                     "2007",
#                     14.45185865
#                 ],
#                 [
#                     "2008",
#                     14.712844084
#                 ],
#                 [
#                     "2009",
#                     14.448933025
#                 ],
#                 [
#                     "2010",
#                     14.992052727
#                 ],
#                 [
#                     "2011",
#                     15.542581104
#                 ],
#                 [
#                     "2012",
#                     16.197007349
#                 ],
#                 [
#                     "2013",
#                     16.78484919
#                 ],
#                 [
#                     "2014",
#                     17.521746534
#                 ],
#                 [
#                     "2015",
#                     18.219297584
#                 ],
#                 [
#                     "2016",
#                     18.707188235
#                 ],
#                 [
#                     "2017",
#                     19.485393853
#                 ],
#                 [
#                     "2018",
#                     20.4941
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7f8e\u56fd\u5386\u5e74GDP"
#             ],
#             "selected": {
#                 "\u7f8e\u56fd\u5386\u5e74GDP": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width":

# %%
scatter_base(year_str, jpn_gdp, '日本').render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="b14cca719d9a4b0fabc78dd46391020a" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_b14cca719d9a4b0fabc78dd46391020a = echarts.init(
#             document.getElementById('b14cca719d9a4b0fabc78dd46391020a'), 'white', {renderer: 'canvas'});
#         var option_b14cca719d9a4b0fabc78dd46391020a = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u65e5\u672c\u5386\u5e74GDP",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "1960",
#                     0.0443073429504
#                 ],
#                 [
#                     "1961",
#                     0.0535086177393778
#                 ],
#                 [
#                     "1962",
#                     0.060723018683733296
#                 ],
#                 [
#                     "1963",
#                     0.0694981317973333
#                 ],
#                 [
#                     "1964",
#                     0.0817490063815111
#                 ],
#                 [
#                     "1965",
#                     0.0909502782577778
#                 ],
#                 [
#                     "1966",
#                     0.10562807034311099
#                 ],
#                 [
#                     "1967",
#                     0.1237818802176
#                 ],
#                 [
#                     "1968",
#                     0.14660107268551098
#                 ],
#                 [
#                     "1969",
#                     0.172204199480889
#                 ],
#                 [
#                     "1970",
#                     0.212609187920833
#                 ],
#                 [
#                     "1971",
#                     0.24015180745995499
#                 ],
#                 [
#                     "1972",
#                     0.318031297492682
#                 ],
#                 [
#                     "1973",
#                     0.43208267045108706
#                 ],
#                 [
#                     "1974",
#                     0.479625998614775
#                 ],
#                 [
#                     "1975",
#                     0.521541905671903
#                 ],
#                 [
#                     "1976",
#                     0.58616185900102
#                 ],
#                 [
#                     "1977",
#                     0.721411786537187
#                 ],
#                 [
#                     "1978",
#                     1.01361217351979
#                 ],
#                 [
#                     "1979",
#                     1.05501211952816
#                 ],
#                 [
#                     "1980",
#                     1.10538597376387
#                 ],
#                 [
#                     "1981",
#                     1.21898893512981
#                 ],
#                 [
#                     "1982",
#                     1.13451800188456
#                 ],
#                 [
#                     "1983",
#                     1.2433235920588301
#                 ],
#                 [
#                     "1984",
#                     1.31838162700376
#                 ],
#                 [
#                     "1985",
#                     1.39889274482069
#                 ],
#                 [
#                     "1986",
#                     2.07895333367355
#                 ],
#                 [
#                     "1987",
#                     2.5328085731570296
#                 ],
#                 [
#                     "1988",
#                     3.07168301317891
#                 ],
#                 [
#                     "1989",
#                     3.0549141662631802
#                 ],
#                 [
#                     "1990",
#                     3.1328176528480403
#                 ],
#                 [
#                     "1991",
#                     3.5844200771008397
#                 ],
#                 [
#                     "1992",
#                     3.90880946346386
#                 ],
#                 [
#                     "1993",
#                     4.45414387694721
#                 ],
#                 [
#                     "1994",
#                     4.907039384469679
#                 ],
#                 [
#                     "1995",
#                     5.4491163049811
#                 ],
#                 [
#                     "1996",
#                     4.8337125422071
#                 ],
#                 [
#                     "1997",
#                     4.41473284354443
#                 ],
#                 [
#                     "1998",
#                     4.03250976087294
#                 ],
#                 [
#                     "1999",
#                     4.56207882233545
#                 ],
#                 [
#                     "2000",
#                     4.887519660744861
#                 ],
#                 [
#                     "2001",
#                     4.30354425984272
#                 ],
#                 [
#                     "2002",
#                     4.11511627906977
#                 ],
#                 [
#                     "2003",
#                     4.44565807122186
#                 ],
#                 [
#                     "2004",
#                     4.815148854362111
#                 ],
#                 [
#                     "2005",
#                     4.75541063091214
#                 ],
#                 [
#                     "2006",
#                     4.5303772249704
#                 ],
#                 [
#                     "2007",
#                     4.51526451443057
#                 ],
#                 [
#                     "2008",
#                     5.03790846511448
#                 ],
#                 [
#                     "2009",
#                     5.2313826745937
#                 ],
#                 [
#                     "2010",
#                     5.70009811474441
#                 ],
#                 [
#                     "2011",
#                     6.157459594823719
#                 ],
#                 [
#                     "2012",
#                     6.20321312133412
#                 ],
#                 [
#                     "2013",
#                     5.15571705627083
#                 ],
#                 [
#                     "2014",
#                     4.8504135360378395
#                 ],
#                 [
#                     "2015",
#                     4.389475622588971
#                 ],
#                 [
#                     "2016",
#                     4.92666708736751
#                 ],
#                 [
#                     "2017",
#                     4.859950558538969
#                 ],
#                 [
#                     "2018",
#                     4.97091555663888
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u65e5\u672c\u5386\u5e74GDP"
#             ],
#             "selected": {
#                 "\u65e5\u672c\u5386\u5e74GDP": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {

# %%
scatter_base(year_str, de_gdp, '德国').render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="f4b165a753e44b27ba45a78e0ba7c03b" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_f4b165a753e44b27ba45a78e0ba7c03b = echarts.init(
#             document.getElementById('f4b165a753e44b27ba45a78e0ba7c03b'), 'white', {renderer: 'canvas'});
#         var option_f4b165a753e44b27ba45a78e0ba7c03b = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5fb7\u56fd\u5386\u5e74GDP",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "1960",
#                     NaN
#                 ],
#                 [
#                     "1961",
#                     NaN
#                 ],
#                 [
#                     "1962",
#                     NaN
#                 ],
#                 [
#                     "1963",
#                     NaN
#                 ],
#                 [
#                     "1964",
#                     NaN
#                 ],
#                 [
#                     "1965",
#                     NaN
#                 ],
#                 [
#                     "1966",
#                     NaN
#                 ],
#                 [
#                     "1967",
#                     NaN
#                 ],
#                 [
#                     "1968",
#                     NaN
#                 ],
#                 [
#                     "1969",
#                     NaN
#                 ],
#                 [
#                     "1970",
#                     0.215021806498156
#                 ],
#                 [
#                     "1971",
#                     0.249039217364635
#                 ],
#                 [
#                     "1972",
#                     0.298667219346133
#                 ],
#                 [
#                     "1973",
#                     0.39686674255397
#                 ],
#                 [
#                     "1974",
#                     0.443618642959716
#                 ],
#                 [
#                     "1975",
#                     0.488780155338262
#                 ],
#                 [
#                     "1976",
#                     0.517787921003573
#                 ],
#                 [
#                     "1977",
#                     0.598226205424071
#                 ],
#                 [
#                     "1978",
#                     0.7376683562804279
#                 ],
#                 [
#                     "1979",
#                     0.8780105369757759
#                 ],
#                 [
#                     "1980",
#                     0.94669535582096
#                 ],
#                 [
#                     "1981",
#                     0.7974434057118129
#                 ],
#                 [
#                     "1982",
#                     0.7736382007737571
#                 ],
#                 [
#                     "1983",
#                     0.7677683780160859
#                 ],
#                 [
#                     "1984",
#                     0.7223676083430691
#                 ],
#                 [
#                     "1985",
#                     0.729763282952432
#                 ],
#                 [
#                     "1986",
#                     1.04230076979195
#                 ],
#                 [
#                     "1987",
#                     1.2932643533188202
#                 ],
#                 [
#                     "1988",
#                     1.39593154850206
#                 ],
#                 [
#                     "1989",
#                     1.39367433215437
#                 ],
#                 [
#                     "1990",
#                     1.7649679489166001
#                 ],
#                 [
#                     "1991",
#                     1.8618738951090201
#                 ],
#                 [
#                     "1992",
#                     2.12313087038197
#                 ],
#                 [
#                     "1993",
#                     2.06855554241098
#                 ],
#                 [
#                     "1994",
#                     2.2059660118115
#                 ],
#                 [
#                     "1995",
#                     2.59162003548519
#                 ],
#                 [
#                     "1996",
#                     2.5036651936573997
#                 ],
#                 [
#                     "1997",
#                     2.21868937514099
#                 ],
#                 [
#                     "1998",
#                     2.24322551961765
#                 ],
#                 [
#                     "1999",
#                     2.19995738333688
#                 ],
#                 [
#                     "2000",
#                     1.9499539340335401
#                 ],
#                 [
#                     "2001",
#                     1.95064876957494
#                 ],
#                 [
#                     "2002",
#                     2.07913608130999
#                 ],
#                 [
#                     "2003",
#                     2.5057336343115097
#                 ],
#                 [
#                     "2004",
#                     2.81924509560467
#                 ],
#                 [
#                     "2005",
#                     2.8614102723541803
#                 ],
#                 [
#                     "2006",
#                     3.00244636808431
#                 ],
#                 [
#                     "2007",
#                     3.4399534629072
#                 ],
#                 [
#                     "2008",
#                     3.7523656071480898
#                 ],
#                 [
#                     "2009",
#                     3.41800500138927
#                 ],
#                 [
#                     "2010",
#                     3.41709456264895
#                 ],
#                 [
#                     "2011",
#                     3.7576982811175497
#                 ],
#                 [
#                     "2012",
#                     3.5439839091480096
#                 ],
#                 [
#                     "2013",
#                     3.75251350327841
#                 ],
#                 [
#                     "2014",
#                     3.89872650384135
#                 ],
#                 [
#                     "2015",
#                     3.3813893386588196
#                 ],
#                 [
#                     "2016",
#                     3.4951628562972203
#                 ],
#                 [
#                     "2017",
#                     3.69320433222978
#                 ],
#                 [
#                     "2018",
#                     3.9967592910578102
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5fb7\u56fd\u5386\u5e74GDP"
#             ],
#             "selected": {
#                 "\u5fb7\u56fd\u5386\u5e74GDP": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale"

# %%
scatter_base(year_str, uk_gdp, '英国').render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="314a44f5fc1c436b93a86970d769a644" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_314a44f5fc1c436b93a86970d769a644 = echarts.init(
#             document.getElementById('314a44f5fc1c436b93a86970d769a644'), 'white', {renderer: 'canvas'});
#         var option_314a44f5fc1c436b93a86970d769a644 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u82f1\u56fd\u5386\u5e74GDP",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "1960",
#                     0.0723280470421588
#                 ],
#                 [
#                     "1961",
#                     0.07669436063591589
#                 ],
#                 [
#                     "1962",
#                     0.08060193963524831
#                 ],
#                 [
#                     "1963",
#                     0.0854437666704279
#                 ],
#                 [
#                     "1964",
#                     0.0933875988139269
#                 ],
#                 [
#                     "1965",
#                     0.100595782309165
#                 ],
#                 [
#                     "1966",
#                     0.10709072144705699
#                 ],
#                 [
#                     "1967",
#                     0.111185383409521
#                 ],
#                 [
#                     "1968",
#                     0.104702736248084
#                 ],
#                 [
#                     "1969",
#                     0.112676874821987
#                 ],
#                 [
#                     "1970",
#                     0.1306719462443
#                 ],
#                 [
#                     "1971",
#                     0.14811389632514002
#                 ],
#                 [
#                     "1972",
#                     0.169965034965035
#                 ],
#                 [
#                     "1973",
#                     0.192537971582558
#                 ],
#                 [
#                     "1974",
#                     0.206131369798971
#                 ],
#                 [
#                     "1975",
#                     0.241756637168142
#                 ],
#                 [
#                     "1976",
#                     0.232614555256065
#                 ],
#                 [
#                     "1977",
#                     0.263066457352172
#                 ],
#                 [
#                     "1978",
#                     0.335883029721956
#                 ],
#                 [
#                     "1979",
#                     0.438994070309191
#                 ],
#                 [
#                     "1980",
#                     0.5649477108993729
#                 ],
#                 [
#                     "1981",
#                     0.5407656752411579
#                 ],
#                 [
#                     "1982",
#                     0.51504891684137
#                 ],
#                 [
#                     "1983",
#                     0.489618008185539
#                 ],
#                 [
#                     "1984",
#                     0.461487097632349
#                 ],
#                 [
#                     "1985",
#                     0.48928516427104707
#                 ],
#                 [
#                     "1986",
#                     0.601452653180885
#                 ],
#                 [
#                     "1987",
#                     0.7451626082693249
#                 ],
#                 [
#                     "1988",
#                     0.9101227321237991
#                 ],
#                 [
#                     "1989",
#                     0.926884816753927
#                 ],
#                 [
#                     "1990",
#                     1.09316938920455
#                 ],
#                 [
#                     "1991",
#                     1.14279717813051
#                 ],
#                 [
#                     "1992",
#                     1.17965952965953
#                 ],
#                 [
#                     "1993",
#                     1.06138872225555
#                 ],
#                 [
#                     "1994",
#                     1.14048974594429
#                 ],
#                 [
#                     "1995",
#                     1.33586239545526
#                 ],
#                 [
#                     "1996",
#                     1.40941029641186
#                 ],
#                 [
#                     "1997",
#                     1.5536231172233101
#                 ],
#                 [
#                     "1998",
#                     1.64166611460749
#                 ],
#                 [
#                     "1999",
#                     1.66827050639055
#                 ],
#                 [
#                     "2000",
#                     1.6482690270842801
#                 ],
#                 [
#                     "2001",
#                     1.62579962573773
#                 ],
#                 [
#                     "2002",
#                     1.77301558752998
#                 ],
#                 [
#                     "2003",
#                     2.04383183673469
#                 ],
#                 [
#                     "2004",
#                     2.4036140607836
#                 ],
#                 [
#                     "2005",
#                     2.5250054545454503
#                 ],
#                 [
#                     "2006",
#                     2.6971517939282403
#                 ],
#                 [
#                     "2007",
#                     3.08411764705882
#                 ],
#                 [
#                     "2008",
#                     2.90403676470588
#                 ],
#                 [
#                     "2009",
#                     2.39478579217947
#                 ],
#                 [
#                     "2010",
#                     2.45289966512447
#                 ],
#                 [
#                     "2011",
#                     2.6348956931312997
#                 ],
#                 [
#                     "2012",
#                     2.67660541764599
#                 ],
#                 [
#                     "2013",
#                     2.75356503377377
#                 ],
#                 [
#                     "2014",
#                     3.03472945604718
#                 ],
#                 [
#                     "2015",
#                     2.8964205865343997
#                 ],
#                 [
#                     "2016",
#                     2.65923893167025
#                 ],
#                 [
#                     "2017",
#                     2.63786634043413
#                 ],
#                 [
#                     "2018",
#                     2.8252079475029
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u82f1\u56fd\u5386\u5e74GDP"
#             ],
#             "selected": {
#                 "\u82f1\u56fd\u5386\u5e74GDP": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {

# %%
import sklearn.pipeline as pl
import sklearn.linear_model as lm
import sklearn.preprocessing as sp
import matplotlib.pyplot as mp
import numpy as np
import sklearn.metrics as sm

# %%
year = [i for i in range(1960, 2019)]
X = np.array(year)
X = X.reshape(-1, 1)
X
# Out:
# array([[1960],
#        [1961],
#        [1962],
#        [1963],
#        [1964],
#        [1965],
#        [1966],
#        [1967],
#        [1968],
#        [1969],
#        [1970],
#        [1971],
#        [1972],
#        [1973],
#        [1974],
#        [1975],
#        [1976],
#        [1977],
#        [1978],
#        [1979],
#        [1980],
#        [1981],
#        [1982],
#        [1983],
#        [1984],
#        [1985],
#        [1986],
#        [1987],
#        [1988],
#        [1989],
#        [1990],
#        [1991],
#        [1992],
#        [1993],
#        [1994],
#        [1995],
#        [1996],
#        [1997],
#        [1998],
#        [1999],
#        [2000],
#        [2001],
#        [2002],
#        [2003],
#        [2004],
#        [2005],
#        [2006],
#        [2007],
#        [2008],
#        [2009],
#        [2010],
#        [2011],
#        [2012],
#        [2013],
#        [2014],
#        [2015],
#        [2016],
#        [2017],
#        [2018]])

# %%
y = usa_gdp

# %%
model = pl.make_pipeline(
    sp.PolynomialFeatures(5),  # 多项式特征拓展器
    lm.LinearRegression()  # 线性回归器
)
# 训练模型
model.fit(X, y)
# 求预测值y
pred_y = model.predict(X)

# %%
pred_y
# Out:
# array([ 0.67561513,  0.64550236,  0.63069893,  0.6310778 ,  0.64651146,
#         0.67687193,  0.7220308 ,  0.78185916,  0.85622766,  0.94500648,
#         1.04806535,  1.16527352,  1.29649978,  1.44161246,  1.60047942,
#         1.77296806,  1.9589453 ,  2.15827761,  2.37083099,  2.59647097,
#         2.8350626 ,  3.08647047,  3.35055872,  3.62719099,  3.91623047,
#         4.21753986,  4.53098142,  4.8564169 ,  5.19370761,  5.54271437,
#         5.90329754,  6.27531699,  6.65863212,  7.05310188,  7.4585847 ,
#         7.87493857,  8.302021  ,  8.739689  ,  9.18779914,  9.64620748,
#        10.11476961, 10.59334065, 11.08177525, 11.57992755, 12.08765123,
#        12.60479949, 13.13122504, 13.66678012, 14.21131649, 14.7646854 ,
#        15.32673766, 15.89732355, 16.47629291, 17.06349506, 17.65877886,
#        18.26199267, 18.87298437, 19.49160136, 20.11769053])

# %%
p_year = [i for i in range(1960, 2020)]
p_X = np.array(p_year)
p_X = p_X.reshape(-1, 1)
p_pred_y = model.predict(p_X)
p_pred_y
# Out:
# array([-6.56811530e-01, -4.31663493e-01, -2.35026973e-01, -6.53989891e-02,
#         7.87281703e-02,  1.98866952e-01,  2.96534541e-01,  3.73252871e-01,
#         4.30548622e-01,  4.69953232e-01,  4.93002894e-01,  5.01238570e-01,
#         4.96205988e-01,  4.79455654e-01,  4.52542849e-01,  4.17027639e-01,
#         3.74474880e-01,  3.26454222e-01,  2.74540110e-01,  2.20311797e-01,
#         1.65353340e-01,  1.11253613e-01,  5.96063043e-02,  1.20099274e-02,
#        -2.99321770e-02, -6.46118355e-02, -9.04160388e-02, -1.05726933e-01,
#        -1.08921820e-01, -9.83731464e-02, -7.24485036e-02, -2.95106209e-02,
#         3.20826372e-02,  1.13978281e-01,  2.17828195e-01,  3.45289144e-01,
#         4.98022782e-01,  6.77695650e-01,  8.85979189e-01,  1.12454974e+00,
#         1.39508854e+00,  1.69928175e+00,  2.03882045e+00,  2.41540061e+00,
#         2.83072316e+00,  3.28649394e+00,  3.78442374e+00,  4.32622827e+00,
#         4.91362820e+00,  5.54834914e+00,  6.23212165e+00,  6.96668128e+00,
#         7.75376850e+00,  8.59512877e+00,  9.49251254e+00,  1.04476752e+01,
#         1.14623772e+01,  1.25383838e+01,  1.36774655e+01,  1.48813976e+01])

# %%
y
# Out:
# [0.5433,
#  0.5633,
#  0.6051,
#  0.6386,
#  0.6858,
#  0.7437,
#  0.815,
#  0.8617,
#  0.9425,
#  1.0199,
#  1.073303,
#  1.16485,
#  1.27911,
#  1.425376,
#  1.545243,
#  1.684904,
#  1.873412,
#  2.081826,
#  2.351599,
#  2.627334,
#  2.857307,
#  3.207042,
#  3.343789,
#  3.634038,
#  4.037613,
#  4.338979,
#  4.579631,
#  4.855215,
#  5.236438,
#  5.64158,
#  5.963144,
#  6.158129,
#  6.520327,
#  6.858559,
#  7.287236,
#  7.639749,
#  8.073122,
#  8.577554463,
#  9.062818211,
#  9.630664202,
#  10.252345464,
#  10.581821399,
#  10.936419054,
#  11.458243878,
#  12.213729147,
#  13.036640229,
#  13.814611414,
#  14.45185865,
#  14.712844084,
#  14.448933025,
#  14.992052727,
#  15.542581104,
#  16.197007349,
#  16.78484919,
#  17.521746534,
#  18.219297584,
#  18.707188235,
#  19.485393853,
#  20.4941]

# %%
# 绘制多项式回归线
px = np.linspace(X.min(), X.max(), 1000)
px = px.reshape(-1, 1)
pred_py = model.predict(px)

# 绘制图像
mp.figure("美国历年GDP拟合结果", facecolor='lightgray')
mp.title('USA GDP Regression', fontsize=16)
mp.tick_params(labelsize=10)
mp.grid(linestyle=':')
mp.xlabel('x')
mp.ylabel('y')

mp.scatter(X, y, s=60, marker='o', c='dodgerblue', label='Points')
mp.plot(px, pred_py, c='orangered', label='PolyFit Line')
mp.tight_layout()
mp.legend()
mp.show()

# %%
# 中国
y = china_gdp
model = pl.make_pipeline(
    sp.PolynomialFeatures(5),  # 多项式特征拓展器
    lm.LinearRegression()  # 线性回归器
)
# 训练模型
model.fit(X, y)
# 求预测值y
pred_y = model.predict(X)

# %%
# 绘制多项式回归线
px = np.linspace(X.min(), X.max(), 1000)
px = px.reshape(-1, 1)
pred_py = model.predict(px)

# 绘制图像
mp.figure("中国历年GDP拟合结果", facecolor='lightgray')
mp.title('CHN GDP Regression', fontsize=16)
mp.tick_params(labelsize=10)
mp.grid(linestyle=':')
mp.xlabel('x')
mp.ylabel('y')

mp.scatter(X, y, s=60, marker='o', c='dodgerblue', label='Points')
mp.plot(px, pred_py, c='orangered', label='PolyFit Line')
mp.tight_layout()
mp.legend()
mp.show()
