# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.kuaiyilicai.com/stats/global/yearly_per_country/g_population_female_perc/chn.html'
res = requests.get(url).text

# %%
html = BeautifulSoup(res, 'html.parser')

# %%
html.find('tbody').find_all('td')
# Out:
# [<td>2018年</td>,
#  <td>48.68%</td>,
#  <td>2017年</td>,
#  <td>48.67%</td>,
#  <td>2016年</td>,
#  <td>48.65%</td>,
#  <td>2015年</td>,
#  <td>48.64%</td>,
#  <td>2014年</td>,
#  <td>48.63%</td>,
#  <td>2013年</td>,
#  <td>48.62%</td>,
#  <td>2012年</td>,
#  <td>48.62%</td>,
#  <td>2011年</td>,
#  <td>48.61%</td>,
#  <td>2010年</td>,
#  <td>48.61%</td>,
#  <td>2009年</td>,
#  <td>48.61%</td>,
#  <td>2008年</td>,
#  <td>48.62%</td>,
#  <td>2007年</td>,
#  <td>48.62%</td>,
#  <td>2006年</td>,
#  <td>48.63%</td>,
#  <td>2005年</td>,
#  <td>48.64%</td>,
#  <td>2004年</td>,
#  <td>48.65%</td>,
#  <td>2003年</td>,
#  <td>48.66%</td>,
#  <td>2002年</td>,
#  <td>48.67%</td>,
#  <td>2001年</td>,
#  <td>48.68%</td>,
#  <td>2000年</td>,
#  <td>48.69%</td>,
#  <td colspan="2">
#  <div style="text-align: center;">
#  <!-- ky_stats_pc_728_90 -->
#  <ins class="adsbygoogle" data-ad-client="ca-pub-7428758777241086" data-ad-slot="3794219983" style="display:inline-block;width:728px;height:90px"></ins>
#  <script>
# ...

# %%
chinese_data = html.find('tbody').find_all('td')

# %%
i = 0
for d in chinese_data:
    if r"adsbygoogle" in d.text:
        chinese_data.pop(i)
    i += 1
print(chinese_data)
# Out:
# [<td>2018年</td>, <td>48.68%</td>, <td>2017年</td>, <td>48.67%</td>, <td>2016年</td>, <td>48.65%</td>, <td>2015年</td>, <td>48.64%</td>, <td>2014年</td>, <td>48.63%</td>, <td>2013年</td>, <td>48.62%</td>, <td>2012年</td>, <td>48.62%</td>, <td>2011年</td>, <td>48.61%</td>, <td>2010年</td>, <td>48.61%</td>, <td>2009年</td>, <td>48.61%</td>, <td>2008年</td>, <td>48.62%</td>, <td>2007年</td>, <td>48.62%</td>, <td>2006年</td>, <td>48.63%</td>, <td>2005年</td>, <td>48.64%</td>, <td>2004年</td>, <td>48.65%</td>, <td>2003年</td>, <td>48.66%</td>, <td>2002年</td>, <td>48.67%</td>, <td>2001年</td>, <td>48.68%</td>, <td>2000年</td>, <td>48.69%</td>, <td>1999年</td>, <td>48.69%</td>, <td>1998年</td>, <td>48.7%</td>, <td>1997年</td>, <td>48.69%</td>, <td>1996年</td>, <td>48.69%</td>, <td>1995年</td>, <td>48.69%</td>, <td>1994年</td>, <td>48.69%</td>, <td>1993年</td>, <td>48.69%</td>, <td>1992年</td>, <td>48.69%</td>, <td>1991年</td>, <td>48.69%</td>, <td>1990年</td>, <td>48.69%</td>, <td>1989年</td>, <td>48.69%</td>, <td>1988
# ...

# %%
chinese_data
# Out:
# [<td>2018年</td>,
#  <td>48.68%</td>,
#  <td>2017年</td>,
#  <td>48.67%</td>,
#  <td>2016年</td>,
#  <td>48.65%</td>,
#  <td>2015年</td>,
#  <td>48.64%</td>,
#  <td>2014年</td>,
#  <td>48.63%</td>,
#  <td>2013年</td>,
#  <td>48.62%</td>,
#  <td>2012年</td>,
#  <td>48.62%</td>,
#  <td>2011年</td>,
#  <td>48.61%</td>,
#  <td>2010年</td>,
#  <td>48.61%</td>,
#  <td>2009年</td>,
#  <td>48.61%</td>,
#  <td>2008年</td>,
#  <td>48.62%</td>,
#  <td>2007年</td>,
#  <td>48.62%</td>,
#  <td>2006年</td>,
#  <td>48.63%</td>,
#  <td>2005年</td>,
#  <td>48.64%</td>,
#  <td>2004年</td>,
#  <td>48.65%</td>,
#  <td>2003年</td>,
#  <td>48.66%</td>,
#  <td>2002年</td>,
#  <td>48.67%</td>,
#  <td>2001年</td>,
#  <td>48.68%</td>,
#  <td>2000年</td>,
#  <td>48.69%</td>,
#  <td>1999年</td>,
#  <td>48.69%</td>,
#  <td>1998年</td>,
#  <td>48.7%</td>,
#  <td>1997年</td>,
#  <td>48.69%</td>,
#  <td>1996年</td>,
#  <td>48.69%</td>,
#  <td>1995年</td>,
#  <td>48.69%</td>,
#  <td>1994年</td>,
#  <td>48.69%</td>,
#  <td>1993年</td>,
# ...

# %%
year = []
data = []
i = 1
for d in chinese_data:
    if i == 1 or i%2  != 0:
        year.append(d.text)
    else:
        temp = d.text.split('%')
        data.append(temp[0])
    i += 1

# %%
year
# Out:
# ['2018年',
#  '2017年',
#  '2016年',
#  '2015年',
#  '2014年',
#  '2013年',
#  '2012年',
#  '2011年',
#  '2010年',
#  '2009年',
#  '2008年',
#  '2007年',
#  '2006年',
#  '2005年',
#  '2004年',
#  '2003年',
#  '2002年',
#  '2001年',
#  '2000年',
#  '1999年',
#  '1998年',
#  '1997年',
#  '1996年',
#  '1995年',
#  '1994年',
#  '1993年',
#  '1992年',
#  '1991年',
#  '1990年',
#  '1989年',
#  '1988年',
#  '1987年',
#  '1986年',
#  '1985年',
#  '1984年',
#  '1983年',
#  '1982年',
#  '1981年',
#  '1980年',
#  '1979年',
#  '1978年',
#  '1977年',
#  '1976年',
#  '1975年',
#  '1974年',
#  '1973年',
#  '1972年',
#  '1971年',
#  '1970年',
#  '1969年',
#  '1968年',
#  '1967年',
#  '1966年',
#  '1965年',
#  '1964年',
#  '1963年',
#  '1962年',
#  '1961年',
#  '1960年',
#  '1959年']

# %%
data
# Out:
# ['48.68',
#  '48.67',
#  '48.65',
#  '48.64',
#  '48.63',
#  '48.62',
#  '48.62',
#  '48.61',
#  '48.61',
#  '48.61',
#  '48.62',
#  '48.62',
#  '48.63',
#  '48.64',
#  '48.65',
#  '48.66',
#  '48.67',
#  '48.68',
#  '48.69',
#  '48.69',
#  '48.7',
#  '48.69',
#  '48.69',
#  '48.69',
#  '48.69',
#  '48.69',
#  '48.69',
#  '48.69',
#  '48.69',
#  '48.69',
#  '48.69',
#  '48.69',
#  '48.69',
#  '48.69',
#  '48.69',
#  '48.69',
#  '48.68',
#  '48.68',
#  '48.68',
#  '48.68',
#  '48.68',
#  '48.68',
#  '48.68',
#  '48.69',
#  '48.69',
#  '48.69',
#  '48.69',
#  '48.68',
#  '48.68',
#  '48.66',
#  '48.64',
#  '48.62',
#  '48.6',
#  '48.58',
#  '48.55',
#  '48.53',
#  '48.51',
#  '48.48',
#  '48.46',
#  '48.42']

# %%
import pyecharts.options as opts
from pyecharts.charts import Line, Bar
from pyecharts.commons.utils import JsCode

# %%
line = Line()
line.add_xaxis(year)
line.add_yaxis("", data)
line.set_global_opts(
            title_opts=opts.TitleOpts(title="中国女性比例"),
            xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30), is_show=True),
    yaxis_opts=opts.AxisOpts(
                axistick_opts=opts.AxisTickOpts(is_show=False),
                axisline_opts=opts.AxisLineOpts(
                    linestyle_opts=opts.LineStyleOpts(opacity=0)
                ),
                axislabel_opts=opts.LabelOpts(formatter="{value}%"),
        min_=48.3
            ),
    datazoom_opts=opts.DataZoomOpts()
)
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="a6daef14ab4a44e3ba92d66a24f0245e" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_a6daef14ab4a44e3ba92d66a24f0245e = echarts.init(
#             document.getElementById('a6daef14ab4a44e3ba92d66a24f0245e'), 'white', {renderer: 'canvas'});
#         var option_a6daef14ab4a44e3ba92d66a24f0245e = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
# ...

# %%
bar = Bar()
bar.add_xaxis(year)
bar.add_yaxis("", data)
bar.extend_axis(
    yaxis=opts.AxisOpts(
                axislabel_opts=opts.LabelOpts(formatter="{value}"), interval=5
            )
)
bar.set_global_opts(
            title_opts=opts.TitleOpts(title="中国女性比例"),
            xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30), is_show=True),
            yaxis_opts=opts.AxisOpts(
                axistick_opts=opts.AxisTickOpts(is_show=False),
                axisline_opts=opts.AxisLineOpts(
                    linestyle_opts=opts.LineStyleOpts(opacity=0)
                ),
                axislabel_opts=opts.LabelOpts(formatter="{value}%"),
                min_=48.3
            ),
            datazoom_opts=opts.DataZoomOpts()
)
bar.set_series_opts(itemstyle_opts={
            "normal": {
                "color": JsCode("""new echarts.graphic.LinearGradient(0, 0, 0, 1, [{
                    offset: 0,
                    color: 'rgba(0, 244, 255, 1)'
                }, {
                    offset: 1,
                    color: 'rgba(0, 77, 167, 1)'
                }], false)"""),
                "barBorderRadius": [30, 30, 30, 30],
                "shadowColor": 'rgb(0, 160, 221)',
            }})
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="0cb258bc65214f7fbbb4e8cedabfec17" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_0cb258bc65214f7fbbb4e8cedabfec17 = echarts.init(
#             document.getElementById('0cb258bc65214f7fbbb4e8cedabfec17'), 'white', {renderer: 'canvas'});
#         var option_0cb258bc65214f7fbbb4e8cedabfec17 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
# ...

# %%
world_url = 'https://www.kuaiyilicai.com/stats/global/yearly_overview/g_population_female_perc.html'
world_res = requests.get(world_url).text

# %%
world_html = BeautifulSoup(world_res, 'html.parser')

# %%
world_html_data = world_html.find('tbody').find_all('td')

# %%
world_html_data
# Out:
# [<td>1</td>,
#  <td>库拉索</td>,
#  <td>美洲</td>,
#  <td>2018</td>,
#  <td>54.1%</td>,
#  <td>2</td>,
#  <td>拉脱维亚</td>,
#  <td>欧洲</td>,
#  <td>2018</td>,
#  <td>54.01%</td>,
#  <td>3</td>,
#  <td>香港</td>,
#  <td>亚洲</td>,
#  <td>2018</td>,
#  <td>53.93%</td>,
#  <td>4</td>,
#  <td>立陶宛</td>,
#  <td>欧洲</td>,
#  <td>2018</td>,
#  <td>53.79%</td>,
#  <td>5</td>,
#  <td>乌克兰</td>,
#  <td>欧洲</td>,
#  <td>2018</td>,
#  <td>53.69%</td>,
#  <td>6</td>,
#  <td>俄罗斯</td>,
#  <td>欧洲</td>,
#  <td>2018</td>,
#  <td>53.66%</td>,
#  <td>7</td>,
#  <td>白俄罗斯</td>,
#  <td>欧洲</td>,
#  <td>2018</td>,
#  <td>53.46%</td>,
#  <td>8</td>,
#  <td>萨尔瓦多</td>,
#  <td>美洲</td>,
#  <td>2018</td>,
#  <td>53.11%</td>,
#  <td>9</td>,
#  <td>亚美尼亚</td>,
#  <td>亚洲</td>,
#  <td>2018</td>,
#  <td>52.96%</td>,
#  <td>10</td>,
#  <td>爱沙尼亚</td>,
#  <td>欧洲</td>,
#  <td>2018</td>,
#  <td>52.86%</td>,
#  <td>11</td>,
#  <td>葡萄牙</td>,
#  <td>欧洲</td>,
#  <td>2018</td>,
#  <td>52.71%</td>,
#  <td>12</td>,
#  <td>阿鲁巴</td>,
#  <td>美洲</td>,
# ...

# %%
i = 0
for d in world_html_data:
    if r"adsbygoogle" in d.text:
        world_html_data.pop(i)
    i += 1
print(world_html_data)
# Out:
# [<td>1</td>, <td>库拉索</td>, <td>美洲</td>, <td>2018</td>, <td>54.1%</td>, <td>2</td>, <td>拉脱维亚</td>, <td>欧洲</td>, <td>2018</td>, <td>54.01%</td>, <td>3</td>, <td>香港</td>, <td>亚洲</td>, <td>2018</td>, <td>53.93%</td>, <td>4</td>, <td>立陶宛</td>, <td>欧洲</td>, <td>2018</td>, <td>53.79%</td>, <td>5</td>, <td>乌克兰</td>, <td>欧洲</td>, <td>2018</td>, <td>53.69%</td>, <td>6</td>, <td>俄罗斯</td>, <td>欧洲</td>, <td>2018</td>, <td>53.66%</td>, <td>7</td>, <td>白俄罗斯</td>, <td>欧洲</td>, <td>2018</td>, <td>53.46%</td>, <td>8</td>, <td>萨尔瓦多</td>, <td>美洲</td>, <td>2018</td>, <td>53.11%</td>, <td>9</td>, <td>亚美尼亚</td>, <td>亚洲</td>, <td>2018</td>, <td>52.96%</td>, <td>10</td>, <td>爱沙尼亚</td>, <td>欧洲</td>, <td>2018</td>, <td>52.86%</td>, <td>11</td>, <td>葡萄牙</td>, <td>欧洲</td>, <td>2018</td>, <td>52.71%</td>, <td>12</td>, <td>阿鲁巴</td>, <td>美洲</td>, <td>2018</td>, <td>52.53%</td>, <td>13</td>, <td>波多黎各</td>, <td>美洲</td>, <td>2018</td>, <td>52.45%</td>, <td>14</td>, <td>匈牙利</td>, <td>欧洲</td>, <td>2018</td>, <td>52.43%<
# ...

# %%
world_year = []
world_country = []
world_continent = []
world_data = []
i = 1
for d in world_html_data:
    if i == 5:
        temp = d.text.split('%')
        world_data.append(temp[0])
        i = 0
        pass
    elif i / 2 == 1:
        world_country.append(d.text)
    elif i % 2 == 1 and i // 2 == 1:
        world_continent.append(d.text)
    i += 1

# %%
world_continent
# Out:
# ['美洲',
#  '欧洲',
#  '亚洲',
#  '欧洲',
#  '欧洲',
#  '欧洲',
#  '欧洲',
#  '美洲',
#  '亚洲',
#  '欧洲',
#  '欧洲',
#  '美洲',
#  '美洲',
#  '欧洲',
#  '非洲',
#  '亚洲',
#  '欧洲',
#  '亚洲',
#  '亚洲',
#  '欧洲',
#  '非洲',
#  '亚洲',
#  '美洲',
#  '非洲',
#  '美洲',
#  '美洲',
#  '欧洲',
#  '非洲',
#  '欧洲',
#  '亚洲',
#  '非洲',
#  '亚洲',
#  '美洲',
#  '欧洲',
#  '欧洲',
#  '欧洲',
#  '欧洲',
#  '非洲',
#  '亚洲',
#  '美洲',
#  '亚洲',
#  '非洲',
#  '亚洲',
#  '非洲',
#  '亚洲',
#  '美洲',
#  '欧洲',
#  '欧洲',
#  '美洲',
#  '欧洲',
#  '欧洲',
#  '非洲',
#  '大洋洲',
#  '大洋洲',
#  '美洲',
#  '欧洲',
#  '欧洲',
#  '非洲',
#  '亚洲',
#  '美洲',
#  '美洲',
#  '美洲',
#  '欧洲',
#  '非洲',
#  '美洲',
#  '非洲',
#  '非洲',
#  '欧洲',
#  '亚洲',
#  '欧洲',
#  '美洲',
#  '欧洲',
#  '美洲',
#  '欧洲',
#  '美洲',
#  '亚洲',
#  '非洲',
#  '欧洲',
#  '非洲',
#  '亚洲',
#  '美洲',
#  '非洲',
#  '非洲',
#  '非洲',
#  '欧洲',
#  '欧洲',
#  '非洲',
#  '非洲',
#  '非洲',
#  '美洲',
#  '美洲',
#  '美洲',
#  '美洲',
#  '非洲',
#  '亚洲',
#  '欧洲',
#  '非洲',
#  '欧洲',
#  '欧洲',
#  '大洋洲',
#  '美洲',
#  '亚洲',
#  '非洲',
#  '非洲',
#  '非洲',
#  '亚洲',
#  '非洲',
#  '非洲',
#  '亚洲',
#  '非洲',
# ...

# %%
world_country
# Out:
# ['库拉索',
#  '拉脱维亚',
#  '香港',
#  '立陶宛',
#  '乌克兰',
#  '俄罗斯',
#  '白俄罗斯',
#  '萨尔瓦多',
#  '亚美尼亚',
#  '爱沙尼亚',
#  '葡萄牙',
#  '阿鲁巴',
#  '波多黎各',
#  '匈牙利',
#  '津巴布韦',
#  '格鲁吉亚',
#  '摩尔多瓦',
#  '澳门',
#  '斯里兰卡',
#  '克罗地亚',
#  '几内亚',
#  '缅甸',
#  '安提瓜和巴布达',
#  '博茨瓦纳',
#  '乌拉圭',
#  '巴巴多斯',
#  '法国',
#  '纳米比亚',
#  '波兰',
#  '哈萨克斯坦',
#  '莫桑比克',
#  '尼泊尔',
#  '巴哈马',
#  '保加利亚',
#  '意大利',
#  '罗马尼亚',
#  '斯洛伐克',
#  '塞内加尔',
#  '泰国',
#  '阿根廷',
#  '柬埔寨',
#  '几内亚比绍',
#  '日本',
#  '斯威士兰',
#  '朝鲜',
#  '墨西哥',
#  '波黑',
#  '塞尔维亚',
#  '哥伦比亚',
#  '希腊',
#  '西班牙',
#  '卢旺达',
#  '基里巴斯',
#  '新西兰',
#  '巴西',
#  '奥地利',
#  '捷克',
#  '乌干达',
#  '土库曼斯坦',
#  '危地马拉',
#  '圣卢西亚',
#  '智利',
#  '芬兰',
#  '莱索托',
#  '尼加拉瓜',
#  '马拉维',
#  '南非',
#  '土耳其',
#  '蒙古',
#  '德国',
#  '海地',
#  '英国',
#  '委内瑞拉',
#  '比利时',
#  '特立尼达和多巴哥',
#  '新加坡',
#  '毛里求斯',
#  '黑山',
#  '安哥拉',
#  '吉尔吉斯斯坦',
#  '美国',
#  '赞比亚',
#  '突尼斯',
#  '中非',
#  '瑞士',
#  '爱尔兰',
#  '布隆迪',
#  '摩洛哥',
#  '冈比亚',
#  '加拿大',
#  '牙买加',
#  '秘鲁',
#  '古巴',
#  '肯尼亚',
#  '以色列',
#  '丹麦',
#  '多哥',
# ...

# %%
world_data
# Out:
# ['54.1',
#  '54.01',
#  '53.93',
#  '53.79',
#  '53.69',
#  '53.66',
#  '53.46',
#  '53.11',
#  '52.96',
#  '52.86',
#  '52.71',
#  '52.53',
#  '52.45',
#  '52.43',
#  '52.36',
#  '52.29',
#  '52.04',
#  '51.98',
#  '51.97',
#  '51.85',
#  '51.82',
#  '51.81',
#  '51.79',
#  '51.73',
#  '51.72',
#  '51.67',
#  '51.58',
#  '51.55',
#  '51.53',
#  '51.51',
#  '51.48',
#  '51.43',
#  '51.43',
#  '51.41',
#  '51.38',
#  '51.34',
#  '51.34',
#  '51.28',
#  '51.27',
#  '51.24',
#  '51.2',
#  '51.17',
#  '51.16',
#  '51.15',
#  '51.09',
#  '51.09',
#  '51.01',
#  '51.0',
#  '50.93',
#  '50.92',
#  '50.9',
#  '50.86',
#  '50.85',
#  '50.84',
#  '50.83',
#  '50.83',
#  '50.81',
#  '50.78',
#  '50.76',
#  '50.76',
#  '50.75',
#  '50.73',
#  '50.72',
#  '50.72',
#  '50.71',
#  '50.7',
#  '50.69',
#  '50.68',
#  '50.67',
#  '50.66',
#  '50.65',
#  '50.64',
#  '50.63',
#  '50.59',
#  '50.59',
#  '50.59',
#  '50.58',
#  '50.56',
#  '50.53',
#  '50.52',
#  '50.52',
#  '50.49',
#  '50.44',
# ...

# %%
bar = Bar()
bar.add_xaxis(world_country[:10])
bar.add_yaxis("", world_data[:10])
bar.extend_axis(
    yaxis=opts.AxisOpts(
                axislabel_opts=opts.LabelOpts(formatter="{value}"), interval=5
            )
)
bar.set_global_opts(
            title_opts=opts.TitleOpts(title="世界范围女性比例"),
            xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30), is_show=True),
            yaxis_opts=opts.AxisOpts(
                axistick_opts=opts.AxisTickOpts(is_show=False),
                axisline_opts=opts.AxisLineOpts(
                    linestyle_opts=opts.LineStyleOpts(opacity=0)
                ),
                axislabel_opts=opts.LabelOpts(formatter="{value}%"),
                min_=48.3
            ),
            # datazoom_opts=opts.DataZoomOpts()
)
bar.set_series_opts(itemstyle_opts={
            "normal": {
                "color": JsCode("""new echarts.graphic.LinearGradient(0, 0, 0, 1, [{
                    offset: 0,
                    color: 'rgba(0, 244, 255, 1)'
                }, {
                    offset: 1,
                    color: 'rgba(0, 77, 167, 1)'
                }], false)"""),
                "barBorderRadius": [30, 30, 30, 30],
                "shadowColor": 'rgb(0, 160, 221)',
            }})
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="d7c2e42350dd4ca887a1e72b54de69b5" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_d7c2e42350dd4ca887a1e72b54de69b5 = echarts.init(
#             document.getElementById('d7c2e42350dd4ca887a1e72b54de69b5'), 'white', {renderer: 'canvas'});
#         var option_d7c2e42350dd4ca887a1e72b54de69b5 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
# ...

# %%
bar = Bar()
bar.add_xaxis(world_country[-11:])
bar.add_yaxis("", world_data[-11:])
bar.extend_axis(
    yaxis=opts.AxisOpts(
                axislabel_opts=opts.LabelOpts(formatter="{value}"), interval=5
            )
)
bar.set_global_opts(
            title_opts=opts.TitleOpts(title="2018世界范围女性比例后十"),
            xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30), is_show=True),
            yaxis_opts=opts.AxisOpts(
                axistick_opts=opts.AxisTickOpts(is_show=False),
                axisline_opts=opts.AxisLineOpts(
                    linestyle_opts=opts.LineStyleOpts(opacity=0)
                ),
                axislabel_opts=opts.LabelOpts(formatter="{value}%")
            ),
            # datazoom_opts=opts.DataZoomOpts()
)
bar.set_series_opts(itemstyle_opts={
            "normal": {
                "color": JsCode("""new echarts.graphic.LinearGradient(0, 0, 0, 1, [{
                    offset: 0,
                    color: 'rgba(246,203,144)'
                }, {
                    offset: 1,
                    color: 'rgba(255,100,97,.5)'
                }], false)"""),
                "barBorderRadius": [30, 30, 30, 30],
                "shadowColor": 'rgb(238,44,44)', # 238,44,44,255,100,97
            }})
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="f9789ca3a0f448128ed51fd0ceafa766" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_f9789ca3a0f448128ed51fd0ceafa766 = echarts.init(
#             document.getElementById('f9789ca3a0f448128ed51fd0ceafa766'), 'white', {renderer: 'canvas'});
#         var option_f9789ca3a0f448128ed51fd0ceafa766 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
# ...

# %%
url = 'https://www.kuaiyilicai.com/stats/global/yearly_per_country/g_population_sex_ratio_at_birth/chn.html'
china_res = requests.get(url).text
china_html = BeautifulSoup(china_res, 'html.parser')
china_html_data = china_html.find('tbody').find_all('td')

# %%
i = 0
for d in china_html_data:
    if r"adsbygoogle" in d.text:
        china_html_data.pop(i)
    i += 1
print(china_html_data)
# Out:
# [<td>2017年</td>, <td>1.13</td>, <td>2016年</td>, <td>1.13</td>, <td>2015年</td>, <td>1.14</td>, <td>2014年</td>, <td>1.14</td>, <td>2013年</td>, <td>1.15</td>, <td>2012年</td>, <td>1.15</td>, <td>2011年</td>, <td>1.15</td>, <td>2010年</td>, <td>1.16</td>, <td>2009年</td>, <td>1.16</td>, <td>2008年</td>, <td>1.17</td>, <td>2007年</td>, <td>1.17</td>, <td>2002年</td>, <td>1.16</td>, <td>1997年</td>, <td>1.14</td>, <td>1992年</td>, <td>1.12</td>, <td>1990年</td>, <td>1.1</td>, <td>1987年</td>, <td>1.08</td>, <td>1982年</td>, <td>1.07</td>, <td>1977年</td>, <td>1.07</td>, <td>1972年</td>, <td>1.07</td>, <td>1967年</td>, <td>1.07</td>, <td>1962年</td>, <td>1.07</td>]

# %%
china_html_data
# Out:
# [<td>2017年</td>,
#  <td>1.13</td>,
#  <td>2016年</td>,
#  <td>1.13</td>,
#  <td>2015年</td>,
#  <td>1.14</td>,
#  <td>2014年</td>,
#  <td>1.14</td>,
#  <td>2013年</td>,
#  <td>1.15</td>,
#  <td>2012年</td>,
#  <td>1.15</td>,
#  <td>2011年</td>,
#  <td>1.15</td>,
#  <td>2010年</td>,
#  <td>1.16</td>,
#  <td>2009年</td>,
#  <td>1.16</td>,
#  <td>2008年</td>,
#  <td>1.17</td>,
#  <td>2007年</td>,
#  <td>1.17</td>,
#  <td>2002年</td>,
#  <td>1.16</td>,
#  <td>1997年</td>,
#  <td>1.14</td>,
#  <td>1992年</td>,
#  <td>1.12</td>,
#  <td>1990年</td>,
#  <td>1.1</td>,
#  <td>1987年</td>,
#  <td>1.08</td>,
#  <td>1982年</td>,
#  <td>1.07</td>,
#  <td>1977年</td>,
#  <td>1.07</td>,
#  <td>1972年</td>,
#  <td>1.07</td>,
#  <td>1967年</td>,
#  <td>1.07</td>,
#  <td>1962年</td>,
#  <td>1.07</td>]

# %%
china_year = []
china_data = []
i = 1
for d in china_html_data:
    if i == 1 or i%2  != 0:
        china_year.append(d.text)
    else:
        temp = d.text.split('%')
        china_data.append(temp[0])
    i += 1

# %%
china_data
# Out:
# ['1.13',
#  '1.13',
#  '1.14',
#  '1.14',
#  '1.15',
#  '1.15',
#  '1.15',
#  '1.16',
#  '1.16',
#  '1.17',
#  '1.17',
#  '1.16',
#  '1.14',
#  '1.12',
#  '1.1',
#  '1.08',
#  '1.07',
#  '1.07',
#  '1.07',
#  '1.07',
#  '1.07']

# %%
line = Line()
line.add_xaxis(china_year)
line.add_yaxis("", china_data)
line.set_global_opts(
            title_opts=opts.TitleOpts(title="中国出生性别比例"),
            xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30), is_show=True),
    yaxis_opts=opts.AxisOpts(
                axistick_opts=opts.AxisTickOpts(is_show=False),
                axisline_opts=opts.AxisLineOpts(
                    linestyle_opts=opts.LineStyleOpts(opacity=0)
                ),
                axislabel_opts=opts.LabelOpts(formatter="{value}"),
        min_=1
            ),
    datazoom_opts=opts.DataZoomOpts()
)
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="59c974e6a7844c67aad22226c0a563de" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_59c974e6a7844c67aad22226c0a563de = echarts.init(
#             document.getElementById('59c974e6a7844c67aad22226c0a563de'), 'white', {renderer: 'canvas'});
#         var option_59c974e6a7844c67aad22226c0a563de = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
# ...

# %%
url = 'https://www.kuaiyilicai.com/stats/global/yearly_overview/g_population_sex_ratio_at_birth.html'
world_ratio_res = requests.get(url).text
world_ratio_html = BeautifulSoup(world_ratio_res, 'html.parser')
world_ratio_html_data = world_ratio_html.find('tbody').find_all('td')

# %%
i = 0
for d in world_ratio_html_data:
    if r"adsbygoogle" in d.text:
        world_ratio_html_data.pop(i)
    i += 1
print(china_html_data)
# Out:
# [<td>2017年</td>, <td>1.13</td>, <td>2016年</td>, <td>1.13</td>, <td>2015年</td>, <td>1.14</td>, <td>2014年</td>, <td>1.14</td>, <td>2013年</td>, <td>1.15</td>, <td>2012年</td>, <td>1.15</td>, <td>2011年</td>, <td>1.15</td>, <td>2010年</td>, <td>1.16</td>, <td>2009年</td>, <td>1.16</td>, <td>2008年</td>, <td>1.17</td>, <td>2007年</td>, <td>1.17</td>, <td>2002年</td>, <td>1.16</td>, <td>1997年</td>, <td>1.14</td>, <td>1992年</td>, <td>1.12</td>, <td>1990年</td>, <td>1.1</td>, <td>1987年</td>, <td>1.08</td>, <td>1982年</td>, <td>1.07</td>, <td>1977年</td>, <td>1.07</td>, <td>1972年</td>, <td>1.07</td>, <td>1967年</td>, <td>1.07</td>, <td>1962年</td>, <td>1.07</td>]

# %%
world_ratio_html_data
# Out:
# [<td>1</td>,
#  <td>中国</td>,
#  <td>亚洲</td>,
#  <td>2017</td>,
#  <td>1.13</td>,
#  <td>2</td>,
#  <td>阿塞拜疆</td>,
#  <td>亚洲</td>,
#  <td>2017</td>,
#  <td>1.13</td>,
#  <td>3</td>,
#  <td>越南</td>,
#  <td>亚洲</td>,
#  <td>2017</td>,
#  <td>1.12</td>,
#  <td>4</td>,
#  <td>亚美尼亚</td>,
#  <td>亚洲</td>,
#  <td>2017</td>,
#  <td>1.11</td>,
#  <td>5</td>,
#  <td>印度</td>,
#  <td>亚洲</td>,
#  <td>2017</td>,
#  <td>1.1</td>,
#  <td>6</td>,
#  <td>巴基斯坦</td>,
#  <td>亚洲</td>,
#  <td>2017</td>,
#  <td>1.09</td>,
#  <td>7</td>,
#  <td>阿尔巴尼亚</td>,
#  <td>欧洲</td>,
#  <td>2017</td>,
#  <td>1.09</td>,
#  <td>8</td>,
#  <td>苏里南</td>,
#  <td>美洲</td>,
#  <td>2017</td>,
#  <td>1.08</td>,
#  <td>9</td>,
#  <td>萨摩亚</td>,
#  <td>大洋洲</td>,
#  <td>2017</td>,
#  <td>1.08</td>,
#  <td>10</td>,
#  <td>巴布亚新几内亚</td>,
#  <td>大洋洲</td>,
#  <td>2017</td>,
#  <td>1.08</td>,
#  <td>11</td>,
#  <td>香港</td>,
#  <td>亚洲</td>,
#  <td>2017</td>,
#  <td>1.08</td>,
#  <td>12</td>,
#  <td>黑山</td>,
#  <td>欧洲</td>,
#  <td>2017</td>,
# ...

# %%
world_ratio_year = []
world_ratio_country = []
world_ratio_continent = []
world_ratio_data = []
i = 1
for d in world_ratio_html_data:
    if i == 5:
        temp = d.text.split('%')
        world_ratio_data.append(temp[0])
        i = 0
        pass
    elif i / 2 == 1:
        world_ratio_country.append(d.text)
    elif i % 2 == 1 and i // 2 == 1:
        world_ratio_continent.append(d.text)
    i += 1

# %%
world_ratio_country
# Out:
# ['中国',
#  '阿塞拜疆',
#  '越南',
#  '亚美尼亚',
#  '印度',
#  '巴基斯坦',
#  '阿尔巴尼亚',
#  '苏里南',
#  '萨摩亚',
#  '巴布亚新几内亚',
#  '香港',
#  '黑山',
#  '塞尔维亚',
#  '新加坡',
#  '马尔代夫',
#  '塞浦路斯',
#  '爱沙尼亚',
#  '哈萨克斯坦',
#  '拉脱维亚',
#  '尼泊尔',
#  '格鲁吉亚',
#  '希腊',
#  '塔吉克斯坦',
#  '瓦努阿图',
#  '波黑',
#  '伊拉克',
#  '所罗门群岛',
#  '马其顿',
#  '西班牙',
#  '白俄罗斯',
#  '意大利',
#  '泰国',
#  '乌克兰',
#  '乌兹别克斯坦',
#  '克罗地亚',
#  '埃及',
#  '保加利亚',
#  '利比亚',
#  '马来西亚',
#  '塞舌尔',
#  '菲律宾',
#  '基里巴斯',
#  '马耳他',
#  '摩洛哥',
#  '阿富汗',
#  '斐济群岛',
#  '密克罗尼西亚联邦',
#  '葡萄牙',
#  '立陶宛',
#  '瑞典',
#  '爱尔兰',
#  '尼日利亚',
#  '匈牙利',
#  '俄罗斯',
#  '罗马尼亚',
#  '关岛',
#  '挪威',
#  '捷克',
#  '摩尔多瓦',
#  '吉尔吉斯斯坦',
#  '斯洛文尼亚',
#  '巴哈马',
#  '古巴',
#  '丹麦',
#  '波兰',
#  '日本',
#  '澳大利亚',
#  '奥地利',
#  '文莱',
#  '突尼斯',
#  '韩国',
#  '新西兰',
#  '约旦',
#  '利比里亚',
#  '加纳',
#  '波多黎各',
#  '荷兰',
#  '以色列',
#  '冰岛',
#  '加拿大',
#  '瑞士',
#  '德国',
#  '厄立特里亚',
#  '伊朗',
#  '英国',
#  '阿尔及利亚',
#  '尼日尔',
#  '玻利维亚',
#  '朝鲜',
#  '巴勒斯坦',
#  '巴拉圭',
#  '黎巴嫩',
#  '毛里塔尼亚',
#  '牙买加',
#  '乌拉圭',
#  '老挝',
#  '也门',
# ...

# %%
bar = Bar()
bar.add_xaxis(world_ratio_country[:10])
bar.add_yaxis("", world_ratio_data[:10])
bar.extend_axis(
    yaxis=opts.AxisOpts(
                axislabel_opts=opts.LabelOpts(formatter="{value}"), interval=5
            )
)
bar.set_global_opts(
            title_opts=opts.TitleOpts(title="2017世界范围出生性别比例"),
            xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30), is_show=True),
            yaxis_opts=opts.AxisOpts(
                axistick_opts=opts.AxisTickOpts(is_show=False),
                axisline_opts=opts.AxisLineOpts(
                    linestyle_opts=opts.LineStyleOpts(opacity=0)
                ),
                axislabel_opts=opts.LabelOpts(formatter="{value}")
            ),
            # datazoom_opts=opts.DataZoomOpts()
)
# 195,90,175,.6,#FF00FF(255,0,255),#FF3E96(255,62,150,1),#FF69B4(255,105,180,1)

bar.set_series_opts(itemstyle_opts={
            "normal": {
                "color": JsCode("""new echarts.graphic.LinearGradient(0, 0, 0, 1, [{
                    offset: 0,
                    color: 'rgba(255,105,180,1)'
                }, {
                    offset: 1,
                    color: 'rgba(255,62,150,1)'
                }], false)"""),
                "barBorderRadius": [30, 30, 30, 30],
                "shadowColor": 'rgb(255,0,255)',
            }})
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="4ee6aaf4d15d4e9e891d27129165cc1f" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_4ee6aaf4d15d4e9e891d27129165cc1f = echarts.init(
#             document.getElementById('4ee6aaf4d15d4e9e891d27129165cc1f'), 'white', {renderer: 'canvas'});
#         var option_4ee6aaf4d15d4e9e891d27129165cc1f = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
# ...

# %%
bar = Bar(init_opts=opts.InitOpts(
                bg_color={
                    "type": "pattern",
                    "image": JsCode("img"),
                    "repeat": "no-repeat",
                }
            ))
bar.add_xaxis(world_ratio_country[-11:])
bar.add_yaxis("", world_ratio_data[-11:])
bar.extend_axis(
    yaxis=opts.AxisOpts(
                axislabel_opts=opts.LabelOpts(formatter="{value}"), interval=5
            )
)
bar.set_global_opts(
            title_opts=opts.TitleOpts(title="2017世界范围出生性别比例后十"),
            xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30), is_show=True),
            yaxis_opts=opts.AxisOpts(
                axistick_opts=opts.AxisTickOpts(is_show=False),
                axisline_opts=opts.AxisLineOpts(
                    linestyle_opts=opts.LineStyleOpts(opacity=0)
                ),
                axislabel_opts=opts.LabelOpts(formatter="{value}")
            ),
            # datazoom_opts=opts.DataZoomOpts()
)
bar.set_series_opts(itemstyle_opts={
            "normal": {
                "color": JsCode("""new echarts.graphic.LinearGradient(0, 0, 0, 1, [{
                    offset: 0,
                    color: 'rgba(246,203,144)'
                }, {
                    offset: 1,
                    color: 'rgba(255,100,97,.5)'
                }], false)"""),
                "barBorderRadius": [30, 30, 30, 30],
                "shadowColor": 'rgb(238,44,44)', # 238,44,44,255,100,97
            }})
bar.add_js_funcs(
        """
        var img = new Image(); img.src = 'luobo.jpg';
        """
    )
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="d457dedadd20446485f96ccc1745e61b" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_d457dedadd20446485f96ccc1745e61b = echarts.init(
#             document.getElementById('d457dedadd20446485f96ccc1745e61b'), 'white', {renderer: 'canvas'});
#
#         var img = new Image(); img.src = 'luobo.jpg';
#
#         var option_d457dedadd20446485f96ccc1745e61b = {
#     "backgroundColor": {
#         "type": "pattern",
#         "image": img,
#         "repeat": "no-repeat"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
# ...
