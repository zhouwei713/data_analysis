# %%
import requests

# %%
headers = {'accept': 'application/json, text/plain, */*',
          'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 11_0_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.96 Safari/537.36'}

# %%
querystring = {"positionId":"100109","industryId":"0","cityId":"0","companySize":"0","financingStage":"0","experienceCode":"0"}

# %%
job_statics_url = 'https://www.zhipin.com/wapi/zpboss/h5/marketpay/statistics.json'

# %%
job_statics_data = requests.get(job_statics_url, params=querystring, headers=headers)

# %%
job_statics_data.json()
# Out:
# {'code': 0,
#  'message': 'Success',
#  'zpData': {'positionId': 100109,
#   'industryId': 0,
#   'cityId': 0,
#   'companySize': 0,
#   'financingStage': 0,
#   'experienceCode': 0,
#   'sampleCount': 1118748,
#   'sampleInsufficient': False,
#   'salaryByMonth': [{'year': '2020年',
#     'showYear': True,
#     'month': '2月',
#     'monthAveSalary': 8625,
#     'title': 'Feb',
#     'grow': True,
#     'percent': 2.13,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0},
#    {'year': '2020年',
#     'showYear': False,
#     'month': '3月',
#     'monthAveSalary': 8279,
#     'title': 'Mar',
#     'grow': False,
#     'percent': 4.01,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0},
#    {'year': '2020年',
#     'showYear': False,
#     'month': '4月',
#     'monthAveSalary': 8075,
#     'title': 'Apr',
#     'grow': False,
#     'percent': 2.46,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0},
#    {'year': '2020年',
#     'showYear': False,
#     'month': '5月',
#     'monthAveSalary': 7835,
#     'title': 'May',
#     'grow': False,
#     'percent': 2.97,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0},
#    {'year': '2020年',
#     'showYear': False,
#     'month': '6月',
#     'monthAveSalary': 7862,
#     'title': 'Jun',
#     'grow': True,
#     'percent': 0.34,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0},
#    {'year': '2020年',
#     'showYear': False,
#     'month': '7月',
#     'monthAveSalary': 7863,
#     'title': 'Jul',
#     'grow': True,
#     'percent': 0.01,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0},
#    {'year': '2020年',
#     'showYear': False,
#     'month': '8月',
#     'monthAveSalary': 8035,
#     'title': 'Aug',
#     'grow': True,
#     'percent': 2.19,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0},
#    {'year': '2020年',
#     'showYear': False,
#     'month': '9月',
#     'monthAveSalary': 8078,
#     'title': 'Sept',
#     'grow': True,
#     'percent': 0.54,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0},
#    {'year': '2020年',
#     'showYear': False,
#     'month': '10月',
#     'monthAveSalary': 8111,
#     'title': 'Oct',
#     'grow': True,
#     'percent': 0.41,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0},
#    {'year': '2020年',
#     'showYear': False,
#     'month': '11月',
#     'monthAveSalary': 8244,
#     'title': 'Nov',
#     'grow': True,
#     'percent': 1.64,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0},
#    {'year': '2020年',
#     'showYear': False,
#     'month': '12月',
#     'monthAveSalary': 7978,
#     'title': 'Dec',
#     'grow': False,
#     'percent': 3.23,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0},
#    {'year': '2021年',
#     'showYear': True,
#     'month': '1月',
#     'monthAveSalary': 8124,
#     'title': 'Jan',
#     'grow': True,
#     'percent': 1.83,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0}],
#   'salaryByAge': [{'ageRange': '24岁以下',
#     'percent': 44,
#     'people': 490609,
#     'percentDecimal': 0.438534,
#     'index': 0},
#    {'ageRange': '25岁-29岁',
#     'percent': 48,
#     'people': 534542,
#     'percentDecimal': 0.477804,
#     'index': 1},
#    {'ageRange': '30岁-34岁',
#     'percent': 7,
#     'people': 76567,
#     'percentDecimal': 0.06844,
#     'index': 2},
#    {'ageRange': '35岁-39岁',
#     'percent': 1,
#     'people': 13284,
#     'percentDecimal': 0.011874,
#     'index': 3},
#    {'ageRange': '40岁-44岁',
#     'percent': 0,
#     'people': 2635,
#     'percentDecimal': 0.002355,
#     'index': 4},
#    {'ageRange': '45岁以上',
#     'percent': 0,
#     'people': 1111,
#     'percentDecimal': 0.000993,
#     'index': 5}],
#   'salaryByWorkExp': [{'percent': 3,
#     'aveSalary': 5741,
#     'workExp': '1年以内',
#     'percentDecimal': 0.027469,
#     'index': 0},
#    {'percent': 55,
#     'aveSalary': 7760,
#     'workExp': '1-3年',
#     'percentDecimal': 0.555199,
#     'index': 1},
#    {'percent': 37,
#     'aveSalary': 9880,
#     'workExp': '3-5年',
#     'percentDecimal': 0.371255,
#     'index': 2},
#    {'percent': 5,
#     'aveSalary': 12091,
#     'workExp': '5-10年',
#     'percentDecimal': 0.045421,
#     'index': 3},
#    {'percent': 0,
#     'aveSalary': 13682,
#     'workExp': '10年以上',
#     'percentDecimal': 0.000656,
#     'index': 4}],
#   'salaryByDistributed': [{'salaryRange': '<7.30',
#     'percent': 24,
#     'people': 0,
#     'percentDecimal': 0.243782,
#     'index': 0},
#    {'salaryRange': '7.30-9.97',
#     'percent': 26,
#     'people': 0,
#     'percentDecimal': 0.262135,
#     'index': 1},
#    {'salaryRange': '9.97-12.63',
#     'percent': 21,
#     'people': 0,
#     'percentDecimal': 0.210872,
#     'index': 2},
#    {'salaryRange': '12.63-15.29',
#     'percent': 13,
#     'people': 0,
#     'percentDecimal': 0.127151,
#     'index': 3},
#    {'salaryRange': '>15.29',
#     'percent': 16,
#     'people': 0,
#     'percentDecimal': 0.155099,
#     'index': 4}],
#   'salaryByPoints': [{'name': '10分位',
#     'title': '低端',
#     'salary': 59699,
#     'point': 10},
#    {'name': '25分位', 'title': '中低端', 'salary': 75803, 'point': 25},
#    {'name': '50分位', 'title': '中端', 'salary': 98774, 'point': 50},
#    {'name': '75分位', 'title': '中高端', 'salary': 129443, 'point': 75},
#    {'name': '90分位', 'title': '高端', 'salary': 166268, 'point': 90}],
#   'salaryByCity': [{'provinceId': 101010000,
#     'provinceAveMonthSalary': 13434,
#     'provinceName': '北京',
#     'cityList': [{'cityId': 101010100,
#       'cityName': '北京',
#       'cityAveMonthSalary': 13434}]},
#    {'provinceId': 101020000,
#     'provinceAveMonthSalary': 12574,
#     'provinceName': '上海',
#     'cityList': [{'cityId': 101020100,
#       'cityName': '上海',
#       'cityAveMonthSalary': 12574}]},
#    {'provinceId': 101030000,
#     'provinceAveMonthSalary': 8111,
#     'provinceName': '天津',
#     'cityList': [{'cityId': 101030100,
#       'cityName': '天津',
#       'cityAveMonthSalary': 8111}]},
#    {'provinceId': 101040000,
#     'provinceAveMonthSalary': 7695,
#     'provinceName': '重庆',
#     'cityList': [{'cityId': 101040100,
#       'cityName': '重庆',
#       'cityAveMonthSalary': 7695}]},
#    {'provinceId': 101050000,
#     'provinceAveMonthSalary': 6721,
#     'provinceName': '黑龙江',
#     'cityList': [{'cityId': 101050100,
#       'cityName': '哈尔滨',
#       'cityAveMonthSalary': 6721}]},
#    {'provinceId': 101060000,
#     'provinceAveMonthSalary': 6567,
#     'provinceName': '吉林',
#     'cityList': [{'cityId': 101060100,
#       'cityName': '长春',
#       'cityAveMonthSalary': 6567}]},
#    {'provinceId': 101070000,
#     'provinceAveMonthSalary': 7655,
#     'provinceName': '辽宁',
#     'cityList': [{'cityId': 101070100,
#       'cityName': '沈阳',
#       'cityAveMonthSalary': 7173},
#      {'cityId': 101070200, 'cityName': '大连', 'cityAveMonthSalary': 8137}]},
#    {'provinceId': 101090000,
#     'provinceAveMonthSalary': 7224,
#     'provinceName': '河北',
#     'cityList': [{'cityId': 101090100,
#       'cityName': '石家庄',
#       'cityAveMonthSalary': 6830},
#      {'cityId': 101090200, 'cityName': '保定', 'cityAveMonthSalary': 6721},
#      {'cityId': 101090600, 'cityName': '廊坊', 'cityAveMonthSalary': 8122}]},
#    {'provinceId': 101100000,
#     'provinceAveMonthSalary': 6295,
#     'provinceName': '山西',
#     'cityList': [{'cityId': 101100100,
#       'cityName': '太原',
#       'cityAveMonthSalary': 6295}]},
#    {'provinceId': 101110000,
#     'provinceAveMonthSalary': 10116,
#     'provinceName': '陕西',
#     'cityList': [{'cityId': 101110100,
#       'cityName': '西安',
#       'cityAveMonthSalary': 10116}]},
#    {'provinceId': 101120000,
#     'provinceAveMonthSalary': 7643,
#     'provinceName': '山东',
#     'cityList': [{'cityId': 101120100,
#       'cityName': '济南',
#       'cityAveMonthSalary': 8084},
#      {'cityId': 101120200, 'cityName': '青岛', 'cityAveMonthSalary': 8289},
#      {'cityId': 101120500, 'cityName': '烟台', 'cityAveMonthSalary': 6556}]},
#    {'provinceId': 101160000,
#     'provinceAveMonthSalary': 6565,
#     'provinceName': '甘肃',
#     'cityList': [{'cityId': 101160100,
#       'cityName': '兰州',
#       'cityAveMonthSalary': 6565}]},
#    {'provinceId': 101180000,
#     'provinceAveMonthSalary': 7282,
#     'provinceName': '河南',
#     'cityList': [{'cityId': 101180100,
#       'cityName': '郑州',
#       'cityAveMonthSalary': 7282}]},
#    {'provinceId': 101190000,
#     'provinceAveMonthSalary': 7983,
#     'provinceName': '江苏',
#     'cityList': [{'cityId': 101190100,
#       'cityName': '南京',
#       'cityAveMonthSalary': 10639},
#      {'cityId': 101190200, 'cityName': '无锡', 'cityAveMonthSalary': 8206},
#      {'cityId': 101190400, 'cityName': '苏州', 'cityAveMonthSalary': 9372},
#      {'cityId': 101190500, 'cityName': '南通', 'cityAveMonthSalary': 7168},
#      {'cityId': 101190600, 'cityName': '扬州', 'cityAveMonthSalary': 6494},
#      {'cityId': 101190800, 'cityName': '徐州', 'cityAveMonthSalary': 6640},
#      {'cityId': 101191100, 'cityName': '常州', 'cityAveMonthSalary': 7364}]},
#    {'provinceId': 101200000,
#     'provinceAveMonthSalary': 9891,
#     'provinceName': '湖北',
#     'cityList': [{'cityId': 101200100,
#       'cityName': '武汉',
#       'cityAveMonthSalary': 9891}]},
#    {'provinceId': 101210000,
#     'provinceAveMonthSalary': 8237,
#     'provinceName': '浙江',
#     'cityList': [{'cityId': 101210100,
#       'cityName': '杭州',
#       'cityAveMonthSalary': 11248},
#      {'cityId': 101210300, 'cityName': '嘉兴', 'cityAveMonthSalary': 7716},
#      {'cityId': 101210400, 'cityName': '宁波', 'cityAveMonthSalary': 8067},
#      {'cityId': 101210500, 'cityName': '绍兴', 'cityAveMonthSalary': 7396},
#      {'cityId': 101210600, 'cityName': '台州', 'cityAveMonthSalary': 7813},
#      {'cityId': 101210700, 'cityName': '温州', 'cityAveMonthSalary': 7576},
#      {'cityId': 101210900, 'cityName': '金华', 'cityAveMonthSalary': 7844}]},
#    {'provinceId': 101220000,
#     'provinceAveMonthSalary': 7618,
#     'provinceName': '安徽',
#     'cityList': [{'cityId': 101220100,
#       'cityName': '合肥',
#       'cityAveMonthSalary': 7618}]},
#    {'provinceId': 101230000,
#     'provinceAveMonthSalary': 7272,
#     'provinceName': '福建',
#     'cityList': [{'cityId': 101230100,
#       'cityName': '福州',
#       'cityAveMonthSalary': 7691},
#      {'cityId': 101230200, 'cityName': '厦门', 'cityAveMonthSalary': 8384},
#      {'cityId': 101230500, 'cityName': '泉州', 'cityAveMonthSalary': 7272}]},
#    {'provinceId': 101240000,
#     'provinceAveMonthSalary': 7312,
#     'provinceName': '江西',
#     'cityList': [{'cityId': 101240100,
#       'cityName': '南昌',
#       'cityAveMonthSalary': 7394}]},
#    {'provinceId': 101250000,
#     'provinceAveMonthSalary': 8029,
#     'provinceName': '湖南',
#     'cityList': [{'cityId': 101250100,
#       'cityName': '长沙',
#       'cityAveMonthSalary': 8029}]},
#    {'provinceId': 101260000,
#     'provinceAveMonthSalary': 6716,
#     'provinceName': '贵州',
#     'cityList': [{'cityId': 101260100,
#       'cityName': '贵阳',
#       'cityAveMonthSalary': 6716}]},
#    {'provinceId': 101270000,
#     'provinceAveMonthSalary': 9984,
#     'provinceName': '四川',
#     'cityList': [{'cityId': 101270100,
#       'cityName': '成都',
#       'cityAveMonthSalary': 9984}]},
#    {'provinceId': 101280000,
#     'provinceAveMonthSalary': 8911,
#     'provinceName': '广东',
#     'cityList': [{'cityId': 101280100,
#       'cityName': '广州',
#       'cityAveMonthSalary': 9822},
#      {'cityId': 101280300, 'cityName': '惠州', 'cityAveMonthSalary': 7496},
#      {'cityId': 101280600, 'cityName': '深圳', 'cityAveMonthSalary': 11831},
#      {'cityId': 101280700, 'cityName': '珠海', 'cityAveMonthSalary': 9002},
#      {'cityId': 101280800, 'cityName': '佛山', 'cityAveMonthSalary': 7947},
#      {'cityId': 101281600, 'cityName': '东莞', 'cityAveMonthSalary': 9016},
#      {'cityId': 101281700, 'cityName': '中山', 'cityAveMonthSalary': 7262}]},
#    {'provinceId': 101290000,
#     'provinceAveMonthSalary': 6706,
#     'provinceName': '云南',
#     'cityList': [{'cityId': 101290100,
#       'cityName': '昆明',
#       'cityAveMonthSalary': 6706}]},
#    {'provinceId': 101300000,
#     'provinceAveMonthSalary': 6845,
#     'provinceName': '广西',
#     'cityList': [{'cityId': 101300100,
#       'cityName': '南宁',
#       'cityAveMonthSalary': 6845}]},
#    {'provinceId': 101310000,
#     'provinceAveMonthSalary': 6377,
#     'provinceName': '海南',
#     'cityList': [{'cityId': 101310100,
#       'cityName': '海口',
#       'cityAveMonthSalary': 6377}]},
#    {'provinceId': 101080000,
#     'provinceAveMonthSalary': 0,
#     'provinceName': '内蒙古',
#     'cityList': None},
#    {'provinceId': 101130000,
#     'provinceAveMonthSalary': 0,
#     'provinceName': '新疆',
#     'cityList': None},
#    {'provinceId': 101150000,
#     'provinceAveMonthSalary': 0,
#     'provinceName': '青海',
#     'cityList': None},
#    {'provinceId': 101170000,
#     'provinceAveMonthSalary': 0,
#     'provinceName': '宁夏',
#     'cityList': None},
#    {'provinceId': 101340000,
#     'provinceAveMonthSalary': 0,
#     'provinceName': '台湾',
#     'cityList': None},
#    {'provinceId': 101140000,
#     'provinceAveMonthSalary': 0,
#     'provinceName': '西藏',
#     'cityList': None},
#    {'provinceId': 101320000,
#     'provinceAveMonthSalary': 0,
#     'provinceName': '香港',
#     'cityList': None},
#    {'provinceId': 101330000,
#     'provinceAveMonthSalary': 0,
#     'provinceName': '澳门',
#     'cityList': None}],
#   'lastUpdateTime': '2021年02月05日'}}

# %%
job_statics_data_json = job_staticis_data.json()
job_statics_data_json['zpData']['salaryByPoints']
# Out:
# [{'name': '10分位', 'title': '低端', 'salary': 59699, 'point': 10},
#  {'name': '25分位', 'title': '中低端', 'salary': 75803, 'point': 25},
#  {'name': '50分位', 'title': '中端', 'salary': 98774, 'point': 50},
#  {'name': '75分位', 'title': '中高端', 'salary': 129443, 'point': 75},
#  {'name': '90分位', 'title': '高端', 'salary': 166268, 'point': 90}]

# %%
statics_x = []
statics_y = []
for i in job_statics_data_json['zpData']['salaryByPoints']:
    statics_x.append(i['name'] + '\n' + i['title'])
    statics_y.append(i['salary'])

# %%
import pyecharts.options as opts
from pyecharts.charts import Line, Bar, Pie, Calendar, WordCloud
from pyecharts.commons.utils import JsCode
from pyecharts.globals import SymbolType
import datetime
import random

# %%
x_data = statics_x
y_data = statics_y

background_color_js = (
    "new echarts.graphic.LinearGradient(0, 0, 0, 1, "
    "[{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false)"
)
area_color_js = (
    "new echarts.graphic.LinearGradient(0, 0, 0, 1, "
    "[{offset: 0, color: '#eb64fb'}, {offset: 1, color: '#3fbbff0d'}], false)"
)

c_line = (
    Line(init_opts=opts.InitOpts(bg_color=JsCode(background_color_js)))
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="薪资",
        y_axis=y_data,
        is_smooth=True,
        is_symbol_show=True,
        symbol="circle",
        symbol_size=6,
        linestyle_opts=opts.LineStyleOpts(color="#fff"),
        label_opts=opts.LabelOpts(is_show=True, position="top", color="white"),
        itemstyle_opts=opts.ItemStyleOpts(
            color="red", border_color="#fff", border_width=3
        ),
        tooltip_opts=opts.TooltipOpts(is_show=False),
        areastyle_opts=opts.AreaStyleOpts(color=JsCode(area_color_js), opacity=1),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="收入分位",
            pos_bottom="5%",
            pos_left="center",
            title_textstyle_opts=opts.TextStyleOpts(color="#fff", font_size=16),
        ),
        xaxis_opts=opts.AxisOpts(
            type_="category",
            boundary_gap=False,
            axislabel_opts=opts.LabelOpts(margin=30, color="#ffffff63"),
            axisline_opts=opts.AxisLineOpts(is_show=False),
            axistick_opts=opts.AxisTickOpts(
                is_show=True,
                length=25,
                linestyle_opts=opts.LineStyleOpts(color="#ffffff1f"),
            ),
            splitline_opts=opts.SplitLineOpts(
                is_show=True, linestyle_opts=opts.LineStyleOpts(color="#ffffff1f")
            ),
        ),
        yaxis_opts=opts.AxisOpts(
            type_="value",
            position="right",
            axislabel_opts=opts.LabelOpts(margin=20, color="#ffffff63"),
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(width=2, color="#fff")
            ),
            axistick_opts=opts.AxisTickOpts(
                is_show=True,
                length=15,
                linestyle_opts=opts.LineStyleOpts(color="#ffffff1f"),
            ),
            splitline_opts=opts.SplitLineOpts(
                is_show=True, linestyle_opts=opts.LineStyleOpts(color="#ffffff1f")
            ),
        ),
        legend_opts=opts.LegendOpts(is_show=False),
    )
)

# %%
c_line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="89cc474b775d417a8e9f19d4a64f0877" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_89cc474b775d417a8e9f19d4a64f0877 = echarts.init(
#                     document.getElementById('89cc474b775d417a8e9f19d4a64f0877'), 'white', {renderer: 'canvas'});
#                 var option_89cc474b775d417a8e9f19d4a64f0877 = {
#     "backgroundColor": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false),
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u85aa\u8d44",
#             "connectNulls": false,
#             "symbol": "circle",
#             "symbolSize": 6,
#             "showSymbol": true,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "10\u5206\u4f4d\n\u4f4e\u7aef",
#                     59699
#                 ],
#                 [
#                     "25\u5206\u4f4d\n\u4e2d\u4f4e\u7aef",
#                     75803
#                 ],
#                 [
#                     "50\u5206\u4f4d\n\u4e2d\u7aef",
#                     98774
#                 ],
#                 [
#                     "75\u5206\u4f4d\n\u4e2d\u9ad8\u7aef",
#                     129443
#                 ],
#                 [
#                     "90\u5206\u4f4d\n\u9ad8\u7aef",
#                     166268
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "color": "white",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid",
#                 "color": "#fff"
#             },
#             "areaStyle": {
#                 "opacity": 1,
#                 "color": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{offset: 0, color: '#eb64fb'}, {offset: 1, color: '#3fbbff0d'}], false)
#             },
#             "tooltip": {
#                 "show": false,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "itemStyle": {
#                 "color": "red",
#                 "borderColor": "#fff",
#                 "borderWidth": 3
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u85aa\u8d44"
#             ],
#             "selected": {
#                 "\u85aa\u8d44": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": false,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0
#             },
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false,
#                 "length": 25,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#ffffff1f"
#                 }
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "color": "#ffffff63",
#                 "margin": 30
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "boundaryGap": false,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#ffffff1f"
#                 }
#             },
#             "data": [
#                 "10\u5206\u4f4d\n\u4f4e\u7aef",
#                 "25\u5206\u4f4d\n\u4e2d\u4f4e\u7aef",
#                 "50\u5206\u4f4d\n\u4e2d\u7aef",
#                 "75\u5206\u4f4d\n\u4e2d\u9ad8\u7aef",
#                 "90\u5206\u4f4d\n\u9ad8\u7aef"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 2,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#fff"
#                 }
#             },
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false,
#                 "length": 15,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#ffffff1f"
#                 }
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "color": "#ffffff63",
#                 "margin": 20
#             },
#             "inverse": false,
#             "position": "right",
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#ffffff1f"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6536\u5165\u5206\u4f4d",
#             "

# %%
statics_x = []
statics_y = []
for i in job_statics_data_json['zpData']['salaryByDistributed']:
    statics_y.append(i['percent'])
    statics_x.append(i['salaryRange'])

# %%
statics_x
statics_y
# Out:
# [24, 26, 21, 13, 16]

# %%
statics_x
# Out:
# ['<7.30', '7.30-9.97', '9.97-12.63', '12.63-15.29', '>15.29']

# %%
def bar_chart(x, y) -> Bar:
    background_color_js = (
        "new echarts.graphic.LinearGradient(0, 0, 0, 1, "
        "[{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false)"
    )
    c = (
        Bar(init_opts=opts.InitOpts(bg_color=JsCode(background_color_js)))
        #Bar()
        .add_xaxis(x)
        # .add_xaxis(searchcount.index.tolist()[:10])
        .reversal_axis()
        .add_yaxis("", y, 
                   label_opts=opts.LabelOpts(position='inside', formatter="{c}%"),
                  color='plum', category_gap="60%"
                  )
        .set_global_opts(xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30, formatter="{value}%"),
                                                 axisline_opts=opts.AxisLineOpts(is_show=False),),
                        yaxis_opts=opts.AxisOpts(
                            axislabel_opts=opts.LabelOpts(is_show=True),
                        axisline_opts=opts.AxisLineOpts(is_show=False),
                        axistick_opts=opts.AxisTickOpts(
                        is_show=True,
                        length=25,
                        linestyle_opts=opts.LineStyleOpts(color="#ffffff1f"),
                    ),)
                        )
        .set_series_opts(
            itemstyle_opts={
            "normal": {
                "color": JsCode("""new echarts.graphic.LinearGradient(0, 0, 0, 1, [{
                    offset: 0,
                    color: 'rgba(255,100,97,.5)'
                }, {
                    offset: 1,
                    color: 'rgba(221,160,221)'
                }], false)"""),
                "barBorderRadius": [30, 30, 30, 30],
                "shadowColor": 'rgb(0, 160, 221)',
            }}
        )
    )
    return c

# %%
bar_chart(statics_x, statics_y).render_notebook()
# bar_chart(statics_x, statics_y).render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9bcc046eeb8c46d484d0b3785b83a666" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9bcc046eeb8c46d484d0b3785b83a666 = echarts.init(
#                     document.getElementById('9bcc046eeb8c46d484d0b3785b83a666'), 'white', {renderer: 'canvas'});
#                 var option_9bcc046eeb8c46d484d0b3785b83a666 = {
#     "backgroundColor": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false),
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "plum",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 24,
#                 26,
#                 21,
#                 13,
#                 16
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "60%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "formatter": "{c}%"
#             },
#             "itemStyle": {
#                 "normal": {
#                     "color": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{                    offset: 0,                    color: 'rgba(255,100,97,.5)'                }, {                    offset: 1,                    color: 'rgba(221,160,221)'                }], false),
#                     "barBorderRadius": [
#                         30,
#                         30,
#                         30,
#                         30
#                     ],
#                     "shadowColor": "rgb(0, 160, 221)"
#                 }
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": false,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -30,
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": false,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0
#             },
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false,
#                 "length": 25,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#ffffff1f"
#                 }
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "<7.30",
#                 "7.30-9.97",
#                 "9.97-12.63",
#                 "12.63-15.29",
#                 ">15.29"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_9bcc046eeb8c46d484d0b3785b83a666.setOption(option_9bcc046eeb8c46d484d0b3785b83a666);
#         });
#     </script>

# %%
statics_x = []
statics_y = []
for i in job_statics_data_json['zpData']['salaryByWorkExp']:
    statics_y.append(i['percent'])
    statics_x.append(i['workExp'] + ':' + str(i['aveSalary']))
statics_y
# Out:
# [3, 55, 37, 5, 0]

# %%
list(zip(statics_x, statics_y))
# Out:
# [('1年以内:5741', 3),
#  ('1-3年:7760', 55),
#  ('3-5年:9880', 37),
#  ('5-10年:12091', 5),
#  ('10年以上:13682', 0)]

# %%
def pie_rosetype(data) -> Pie:
    background_color_js = (
    "new echarts.graphic.LinearGradient(0, 0, 0, 1, "
    "[{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false)"
)
    c = (
        Pie(init_opts=opts.InitOpts(bg_color=JsCode(background_color_js)))
        .add(
            "",
            list(data),
            radius=["30%", "75%"],
            center=["45%", "50%"],
            rosetype="radius",
            label_opts=opts.LabelOpts(formatter="{b}: {c}"),
        )
        .set_global_opts(title_opts=opts.TitleOpts(title=""),
                        )
    )
    return c

# %%
pie_rosetype(zip(statics_x, statics_y)).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="56aa21f76bc043e7b33049c634b3cc50" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_56aa21f76bc043e7b33049c634b3cc50 = echarts.init(
#                     document.getElementById('56aa21f76bc043e7b33049c634b3cc50'), 'white', {renderer: 'canvas'});
#                 var option_56aa21f76bc043e7b33049c634b3cc50 = {
#     "backgroundColor": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false),
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "1\u5e74\u4ee5\u5185",
#                     "value": 3
#                 },
#                 {
#                     "name": "1-3\u5e74",
#                     "value": 55
#                 },
#                 {
#                     "name": "3-5\u5e74",
#                     "value": 37
#                 },
#                 {
#                     "name": "5-10\u5e74",
#                     "value": 5
#                 },
#                 {
#                     "name": "10\u5e74\u4ee5\u4e0a",
#                     "value": 0
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "45%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "1\u5e74\u4ee5\u5185",
#                 "1-3\u5e74",
#                 "3-5\u5e74",
#                 "5-10\u5e74",
#                 "10\u5e74\u4ee5\u4e0a"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_56aa21f76bc043e7b33049c634b3cc50.setOption(option_56aa21f76bc043e7b33049c634b3cc50);
#         });
#     </script>

# %%
background_color_js = (
    "new echarts.graphic.LinearGradient(0, 0, 0, 1, "
    "[{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false)"
)
c = (
    Pie(init_opts=opts.InitOpts(bg_color=JsCode(background_color_js)))
    .add(
        "",
        list(zip(statics_x, statics_y)),
        radius=["40%", "55%"],
        label_opts=opts.LabelOpts(
            position="outside",
            formatter="{a|job}{abg|}\n{hr|}\n {b|{b}: }{per|{d}%}  ",
            background_color="#eee",
            border_color="#aaa",
            border_width=1,
            border_radius=4,
            rich={
                "a": {"color": "#999", "lineHeight": 22, "align": "center"},
                "abg": {
                    "backgroundColor": "#e3e3e3",
                    "width": "100%",
                    "align": "right",
                    "height": 22,
                    "borderRadius": [4, 4, 0, 0],
                },
                "hr": {
                    "borderColor": "#aaa",
                    "width": "100%",
                    "borderWidth": 0.5,
                    "height": 0,
                },
                "b": {"fontSize": 16, "lineHeight": 33},
                "per": {
                    "color": "#eee",
                    "backgroundColor": "#334455",
                    "padding": [2, 4],
                    "borderRadius": 2,
                },
            },
        ),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title=""))
)

# %%
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="805b4345470d4b10956ae4ba19b36cb7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_805b4345470d4b10956ae4ba19b36cb7 = echarts.init(
#                     document.getElementById('805b4345470d4b10956ae4ba19b36cb7'), 'white', {renderer: 'canvas'});
#                 var option_805b4345470d4b10956ae4ba19b36cb7 = {
#     "backgroundColor": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false),
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "1\u5e74\u4ee5\u5185:5741",
#                     "value": 3
#                 },
#                 {
#                     "name": "1-3\u5e74:7760",
#                     "value": 55
#                 },
#                 {
#                     "name": "3-5\u5e74:9880",
#                     "value": 37
#                 },
#                 {
#                     "name": "5-10\u5e74:12091",
#                     "value": 5
#                 },
#                 {
#                     "name": "10\u5e74\u4ee5\u4e0a:13682",
#                     "value": 0
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "55%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "outside",
#                 "margin": 8,
#                 "formatter": "{a|job}{abg|}\n{hr|}\n {b|{b}: }{per|{d}%}  ",
#                 "backgroundColor": "#eee",
#                 "borderColor": "#aaa",
#                 "borderWidth": 1,
#                 "borderRadius": 4,
#                 "rich": {
#                     "a": {
#                         "color": "#999",
#                         "lineHeight": 22,
#                         "align": "center"
#                     },
#                     "abg": {
#                         "backgroundColor": "#e3e3e3",
#                         "width": "100%",
#                         "align": "right",
#                         "height": 22,
#                         "borderRadius": [
#                             4,
#                             4,
#                             0,
#                             0
#                         ]
#                     },
#                     "hr": {
#                         "borderColor": "#aaa",
#                         "width": "100%",
#                         "borderWidth": 0.5,
#                         "height": 0
#                     },
#                     "b": {
#                         "fontSize": 16,
#                         "lineHeight": 33
#                     },
#                     "per": {
#                         "color": "#eee",
#                         "backgroundColor": "#334455",
#                         "padding": [
#                             2,
#                             4
#                         ],
#                         "borderRadius": 2
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "1\u5e74\u4ee5\u5185:5741",
#                 "1-3\u5e74:7760",
#                 "3-5\u5e74:9880",
#                 "5-10\u5e74:12091",
#                 "10\u5e74\u4ee5\u4e0a:13682"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_805b4345470d4b10956ae4ba19b36cb7.setOption(option_805b4345470d4b10956ae4ba19b36cb7);
#         });
#     </script>

# %%
statics_x = []
statics_y = []
for i in job_statics_data_json['zpData']['salaryByAge']:
    statics_x.append(i['ageRange'])
    statics_y.append(i['people'])
statics_y
# Out:
# [490609, 534542, 76567, 13284, 2635, 1111]

# %%
def bar_chart_age(x, y) -> Bar:
    background_color_js = (
        "new echarts.graphic.LinearGradient(0, 0, 0, 1, "
        "[{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false)"
    )
    c = (
        Bar(init_opts=opts.InitOpts(bg_color=JsCode(background_color_js)))
        #Bar()
        .add_xaxis(x)
        # .add_xaxis(searchcount.index.tolist()[:10])
        # .reversal_axis()
        .add_yaxis("", y, 
                   label_opts=opts.LabelOpts(position='inside', formatter="{c}"),
                  color='plum', category_gap="60%"
                  )
        .set_global_opts(xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30, formatter="{value}"),
                                                 axisline_opts=opts.AxisLineOpts(is_show=False),),
                        yaxis_opts=opts.AxisOpts(
                            axislabel_opts=opts.LabelOpts(is_show=True),
                        axisline_opts=opts.AxisLineOpts(is_show=False),
                        axistick_opts=opts.AxisTickOpts(
                        is_show=True,
                        length=25,
                        linestyle_opts=opts.LineStyleOpts(color="#ffffff1f"),
                    ),)
                        )
        .set_series_opts(
            itemstyle_opts={
            "normal": {
                "color": JsCode("""new echarts.graphic.LinearGradient(0, 0, 0, 1, [{
                    offset: 0,
                    color: 'rgba(255,100,97,.5)'
                }, {
                    offset: 1,
                    color: 'rgba(221,160,221)'
                }], false)"""),
                "barBorderRadius": [30, 30, 30, 30],
                "shadowColor": 'rgb(0, 160, 221)',
            }}
        )
    )
    return c

# %%
bar_chart_age(statics_x, statics_y).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="fb795a7c5c464e26b52c8a36149481e2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_fb795a7c5c464e26b52c8a36149481e2 = echarts.init(
#                     document.getElementById('fb795a7c5c464e26b52c8a36149481e2'), 'white', {renderer: 'canvas'});
#                 var option_fb795a7c5c464e26b52c8a36149481e2 = {
#     "backgroundColor": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false),
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "plum",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 490609,
#                 534542,
#                 76567,
#                 13284,
#                 2635,
#                 1111
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "60%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "formatter": "{c}"
#             },
#             "itemStyle": {
#                 "normal": {
#                     "color": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{                    offset: 0,                    color: 'rgba(255,100,97,.5)'                }, {                    offset: 1,                    color: 'rgba(221,160,221)'                }], false),
#                     "barBorderRadius": [
#                         30,
#                         30,
#                         30,
#                         30
#                     ],
#                     "shadowColor": "rgb(0, 160, 221)"
#                 }
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": false,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -30,
#                 "margin": 8,
#                 "formatter": "{value}"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "24\u5c81\u4ee5\u4e0b",
#                 "25\u5c81-29\u5c81",
#                 "30\u5c81-34\u5c81",
#                 "35\u5c81-39\u5c81",
#                 "40\u5c81-44\u5c81",
#                 "45\u5c81\u4ee5\u4e0a"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": false,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0
#             },
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false,
#                 "length": 25,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#ffffff1f"
#                 }
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_fb795a7c5c464e26b52c8a36149481e2.setOption(option_fb795a7c5c464e26b52c8a36149481e2);
#         });
#     </script>

# %%
statics_x = []
statics_y = []
for i in job_statics_data_json['zpData']['salaryByMonth']:
    statics_x.append(i['year'] + '-' + i['month'])
    statics_y.append(i['monthAveSalary'])
statics_y
# Out:
# [8625, 8279, 8075, 7835, 7862, 7863, 8035, 8078, 8111, 8244, 7978, 8124]

# %%
x_data = statics_x
y_data = statics_y

background_color_js = (
    "new echarts.graphic.LinearGradient(0, 0, 0, 1, "
    "[{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false)"
)
area_color_js = (
    "new echarts.graphic.LinearGradient(0, 0, 0, 1, "
    "[{offset: 0, color: '#eb64fb'}, {offset: 1, color: '#3fbbff0d'}], false)"
)

c_line_month = (
    Line(init_opts=opts.InitOpts(bg_color=JsCode(background_color_js)))
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="薪资",
        y_axis=y_data,
        is_smooth=True,
        is_symbol_show=True,
        symbol="circle",
        symbol_size=6,
        linestyle_opts=opts.LineStyleOpts(color="#fff"),
        label_opts=opts.LabelOpts(is_show=True, position="top", color="white"),
        itemstyle_opts=opts.ItemStyleOpts(
            color="red", border_color="#fff", border_width=3
        ),
        tooltip_opts=opts.TooltipOpts(is_show=False),
        areastyle_opts=opts.AreaStyleOpts(color=JsCode(area_color_js), opacity=1),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="薪资变化",
            pos_bottom="5%",
            pos_left="center",
            title_textstyle_opts=opts.TextStyleOpts(color="#fff", font_size=16),
        ),
        xaxis_opts=opts.AxisOpts(
            type_="category",
            boundary_gap=False,
            axislabel_opts=opts.LabelOpts(rotate=-20, margin=30, color="#ffffff63"),
            axisline_opts=opts.AxisLineOpts(is_show=False),
            axistick_opts=opts.AxisTickOpts(
                is_show=True,
                length=25,
                linestyle_opts=opts.LineStyleOpts(color="#ffffff1f"),
            ),
            splitline_opts=opts.SplitLineOpts(
                is_show=True, linestyle_opts=opts.LineStyleOpts(color="#ffffff1f")
            ),
        ),
        yaxis_opts=opts.AxisOpts(
            min_=7500,
            type_="value",
            position="right",
            axislabel_opts=opts.LabelOpts(margin=20, color="#ffffff63"),
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(width=2, color="#fff")
            ),
            axistick_opts=opts.AxisTickOpts(
                is_show=True,
                length=15,
                linestyle_opts=opts.LineStyleOpts(color="#ffffff1f"),
            ),
            splitline_opts=opts.SplitLineOpts(
                is_show=True, linestyle_opts=opts.LineStyleOpts(color="#ffffff1f")
            ),
        ),
        legend_opts=opts.LegendOpts(is_show=False),
    )
)

# %%
c_line_month.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="cbcb46bbbd3d43fc83fd52b73a12ef29" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_cbcb46bbbd3d43fc83fd52b73a12ef29 = echarts.init(
#                     document.getElementById('cbcb46bbbd3d43fc83fd52b73a12ef29'), 'white', {renderer: 'canvas'});
#                 var option_cbcb46bbbd3d43fc83fd52b73a12ef29 = {
#     "backgroundColor": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false),
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u85aa\u8d44",
#             "connectNulls": false,
#             "symbol": "circle",
#             "symbolSize": 6,
#             "showSymbol": true,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2020\u5e74-2\u6708",
#                     8625
#                 ],
#                 [
#                     "2020\u5e74-3\u6708",
#                     8279
#                 ],
#                 [
#                     "2020\u5e74-4\u6708",
#                     8075
#                 ],
#                 [
#                     "2020\u5e74-5\u6708",
#                     7835
#                 ],
#                 [
#                     "2020\u5e74-6\u6708",
#                     7862
#                 ],
#                 [
#                     "2020\u5e74-7\u6708",
#                     7863
#                 ],
#                 [
#                     "2020\u5e74-8\u6708",
#                     8035
#                 ],
#                 [
#                     "2020\u5e74-9\u6708",
#                     8078
#                 ],
#                 [
#                     "2020\u5e74-10\u6708",
#                     8111
#                 ],
#                 [
#                     "2020\u5e74-11\u6708",
#                     8244
#                 ],
#                 [
#                     "2020\u5e74-12\u6708",
#                     7978
#                 ],
#                 [
#                     "2021\u5e74-1\u6708",
#                     8124
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "color": "white",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid",
#                 "color": "#fff"
#             },
#             "areaStyle": {
#                 "opacity": 1,
#                 "color": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{offset: 0, color: '#eb64fb'}, {offset: 1, color: '#3fbbff0d'}], false)
#             },
#             "tooltip": {
#                 "show": false,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "itemStyle": {
#                 "color": "red",
#                 "borderColor": "#fff",
#                 "borderWidth": 3
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u85aa\u8d44"
#             ],
#             "selected": {
#                 "\u85aa\u8d44": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": false,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0
#             },
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false,
#                 "length": 25,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#ffffff1f"
#                 }
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "color": "#ffffff63",
#                 "rotate": -20,
#                 "margin": 30
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "boundaryGap": false,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#ffffff1f"
#                 }
#             },
#             "data": [
#                 "2020\u5e74-2\u6708",
#                 "2020\u5e74-3\u6708",
#                 "2020\u5e74-4\u6708",
#                 "2020\u5e74-5\u6708",
#                 "2020\u5e74-6\u6708",
#                 "2020\u5e74-7\u6708",
#                 "2020\u5e74-8\u6708",
#                 "2020\u5e74-9\u6708",
#                 "2020\u5e74-10\u6708",
#                 "2020\u5e74-11\u6708",
#                 "2020\u5e74-12\u6708",
#                 "2021\u5e74-1\u6708"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 2,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#fff"
#                 }
#             },
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false,
#                 "length": 15,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,

# %%
from pyecharts.charts import Map
from pyecharts.faker import Faker

# %%
statics_x = []
statics_y = []
for i in job_statics_data_json['zpData']['salaryByCity']:
    if i['cityList']:
        statics_x.append(i['cityList'][0]['cityAveMonthSalary'])
    statics_y.append(i['provinceName'])

# %%
background_color_js = (
    "new echarts.graphic.LinearGradient(0, 0, 0, 1, "
    "[{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false)"
)
c = (
    Map(init_opts=opts.InitOpts(bg_color=JsCode(background_color_js)))
    .add("全国薪资", [list(z) for z in zip(statics_y, statics_x)], "china")
    .set_global_opts(
        title_opts=opts.TitleOpts(title=""),
        visualmap_opts=opts.VisualMapOpts(max_=15000, min_=6000),
    )
)

# %%
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="d0181d4365b7427aadb91f0c30c0b03f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_d0181d4365b7427aadb91f0c30c0b03f = echarts.init(
#                     document.getElementById('d0181d4365b7427aadb91f0c30c0b03f'), 'white', {renderer: 'canvas'});
#                 var option_d0181d4365b7427aadb91f0c30c0b03f = {
#     "backgroundColor": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false),
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5168\u56fd\u85aa\u8d44",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 13434
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 12574
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 8111
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 7695
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 6721
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 6567
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 7173
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 6830
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 6295
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 10116
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 8084
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 6565
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 7282
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 10639
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 9891
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 11248
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 7618
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 7691
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 7394
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 8029
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 6716
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 9984
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 9822
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 6706
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 6845
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 6377
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5168\u56fd\u85aa\u8d44"
#             ],
#             "selected": {
#                 "\u5168\u56fd\u85aa\u8d44": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 6000,
#         "max": 15000,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_d0181d4365b7427aadb91f0c30c0b03f.setOption(option_d0181d4365b7427aadb91f0c30c0b03f);
#         });
#     </script>
