# %%
import requests
import pandas as pd

# %%
df = pd.DataFrame()
for i in range(1, 206):
    test = "http://college.gaokao.com/areapoint/p%s/" % str(i)
    print(test)
    d = pd.read_html(test)[0]
    df = pd.concat([df, d], axis=0, ignore_index=True)
# Out:
# http://college.gaokao.com/areapoint/p1/
# http://college.gaokao.com/areapoint/p2/
# http://college.gaokao.com/areapoint/p3/
# http://college.gaokao.com/areapoint/p4/
# http://college.gaokao.com/areapoint/p5/
# http://college.gaokao.com/areapoint/p6/
# http://college.gaokao.com/areapoint/p7/
# http://college.gaokao.com/areapoint/p8/
# http://college.gaokao.com/areapoint/p9/
# http://college.gaokao.com/areapoint/p10/
# http://college.gaokao.com/areapoint/p11/
# http://college.gaokao.com/areapoint/p12/
# http://college.gaokao.com/areapoint/p13/
# http://college.gaokao.com/areapoint/p14/
# http://college.gaokao.com/areapoint/p15/
# http://college.gaokao.com/areapoint/p16/
# http://college.gaokao.com/areapoint/p17/
# http://college.gaokao.com/areapoint/p18/
# http://college.gaokao.com/areapoint/p19/
# http://college.gaokao.com/areapoint/p20/
# http://college.gaokao.com/areapoint/p21/
# http://college.gaokao.com/areapoint/p22/
# http://college.gaokao.com/areapoint/p23/
# ...

# %%
df
# Out:
#          年份 考生所在地  文理分科            批次名称  最低控制分数线
# 0      2020    北京  综合改革             本科批      436
# 1      2020    北京  综合改革       特殊类型招生控制线      526
# 2      2020    北京  综合改革         艺术类（本科）      316
# 3      2020    北京  综合改革       艺术类（高职专科）       84
# 4      2020    北京  综合改革  体育类（本科）体育成绩60分      300
# ...     ...   ...   ...             ...      ...
# 15169  2005    江西    其他     艺术类本科戏剧表演专业      341
# 15170  2005    江西    其他       艺术类本科空乘专业      333
# 15171  2005    江西    其他        三校本科美术专业      193
# 15172  2005    江西    其他           体育类本科      297
# 15173  2005    江西    其他           体育类专科      275
#
# [15174 rows x 5 columns]

# %%
df.to_csv("gaokaofenshu.txt")

# %%
from pyecharts.charts import Bar,Map,Line,Page,Scatter, Geo, Map
from pyecharts import options as opts
from pyecharts.globals import SymbolType,ThemeType, ChartType
from pyecharts.charts import Grid
from pyecharts.commons.utils import JsCode

# %%
# 考生数量

# %%
num = pd.read_csv("gaokao_renshu")

# %%
num_sort = num.sort_values(by=['number'], ascending=False)

# %%
result_num = num_sort['number'][:10]
result_pro = num_sort['province'][:10]
x_data = result_pro.values.tolist()
y_data = result_num.values.tolist()

b = (Bar()
     .add_xaxis(x_data)
     .add_yaxis('',y_data)
     .set_global_opts(title_opts = opts.TitleOpts(title='考生人数前十名'),
                     xaxis_opts=opts.AxisOpts(name="万人"))
     .set_series_opts(label_opts=opts.LabelOpts(is_show=True,position='right'))
     .reversal_axis()
)
grid = Grid(init_opts=opts.InitOpts(theme=ThemeType.VINTAGE))
grid.add(b, grid_opts=opts.GridOpts(pos_left="20%"))
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="7e354a9f65d642349fb8ea0f73e5cf7a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_7e354a9f65d642349fb8ea0f73e5cf7a = echarts.init(
#                     document.getElementById('7e354a9f65d642349fb8ea0f73e5cf7a'), 'vintage', {renderer: 'canvas'});
#                 var option_7e354a9f65d642349fb8ea0f73e5cf7a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [],
#     "series": [
#         {
# ...

# %%
result_num = num_sort['number'][-10:]
result_pro = num_sort['province'][-10:]
x_data = result_pro.values.tolist()
y_data = result_num.values.tolist()

b = (Bar()
     .add_xaxis(x_data)
     .add_yaxis('',y_data)
     .set_global_opts(title_opts = opts.TitleOpts(title='考生人数后十名'),
                     xaxis_opts=opts.AxisOpts(name="万人"))
     .set_series_opts(label_opts=opts.LabelOpts(is_show=True,position='right'))
     .reversal_axis()
)
grid = Grid(init_opts=opts.InitOpts(theme=ThemeType.VINTAGE))
grid.add(b, grid_opts=opts.GridOpts(pos_left="20%"))
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="7b929911f1a7422aac5c45d80e4b703f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_7b929911f1a7422aac5c45d80e4b703f = echarts.init(
#                     document.getElementById('7b929911f1a7422aac5c45d80e4b703f'), 'vintage', {renderer: 'canvas'});
#                 var option_7b929911f1a7422aac5c45d80e4b703f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [],
#     "series": [
#         {
# ...

# %%
# 招生分数线

# %%
df
# Out:
#          年份 考生所在地  文理分科            批次名称  最低控制分数线
# 0      2020    北京  综合改革             本科批      436
# 1      2020    北京  综合改革       特殊类型招生控制线      526
# 2      2020    北京  综合改革         艺术类（本科）      316
# 3      2020    北京  综合改革       艺术类（高职专科）       84
# 4      2020    北京  综合改革  体育类（本科）体育成绩60分      300
# ...     ...   ...   ...             ...      ...
# 15169  2005    江西    其他     艺术类本科戏剧表演专业      341
# 15170  2005    江西    其他       艺术类本科空乘专业      333
# 15171  2005    江西    其他        三校本科美术专业      193
# 15172  2005    江西    其他           体育类本科      297
# 15173  2005    江西    其他           体育类专科      275
#
# [15174 rows x 5 columns]

# %%
benke = df[df["批次名称"].isin(['本科一批'])|df["批次名称"].isin(['本科批'])|df["批次名称"].isin(['本科'])|df["批次名称"].isin(['平行录取一段'])|df["批次名称"].isin(['普通类一段'])]

# %%
benke_2020 = benke[benke["年份"]==2020].drop_duplicates()

# %%
benke_2020_like = benke_2020[(benke_2020["文理分科"]=='理科')|(benke_2020["文理分科"]=='综合改革')]
benke_2020_like_wenke = benke_2020[(benke_2020["文理分科"]=='文科')|(benke_2020["文理分科"]=='综合改革')]

# %%
benke_2020_like_sort = benke_2020_like.sort_values(by=['最低控制分数线'], ascending=False)
benke_2020_like_sort_wenke = benke_2020_like_wenke.sort_values(by=['最低控制分数线'], ascending=False)

# %%
benke_2020_like_sort
# Out:
#        年份 考生所在地  文理分科    批次名称  最低控制分数线
# 35   2020    浙江  综合改革  平行录取一段      594
# 139  2020    河南    理科    本科一批      544
# 125  2020    山西    理科    本科一批      537
# 326  2020    江西    理科    本科一批      535
# 211  2020    云南    理科    本科一批      535
# 103  2020    四川    理科    本科一批      529
# 50   2020    湖北    理科    本科一批      521
# 15   2020    吉林    理科    本科一批      517
# 38   2020    安徽    理科    本科一批      515
# 56   2020    湖南    理科    本科一批      507
# 72   2020    重庆    理科    本科一批      500
# 149  2020    广西    理科    本科一批      496
# 205  2020    贵州    理科    本科一批      480
# 6    2020    天津  综合改革     本科批      476
# 145  2020    海南  综合改革     本科批      463
# 115  2020    甘肃    理科    本科一批      458
# 21   2020   黑龙江    理科    本科一批      455
# 133  2020   内蒙古    理科    本科一批      452
# 109  2020    陕西    理科    本科一批      451
# 48   2020    山东  综合改革   普通类一段      449
# 0    2020    北京  综合改革     本科批      436
# 239  2020    宁夏    理科    本科一批      434
# 121  2020    河北    理科     本科批      415
# ...

# %%
benke_2020_like_sort_wenke
# Out:
#        年份 考生所在地  文理分科    批次名称  最低控制分数线
# 35   2020    浙江  综合改革  平行录取一段      594
# 142  2020    河南    文科    本科一批      556
# 214  2020    云南    文科    本科一批      555
# 60   2020    湖南    文科    本科一批      550
# 208  2020    贵州    文科    本科一批      548
# 329  2020    江西    文科    本科一批      547
# 18   2020    吉林    文科    本科一批      543
# 129  2020    山西    文科    本科一批      542
# 41   2020    安徽    文科    本科一批      541
# 100  2020    重庆    文科    本科一批      536
# 53   2020    湖北    文科    本科一批      531
# 106  2020    四川    文科    本科一批      527
# 245  2020    宁夏    文科    本科一批      523
# 118  2020    甘肃    文科    本科一批      520
# 136  2020   内蒙古    文科    本科一批      520
# 112  2020    陕西    文科    本科一批      512
# 202  2020    广西    文科    本科一批      500
# 24   2020   黑龙江    文科    本科一批      483
# 6    2020    天津  综合改革     本科批      476
# 13   2020    辽宁    文科     本科批      472
# 46   2020    福建    文科     本科批      465
# 123  2020    河北    文科     本科批      465
# 145  2020    海南  综合改革     本科批      463
# ...

# %%
result_num = benke_2020_like_sort['最低控制分数线'][:10]
result_pro = benke_2020_like_sort['考生所在地'][:10]
x_data = result_pro.values.tolist()
y_data = result_num.values.tolist()

b = (Bar()
     .add_xaxis(x_data)
     .add_yaxis('',y_data)
     .set_global_opts(title_opts = opts.TitleOpts(title='2020理科本科一批分数前十'),
                     xaxis_opts=opts.AxisOpts(name="分数"))
     .set_series_opts(label_opts=opts.LabelOpts(is_show=True,position='right'))
     .reversal_axis()
)
grid = Grid(init_opts=opts.InitOpts(theme=ThemeType.VINTAGE))
grid.add(b, grid_opts=opts.GridOpts(pos_left="20%"))
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="0defb43ee1d94fe1a3a61c163700bef2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_0defb43ee1d94fe1a3a61c163700bef2 = echarts.init(
#                     document.getElementById('0defb43ee1d94fe1a3a61c163700bef2'), 'vintage', {renderer: 'canvas'});
#                 var option_0defb43ee1d94fe1a3a61c163700bef2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [],
#     "series": [
#         {
# ...

# %%
result_num = benke_2020_like_sort_wenke['最低控制分数线'][:10]
result_pro = benke_2020_like_sort_wenke['考生所在地'][:10]
x_data = result_pro.values.tolist()
y_data = result_num.values.tolist()

b = (Bar()
     .add_xaxis(x_data)
     .add_yaxis('',y_data)
     .set_global_opts(title_opts = opts.TitleOpts(title='2020文科本科一批分数前十'),
                     xaxis_opts=opts.AxisOpts(name="分数"))
     .set_series_opts(label_opts=opts.LabelOpts(is_show=True,position='right'))
     .reversal_axis()
)
grid = Grid(init_opts=opts.InitOpts(theme=ThemeType.VINTAGE))
grid.add(b, grid_opts=opts.GridOpts(pos_left="20%"))
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="1a9cb1d92c2c4ee69323b4ed4df6fcfa" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_1a9cb1d92c2c4ee69323b4ed4df6fcfa = echarts.init(
#                     document.getElementById('1a9cb1d92c2c4ee69323b4ed4df6fcfa'), 'vintage', {renderer: 'canvas'});
#                 var option_1a9cb1d92c2c4ee69323b4ed4df6fcfa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [],
#     "series": [
#         {
# ...

# %%
benke_2019 = benke[benke["年份"]==2019].drop_duplicates()
benke_2019_like = benke_2019[(benke_2019["文理分科"]=='理科')|(benke_2019["文理分科"]=='综合改革')]
benke_2019_like_sort = benke_2019_like.sort_values(by=['最低控制分数线'], ascending=False)

result_num = benke_2019_like_sort['最低控制分数线'][:10]
result_pro = benke_2019_like_sort['考生所在地'][:10]
x_data = result_pro.values.tolist()
y_data = result_num.values.tolist()

b = (Bar()
     .add_xaxis(x_data)
     .add_yaxis('',y_data)
     .set_global_opts(title_opts = opts.TitleOpts(title='2019理科本科一批分数前十'),
                     xaxis_opts=opts.AxisOpts(name="分数"))
     .set_series_opts(label_opts=opts.LabelOpts(is_show=True,position='right'))
     .reversal_axis()
)
grid = Grid(init_opts=opts.InitOpts(theme=ThemeType.VINTAGE))
grid.add(b, grid_opts=opts.GridOpts(pos_left="20%"))
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="77dfdb40a20c4daf8778dc922511aa4d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_77dfdb40a20c4daf8778dc922511aa4d = echarts.init(
#                     document.getElementById('77dfdb40a20c4daf8778dc922511aa4d'), 'vintage', {renderer: 'canvas'});
#                 var option_77dfdb40a20c4daf8778dc922511aa4d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [],
#     "series": [
#         {
# ...

# %%
benke_beijing = benke[(benke["考生所在地"]=="北京")].drop_duplicates()
benke_shanghai = benke[benke["考生所在地"]=="上海"].drop_duplicates()

# %%
benke_beijing[(benke_beijing["文理分科"]=="理科")|(benke_beijing["文理分科"]=="综合改革")]
benke_shanghai[(benke_shanghai["文理分科"]=="理科")|(benke_shanghai["文理分科"]=="综合改革")]
# Out:
#          年份 考生所在地  文理分科  批次名称  最低控制分数线
# 27     2020    上海  综合改革   本科批      400
# 2278   2016    上海    理科   本科批      360
# 3036   2015    上海    理科  本科一批      414
# 3808   2014    上海    理科  本科一批      423
# 4566   2013    上海    理科  本科一批      405
# 5294   2012    上海    理科  本科一批      423
# 6216   2011    上海    理科  本科一批      462
# 7700   2010    上海    理科  本科一批      474
# 11482  2006    上海    理科  本科一批      466

# %%
benke_beijing
# Out:
#          年份 考生所在地  文理分科  批次名称  最低控制分数线
# 0      2020    北京  综合改革   本科批      436
# 889    2018    北京    理科  本科一批      532
# 893    2018    北京    文科  本科一批      576
# 1541   2017    北京    理科  本科一批      537
# 1546   2017    北京    文科  本科一批      555
# 1984   2016    北京    理科  本科一批      548
# 1990   2016    北京    文科  本科一批      583
# 2732   2015    北京    理科  本科一批      548
# 2740   2015    北京    文科  本科一批      579
# 3756   2014    北京    理科  本科一批      543
# 3764   2014    北京    文科  本科一批      565
# 4522   2013    北京    理科  本科一批      550
# 4529   2013    北京    文科  本科一批      549
# 5257   2012    北京    理科  本科一批      477
# 5263   2012    北京    文科  本科一批      495
# 6112   2011    北京    理科  本科一批      484
# 6118   2011    北京    文科  本科一批      524
# 7524   2010    北京    理科  本科一批      494
# 7532   2010    北京    文科  本科一批      524
# 9112   2009    北京    理科  本科一批      501
# 9118   2009    北京    文科  本科一批      532
# 10566  2008    北京    理科  本科一批      502
# 10569  2008    北京    文科  本科一批      515
# ...

# %%
df = pd.read_csv("college_data.csv")
df_new = df.drop_duplicates(subset=['name'])  # 有重复的数据，需要删除
df_site = df_new[df_new['site'] != '——']
df_site = df_site[df_site['site'] != '------']

# 高校总数量分析
site_counts = df_site['site'].value_counts()
dict_site = {'name': site_counts.index, 'counts': site_counts.values}
data = pd.DataFrame(dict_site)

b = (Bar()
    .add_xaxis(data['name'].values.tolist()[:10])
    .add_yaxis("", data['counts'].values.tolist()[:10])
    .set_global_opts(
    xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
    title_opts=opts.TitleOpts(title="各城市高校数量", subtitle=""),
    # datazoom_opts=opts.DataZoomOpts(),
)
    .set_series_opts()
    )
grid = Grid(init_opts=opts.InitOpts(theme=ThemeType.VINTAGE))
grid.add(b, grid_opts=opts.GridOpts(pos_left="20%"))
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="e8e97574663449489ad617f911b42c9d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_e8e97574663449489ad617f911b42c9d = echarts.init(
#                     document.getElementById('e8e97574663449489ad617f911b42c9d'), 'vintage', {renderer: 'canvas'});
#                 var option_e8e97574663449489ad617f911b42c9d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [],
#     "series": [
#         {
# ...

# %%
df_title = df_new[df_new['title'] != '——']
df_985 = df_title[df_title['title'] == '211985']
df_211 = df_title[df_title['title'] == '211']
# 211 985 综合
df_985_211 = pd.concat([df_211, df_985], ignore_index=True)

site_counts_985_211 = df_985_211['site'].value_counts()
dict_site_985_211 = {'name': site_counts_985_211.index, 'counts': site_counts_985_211.values}
data_985_211 = pd.DataFrame(dict_site_985_211)
sum_counts = data_985_211['counts'].sum()
data_985_211['rate'] = data_985_211['counts'].apply(lambda x : x/sum_counts)

# 各城市高质量高校数量
b = (Bar()
    .add_xaxis(data_985_211['name'].values.tolist()[:10])
    .add_yaxis("", data_985_211['counts'].values.tolist()[:10])
    .set_global_opts(
    xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
    title_opts=opts.TitleOpts(title="各城市高质量高校数量", subtitle="统计高质量高校数量"),
)
    .set_series_opts()
      )
grid = Grid(init_opts=opts.InitOpts(theme=ThemeType.VINTAGE))
grid.add(b, grid_opts=opts.GridOpts(pos_left="20%"))
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="0f4dae6839af46189b6e4f4334fc6523" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_0f4dae6839af46189b6e4f4334fc6523 = echarts.init(
#                     document.getElementById('0f4dae6839af46189b6e4f4334fc6523'), 'vintage', {renderer: 'canvas'});
#                 var option_0f4dae6839af46189b6e4f4334fc6523 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [],
#     "series": [
#         {
# ...

# %%
data_985_211['par'] = data_985_211['counts'].apply(lambda x : x/10)

# %%
data_985_211
# Out:
#    name  counts      rate  par
# 0    北京      30  0.225564  3.0
# 1    上海      12  0.090226  1.2
# 2    江苏      11  0.082707  1.1
# 3    陕西       8  0.060150  0.8
# 4    湖北       7  0.052632  0.7
# 5    四川       5  0.037594  0.5
# 6    广东       5  0.037594  0.5
# 7    河北       5  0.037594  0.5
# 8    辽宁       5  0.037594  0.5
# 9    山东       5  0.037594  0.5
# 10   湖南       4  0.030075  0.4
# 11  黑龙江       4  0.030075  0.4
# 12   天津       4  0.030075  0.4
# 13   吉林       3  0.022556  0.3
# 14   重庆       3  0.022556  0.3
# 15   安徽       3  0.022556  0.3
# 16   福建       2  0.015038  0.2
# 17   河南       2  0.015038  0.2
# 18   新疆       2  0.015038  0.2
# 19   浙江       2  0.015038  0.2
# 20   甘肃       1  0.007519  0.1
# 21   青海       1  0.007519  0.1
# 22   江西       1  0.007519  0.1
# 23   西藏       1  0.007519  0.1
# 24   广西       1  0.007519  0.1
# 25   云南       1  0.007519  0.1
# 26   贵州       1  0.007519  0.1
# 27   宁夏       1  0.007519  0.1
# 28  内蒙古       1  0.007519  0.1
# ...

# %%
new_df = pd.merge(data_985_211,num_sort,left_on='name',right_on='province')
new_df['num_par'] = new_df['number'].apply(lambda x : x/10)
new_df['finally_par'] = round(new_df['num_par']/new_df['par'],2)
new_df_sort = new_df.sort_values(by=['finally_par'], ascending=False)
new_df_sort
# Out:
#    name  counts      rate  par province  number  type  num_par  finally_par
# 17   河南       2  0.015038  0.2       河南  125.00     1   12.500        62.50
# 22   江西       1  0.007519  0.1       江西   49.30     1    4.930        49.30
# 24   广西       1  0.007519  0.1       广西   46.00     3    4.600        46.00
# 26   贵州       1  0.007519  0.1       贵州   44.17     3    4.417        44.17
# 25   云南       1  0.007519  0.1       云南   35.80     3    3.580        35.80
# 30   山西       1  0.007519  0.1       山西   31.57     1    3.157        31.57
# 20   甘肃       1  0.007519  0.1       甘肃   24.59     2    2.459        24.59
# 28  内蒙古       1  0.007519  0.1      内蒙古   19.80     2    1.980        19.80
# 15   安徽       3  0.022556  0.3       安徽   54.25     1    5.425        18.08
# 9    山东       5  0.037594  0.5       山东   79.50     4    7.950        15.90
# 19   浙江       2  0.015038  0.2       浙江   31.50     4    3.150        15.75
# ...

# %%
result_num = new_df_sort['finally_par'][:10]
result_pri = new_df_sort['name'][:10]
x_data = result_pri.values.tolist()
y_data = result_num.values.tolist()

# 各城市高质量高校数量
b = (Bar()
    .add_xaxis(x_data)
    .add_yaxis("", y_data)
    .set_global_opts(
    xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
    title_opts=opts.TitleOpts(title="各城市高考难度前十", subtitle=""),
)
    .set_series_opts()
      )
grid = Grid(init_opts=opts.InitOpts(theme=ThemeType.VINTAGE))
grid.add(b, grid_opts=opts.GridOpts(pos_left="20%"))
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="f0e15542df99408ebf71d46acd0ad03e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_f0e15542df99408ebf71d46acd0ad03e = echarts.init(
#                     document.getElementById('f0e15542df99408ebf71d46acd0ad03e'), 'vintage', {renderer: 'canvas'});
#                 var option_f0e15542df99408ebf71d46acd0ad03e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [],
#     "series": [
#         {
# ...

# %%
result_num = new_df_sort['finally_par'][-10:]
result_pri = new_df_sort['name'][-10:]
x_data = result_pri.values.tolist()
y_data = result_num.values.tolist()

# 各城市高质量高校数量
b = (Bar()
    .add_xaxis(x_data)
    .add_yaxis("", y_data)
    .set_global_opts(
    xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
    title_opts=opts.TitleOpts(title="各城市高考难度后十", subtitle=""),
)
    .set_series_opts()
      )
grid = Grid(init_opts=opts.InitOpts(theme=ThemeType.VINTAGE))
grid.add(b, grid_opts=opts.GridOpts(pos_left="20%"))
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="ddd16e4926784bc1b71f6e32ffdde32c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_ddd16e4926784bc1b71f6e32ffdde32c = echarts.init(
#                     document.getElementById('ddd16e4926784bc1b71f6e32ffdde32c'), 'vintage', {renderer: 'canvas'});
#                 var option_ddd16e4926784bc1b71f6e32ffdde32c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [],
#     "series": [
#         {
# ...

# %%
# 高高考难度分布热力图
geo = Geo()
geo.add_schema(maptype="china")
geo.add("高考难度分布热力图", [list(z) for z in zip(new_df_sort['name'].values.tolist(), new_df_sort['finally_par'].values.tolist())],
       type_=ChartType.HEATMAP)
geo.set_global_opts(
            visualmap_opts=opts.VisualMapOpts(max_=65),
            title_opts=opts.TitleOpts(title="高考难度分布热力图"),
        )
geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="d8ec1ef960694e57ba86bd04e438fc82" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_d8ec1ef960694e57ba86bd04e438fc82 = echarts.init(
#                     document.getElementById('d8ec1ef960694e57ba86bd04e438fc82'), 'white', {renderer: 'canvas'});
#                 var option_d8ec1ef960694e57ba86bd04e438fc82 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
c = (
    Map()
    .add("高考难度地图", [list(z) for z in zip(new_df_sort['name'].values.tolist(), new_df_sort['finally_par'].values.tolist())], "china")
    .set_global_opts(
        title_opts=opts.TitleOpts(title="高考难度地图"),
        visualmap_opts=opts.VisualMapOpts(max_=65),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="72bf0c5d60ea413483f200ce6d957dd0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_72bf0c5d60ea413483f200ce6d957dd0 = echarts.init(
#                     document.getElementById('72bf0c5d60ea413483f200ce6d957dd0'), 'white', {renderer: 'canvas'});
#                 var option_72bf0c5d60ea413483f200ce6d957dd0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
# 高质量高校分布热力图
geo = Geo()
geo.add_schema(maptype="china")
geo.add("高质量高校分布热力图", [list(z) for z in zip(data_985_211['name'].values.tolist(), data_985_211['counts'].values.tolist())],
       type_=ChartType.HEATMAP)
geo.set_global_opts(
            visualmap_opts=opts.VisualMapOpts(max_=30),
            title_opts=opts.TitleOpts(title="高质量高校分布热力图"),
        )
geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="e4d20dacbd1b46deb66463e9d14185e0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_e4d20dacbd1b46deb66463e9d14185e0 = echarts.init(
#                     document.getElementById('e4d20dacbd1b46deb66463e9d14185e0'), 'white', {renderer: 'canvas'});
#                 var option_e4d20dacbd1b46deb66463e9d14185e0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...
