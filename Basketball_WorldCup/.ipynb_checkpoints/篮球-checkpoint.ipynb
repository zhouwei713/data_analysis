# %%
import pandas as pd

# %%
points = pd.read_csv('PointsAverage_data.csv')

# %%
points
# Out:
#        name country  points  rebounds  steals  assists  fouls  plus_minus  \
# 0       罗建儿      韩国    23.0      12.8     1.4      1.8    1.8       -14.2
# 1    博格达诺维奇    塞尔维亚    22.9       4.1     1.3      4.4    1.3        12.5
# 2    K-韦伯斯特     新西兰    22.8       4.6     1.0      5.6    2.0         8.0
# 3       米尔斯    澳大利亚    22.5       2.4     0.8      3.9    1.6         7.1
# 4        塔克      约旦    21.0       4.8     1.2      1.2    1.4       -20.2
# 5       奥斯曼     土耳其    20.4       3.2     1.4      2.6    2.8         4.4
# 6       富尼耶      法国    19.8       3.8     0.9      3.0    2.5         8.1
# 7       施罗德      德国    19.6       4.6     1.4      9.4    1.4         9.8
# 8     马穆托格鲁     土耳其    18.6       1.6     0.8      1.0    0.8         4.8
# 9        弗图     新西兰    18.4       6.0     0.2      1.6    2.4         9.8
# 10      斯科拉     阿根廷    17.9       8.1     0.8      1.8    3.0        12.9
# 11      易建联      中国    17.8       7.8     1.0      1.2    2.4         0.4
# 12     加里纳利     意大利    17.2       5.6     1.0      2.8    1.6        10.8
# 13     德-科洛      法国    16.5       1.6     0.9      3.4    2.3         5.9
# 14      卢比奥     西班牙    16.4       4.6     1.5      6.0    2.3        12.0
# 15      威尔彻     加拿大    16.4       3.0     0.6      1.0    1.2         4.0
# 16    阿尔迪瓦里      约旦    16.3       7.5     0.5      1.5    2.0       -25.2
# 17      梅杰里     突尼斯    16.2      10.2     1.0      2.4    2.8         1.0
# 18    伊利亚索瓦     土耳其    16.0       9.3     1.7      2.0    3.3         6.7
# 19      布拉切     菲律宾    15.8       8.4     2.4      3.4    3.6       -24.4
# 20     渡边雄太      日本    15.6       5.6     0.8      1.6    1.8       -22.8
# 21    萨托兰斯基      捷克    15.5       5.6     0.9      8.5    1.8         1.9
# 22     博哈西克      捷克    15.3       4.0     0.3      2.4    3.1         0.6
# 23     贝里内利     意大利    15.0       4.0     1.2      3.2    1.6        11.6
# 24      约瑟夫     加拿大    15.0       3.6     1.4      4.8    2.6         5.0
# 25  G-阿德托昆博      希腊    14.8       8.8     2.4      2.4    3.6         6.6
# 26      哈达迪      伊朗    14.6      10.8     0.6      4.4    3.0        -2.0
# 27     武切维奇      黑山    14.6       6.4     0.8      1.2    1.2        -2.4
# 28       沃克      美国    14.4       3.0     0.9      5.4    2.3        11.3
# 29      加索尔     西班牙    14.4       5.5     1.1      4.1    1.9        13.6
# 30     费泽卡斯      日本    14.4       7.4     1.0      1.2    1.6       -18.8
# 31     胡尔塔斯    波多黎各    14.2       1.8     0.2      2.0    2.0        -5.6
# 32       罗尔     突尼斯    14.2       2.2     1.0      3.8    2.4         3.8
# 33    瓦兰丘纳斯     立陶宛    14.0       8.8     1.0      1.0    2.6        12.0
# 34     瓦奇斯基      波兰    13.9       2.6     0.6      2.8    1.8        -2.4
# 35       戴克     阿根廷    13.9       3.1     1.1      0.9    1.8         5.2
# 36      巴博萨      巴西    13.6       1.6     0.6      2.2    2.0        -2.0
# 37      波尼卡      波兰    13.5       6.8     1.4      1.6    2.4        -2.5
# 38     卡拉希斯      希腊    13.4       4.2     1.6      5.4    2.6         5.4
# 39      阿布沃    科特迪瓦    13.4       3.0     1.0      1.6    1.4        -8.2
# 40   T-韦伯斯特     新西兰    13.4       3.8     0.4      4.4    3.6         4.8
# 41     斯劳特尔      波兰    13.3       2.8     0.9      4.8    1.5        -3.1
# 42      坎帕佐     阿根廷    13.3       4.3     2.0      7.8    1.9        13.2
# 43      八村垒      日本    13.3       5.7     1.7      2.3    2.7       -23.7
# 44      汤普森    科特迪瓦    13.2       6.4     1.0      1.6    1.6       -14.4
# 45      米切尔      美国    13.1       4.3     1.1      5.0    2.0        12.0
# 46       利兹    多米尼加    13.0       2.8     1.4      2.0    1.4        -8.0
# 47    莱卡维丘斯     立陶宛    13.0       1.6     1.0      1.8    1.8         8.4
# 48       吉扬    委内瑞拉    13.0       2.0     1.0      6.2    1.4         2.2
# 49    本-鲁姆赞     突尼斯    13.0       7.2     1.8      3.6    3.2         6.0
#
#     blocked  goals_percentage  turnovers
# 0       1.2              49.5        2.4
# 1       0.3              55.6        1.4
# 2       0.0              54.2        1.6
# 3       0.3              49.6        3.5
# 4       0.2              42.1        3.0
# 5       0.4              50.0        1.4
# 6       0.1              42.0        1.9
# 7       0.2              41.4        3.4
# 8       0.0              57.8        0.8
# 9       0.0              66.7        1.6
# 10      0.4              43.4        1.9
# 11      0.6              51.7        2.6
# 12      0.4              53.1        1.0
# 13      0.0              54.5        2.3
# 14      0.0              43.6        3.5
# 15      0.0              48.3        1.0
# 16      0.0              60.5        2.0
# 17      3.2              54.4        2.2
# 18      1.0              36.4        1.7
# 19      0.6              40.0        4.4
# 20      0.4              44.6        1.2
# 21      0.4              45.7        2.8
# 22      0.1              44.6        1.5
# 23      0.0              40.0        1.6
# 24      0.0              46.0        1.8
# 25      0.6              52.2        2.6
# 26      1.2              47.5        4.4
# 27      0.6              47.6        1.6
# 28      0.3              48.6        1.7
# 29      1.1              42.5        1.8
# 30      0.2              48.3        1.8
# 31      0.2              47.4        1.6
# 32      0.0              46.0        1.4
# 33      1.6              64.3        1.0
# 34      0.1              42.5        1.8
# 35      0.1              56.0        0.9
# 36      0.2              43.6        1.6
# 37      0.9              50.0        2.4
# 38      0.0              49.1        2.6
# 39      0.0              44.6        1.6
# 40      0.0              43.6        4.0
# 41      0.1              39.8        2.0
# 42      0.1              41.8        2.6
# 43      0.0              43.3        1.3
# 44      0.6              47.2        2.2
# 45      0.4              46.6        1.0
# 46      0.2              37.7        3.4
# 47      0.0              64.9        1.2
# 48      0.0              42.6        1.6
# 49      0.4              51.0        1.6

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.commons.utils import JsCode

# %%
# points_data = points.groupby(['name', 'country'])['points'].sum().sort_values(ascending=False)
points_data = points.groupby(['name', 'country'])['points', 'rebounds'].sum().sort_values(by='points', ascending=False)
points_data_index = points_data['points'].index.values.tolist()[:15]
points_data_value = points_data['points'].values.tolist()[:15]
points_data_rebounds_value = points_data['rebounds'].values.tolist()[:15]
points_data_rebounds_value
# Out:
# [12.8, 4.1, 4.6, 2.4, 4.8, 3.2, 3.8, 4.6, 1.6, 6.0, 8.1, 7.8, 5.6, 1.6, 4.6]

# %%
bar = Bar()
bar.add_xaxis(points_data_index)
bar.add_yaxis("", points_data_value, category_gap="60%")
bar.set_global_opts(title_opts=opts.TitleOpts(title='得分排名'),
                   xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-20)),
                   datazoom_opts=opts.DataZoomOpts())
bar.set_series_opts(itemstyle_opts={
            "normal": {
                "color": JsCode("""new echarts.graphic.LinearGradient(0, 0, 0, 1, [{
                    offset: 0,
                    color: 'rgba(0, 244, 255, 1)'
                }, {
                    offset: 1,
                    color: 'rgba(0, 77, 167, 1)'
                }], false)"""),
                "barBorderRadius": [30, 30, 30, 30],
                "shadowColor": 'rgb(0, 160, 221)',
            }})
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="78caaea555ca4c1eb2fa69ef65cbeaaa" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_78caaea555ca4c1eb2fa69ef65cbeaaa = echarts.init(
#             document.getElementById('78caaea555ca4c1eb2fa69ef65cbeaaa'), 'white', {renderer: 'canvas'});
#         var option_78caaea555ca4c1eb2fa69ef65cbeaaa = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 23.0,
#                 22.9,
#                 22.8,
#                 22.5,
#                 21.0,
#                 20.4,
#                 19.8,
#                 19.6,
#                 18.6,
#                 18.4,
#                 17.9,
#                 17.8,
#                 17.2,
#                 16.5,
#                 16.4
#             ],
#             "barCategoryGap": "60%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {
#                     "color": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{                    offset: 0,                    color: 'rgba(0, 244, 255, 1)'                }, {                    offset: 1,                    color: 'rgba(0, 77, 167, 1)'                }], false),
#                     "barBorderRadius": [
#                         30,
#                         30,
#                         30,
#                         30
#                     ],
#                     "shadowColor": "rgb(0, 160, 221)"
#                 }
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -20,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 [
#                     "\u7f57\u5efa\u513f",
#                     "\u97e9\u56fd"
#                 ],
#                 [
#                     "\u535a\u683c\u8fbe\u8bfa\u7ef4\u5947",
#                     "\u585e\u5c14\u7ef4\u4e9a"
#                 ],
#                 [
#                     "K-\u97e6\u4f2f\u65af\u7279",
#                     "\u65b0\u897f\u5170"
#                 ],
#                 [
#                     "\u7c73\u5c14\u65af",
#                     "\u6fb3\u5927\u5229\u4e9a"
#                 ],
#                 [
#                     "\u5854\u514b",
#                     "\u7ea6\u65e6"
#                 ],
#                 [
#                     "\u5965\u65af\u66fc",
#                     "\u571f\u8033\u5176"
#                 ],
#                 [
#                     "\u5bcc\u5c3c\u8036",
#                     "\u6cd5\u56fd"
#                 ],
#                 [
#                     "\u65bd\u7f57\u5fb7",
#                     "\u5fb7\u56fd"
#                 ],
#                 [
#                     "\u9a6c\u7a46\u6258\u683c\u9c81",
#                     "\u571f\u8033\u5176"
#                 ],
#                 [
#                     "\u5f17\u56fe",
#                     "\u65b0\u897f\u5170"
#                 ],
#                 [
#                     "\u65af\u79d1\u62c9",
#                     "\u963f\u6839\u5ef7"
#                 ],
#                 [
#                     "\u6613\u5efa\u8054",
#                     "\u4e2d\u56fd"
#                 ],
#                 [
#                     "\u52a0\u91cc\u7eb3\u5229",
#                     "\u610f\u5927\u5229"
#                 ],
#                 [
#                     "\u5fb7-\u79d1\u6d1b",
#                     "\u6cd5\u56fd"
#                 ],
#                 [
#                     "\u5362\u6bd4\u5965",
#                     "\u897f\u73ed\u7259"
#                 ]
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5f97\u5206\u6392\u540d"
#         }
#     ],
#     "dataZoom": {
#         "show": true,
#         "type": "slider",
#         "realtime": true,
#         "start": 20,
#         "end": 80,
#         "orient": "horizontal",
#         "zoomLock": false
#     }
# };
#         chart_78caaea555ca4c1eb2fa69ef65cbeaaa.setOption(option_78caaea555ca4c1eb2fa69ef65cbeaaa);
#     });
# </script>

# %%
rebounds_data = points.groupby(['name', 'country'])['points', 'rebounds'].sum().sort_values(by='rebounds', ascending=False)
rebounds_data_index = rebounds_data['rebounds'].index.values.tolist()[:15]
rebounds_data_value = rebounds_data['rebounds'].values.tolist()[:15]
rebounds_data_rebounds_value = rebounds_data['rebounds'].values.tolist()[:15]
points_data_rebounds_value
# Out:
# [12.8, 10.8, 10.2, 9.3, 8.8, 8.8, 8.4, 8.1, 7.8, 7.5, 7.4, 7.2, 6.8, 6.4, 6.4]

# %%
bar = Bar()
bar.add_xaxis(rebounds_data_index)
bar.add_yaxis("", rebounds_data_rebounds_value, category_gap="60%")
bar.set_global_opts(title_opts=opts.TitleOpts(title='篮板排名'),
                   xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-20)),
                   datazoom_opts=opts.DataZoomOpts())
bar.set_series_opts(itemstyle_opts={
            "normal": {
                "color": JsCode("""new echarts.graphic.LinearGradient(0, 0, 0, 1, [{
                    offset: 0,
                    color: 'rgba(0, 244, 255, 1)'
                }, {
                    offset: 1,
                    color: 'rgba(0, 77, 167, 1)'
                }], false)"""),
                "barBorderRadius": [30, 30, 30, 30],
                "shadowColor": 'rgb(0, 160, 221)',
            }})
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="98ca15392c014299b0cc9f5a44b43659" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_98ca15392c014299b0cc9f5a44b43659 = echarts.init(
#             document.getElementById('98ca15392c014299b0cc9f5a44b43659'), 'white', {renderer: 'canvas'});
#         var option_98ca15392c014299b0cc9f5a44b43659 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 12.8,
#                 10.8,
#                 10.2,
#                 9.3,
#                 8.8,
#                 8.8,
#                 8.4,
#                 8.1,
#                 7.8,
#                 7.5,
#                 7.4,
#                 7.2,
#                 6.8,
#                 6.4,
#                 6.4
#             ],
#             "barCategoryGap": "60%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {
#                     "color": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{                    offset: 0,                    color: 'rgba(0, 244, 255, 1)'                }, {                    offset: 1,                    color: 'rgba(0, 77, 167, 1)'                }], false),
#                     "barBorderRadius": [
#                         30,
#                         30,
#                         30,
#                         30
#                     ],
#                     "shadowColor": "rgb(0, 160, 221)"
#                 }
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -20,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 [
#                     "\u7f57\u5efa\u513f",
#                     "\u97e9\u56fd"
#                 ],
#                 [
#                     "\u54c8\u8fbe\u8fea",
#                     "\u4f0a\u6717"
#                 ],
#                 [
#                     "\u6885\u6770\u91cc",
#                     "\u7a81\u5c3c\u65af"
#                 ],
#                 [
#                     "\u4f0a\u5229\u4e9a\u7d22\u74e6",
#                     "\u571f\u8033\u5176"
#                 ],
#                 [
#                     "G-\u963f\u5fb7\u6258\u6606\u535a",
#                     "\u5e0c\u814a"
#                 ],
#                 [
#                     "\u74e6\u5170\u4e18\u7eb3\u65af",
#                     "\u7acb\u9676\u5b9b"
#                 ],
#                 [
#                     "\u5e03\u62c9\u5207",
#                     "\u83f2\u5f8b\u5bbe"
#                 ],
#                 [
#                     "\u65af\u79d1\u62c9",
#                     "\u963f\u6839\u5ef7"
#                 ],
#                 [
#                     "\u6613\u5efa\u8054",
#                     "\u4e2d\u56fd"
#                 ],
#                 [
#                     "\u963f\u5c14\u8fea\u74e6\u91cc",
#                     "\u7ea6\u65e6"
#                 ],
#                 [
#                     "\u8d39\u6cfd\u5361\u65af",
#                     "\u65e5\u672c"
#                 ],
#                 [
#                     "\u672c-\u9c81\u59c6\u8d5e",
#                     "\u7a81\u5c3c\u65af"
#                 ],
#                 [
#                     "\u6ce2\u5c3c\u5361",
#                     "\u6ce2\u5170"
#                 ],
#                 [
#                     "\u6c64\u666e\u68ee",
#                     "\u79d1\u7279\u8fea\u74e6"
#                 ],
#                 [
#                     "\u6b66\u5207\u7ef4\u5947",
#                     "\u9ed1\u5c71"
#                 ]
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u7bee\u677f\u6392\u540d"
#         }
#     ],
#     "dataZoom": {
#         "show": true,
#         "type": "slider",
#         "realtime": true,
#         "start": 20,
#         "end": 80,
#         "orient": "horizontal",
#         "zoomLock": false
#     }
# };
#         chart_98ca15392c014299b0cc9f5a44b43659.setOption(option_98ca15392c014299b0cc9f5a44b43659);
#     });
# </script>

# %%
bar = Bar()
bar.add_xaxis(points_data_index)
bar.add_yaxis("", points_data_value, gap="0%")
bar.add_yaxis("", points_data_rebounds_value, gap="0%")
bar.set_global_opts(title_opts=opts.TitleOpts(title='得分排名和篮板'),
                   xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-20)),
                   datazoom_opts=opts.DataZoomOpts())
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="72e24bee406d49e981974f45b1d5d329" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_72e24bee406d49e981974f45b1d5d329 = echarts.init(
#             document.getElementById('72e24bee406d49e981974f45b1d5d329'), 'white', {renderer: 'canvas'});
#         var option_72e24bee406d49e981974f45b1d5d329 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 23.0,
#                 22.9,
#                 22.8,
#                 22.5,
#                 21.0,
#                 20.4,
#                 19.8,
#                 19.6,
#                 18.6,
#                 18.4,
#                 17.9,
#                 17.8,
#                 17.2,
#                 16.5,
#                 16.4
#             ],
#             "barCategoryGap": "20%",
#             "barGap": "0%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "data": [
#                 12.8,
#                 4.1,
#                 4.6,
#                 2.4,
#                 4.8,
#                 3.2,
#                 3.8,
#                 4.6,
#                 1.6,
#                 6.0,
#                 8.1,
#                 7.8,
#                 5.6,
#                 1.6,
#                 4.6
#             ],
#             "barCategoryGap": "20%",
#             "barGap": "0%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "",
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -20,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 [
#                     "\u7f57\u5efa\u513f",
#                     "\u97e9\u56fd"
#                 ],
#                 [
#                     "\u535a\u683c\u8fbe\u8bfa\u7ef4\u5947",
#                     "\u585e\u5c14\u7ef4\u4e9a"
#                 ],
#                 [
#                     "K-\u97e6\u4f2f\u65af\u7279",
#                     "\u65b0\u897f\u5170"
#                 ],
#                 [
#                     "\u7c73\u5c14\u65af",
#                     "\u6fb3\u5927\u5229\u4e9a"
#                 ],
#                 [
#                     "\u5854\u514b",
#                     "\u7ea6\u65e6"
#                 ],
#                 [
#                     "\u5965\u65af\u66fc",
#                     "\u571f\u8033\u5176"
#                 ],
#                 [
#                     "\u5bcc\u5c3c\u8036",
#                     "\u6cd5\u56fd"
#                 ],
#                 [
#                     "\u65bd\u7f57\u5fb7",
#                     "\u5fb7\u56fd"
#                 ],
#                 [
#                     "\u9a6c\u7a46\u6258\u683c\u9c81",
#                     "\u571f\u8033\u5176"
#                 ],
#                 [
#                     "\u5f17\u56fe",
#                     "\u65b0\u897f\u5170"
#                 ],
#                 [
#                     "\u65af\u79d1\u62c9",
#                     "\u963f\u6839\u5ef7"
#                 ],
#                 [
#                     "\u6613\u5efa\u8054",
#                     "\u4e2d\u56fd"
#                 ],
#                 [
#                     "\u52a0\u91cc\u7eb3\u5229",
#                     "\u610f\u5927\u5229"
#                 ],
#                 [
#                     "\u5fb7-\u79d1\u6d1b",
#                     "\u6cd5\u56fd"
#                 ],
#                 [
#                     "\u5362\u6bd4\u5965",
#                     "\u897f\u73ed\u7259"
#                 ]
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5f97\u5206\u6392\u540d\u548c\u7bee\u677f"
#         }
#     ],
#     "dataZoom": {
#         "show": true,
#         "type": "slider",
#         "realtime": true,
#         "start": 20,
#         "end": 80,
#         "orient": "horizontal",
#         "zoomLock": false
#     }
# };
#         chart_72e24bee406d49e981974f45b1d5d329.setOption(option_72e24bee406d49e981974f45b1d5d329);
#     });
# </script>

# %%
the_best_lineup = [
    '博格达诺维奇',
    '富尼耶',
    '卢比奥',
    '斯科拉',
    '加索尔'
]

# %%
points
# Out:
#        name country  points  rebounds  steals  assists  fouls  plus_minus  \
# 0       罗建儿      韩国    23.0      12.8     1.4      1.8    1.8       -14.2
# 1    博格达诺维奇    塞尔维亚    22.9       4.1     1.3      4.4    1.3        12.5
# 2    K-韦伯斯特     新西兰    22.8       4.6     1.0      5.6    2.0         8.0
# 3       米尔斯    澳大利亚    22.5       2.4     0.8      3.9    1.6         7.1
# 4        塔克      约旦    21.0       4.8     1.2      1.2    1.4       -20.2
# 5       奥斯曼     土耳其    20.4       3.2     1.4      2.6    2.8         4.4
# 6       富尼耶      法国    19.8       3.8     0.9      3.0    2.5         8.1
# 7       施罗德      德国    19.6       4.6     1.4      9.4    1.4         9.8
# 8     马穆托格鲁     土耳其    18.6       1.6     0.8      1.0    0.8         4.8
# 9        弗图     新西兰    18.4       6.0     0.2      1.6    2.4         9.8
# 10      斯科拉     阿根廷    17.9       8.1     0.8      1.8    3.0        12.9
# 11      易建联      中国    17.8       7.8     1.0      1.2    2.4         0.4
# 12     加里纳利     意大利    17.2       5.6     1.0      2.8    1.6        10.8
# 13     德-科洛      法国    16.5       1.6     0.9      3.4    2.3         5.9
# 14      卢比奥     西班牙    16.4       4.6     1.5      6.0    2.3        12.0
# 15      威尔彻     加拿大    16.4       3.0     0.6      1.0    1.2         4.0
# 16    阿尔迪瓦里      约旦    16.3       7.5     0.5      1.5    2.0       -25.2
# 17      梅杰里     突尼斯    16.2      10.2     1.0      2.4    2.8         1.0
# 18    伊利亚索瓦     土耳其    16.0       9.3     1.7      2.0    3.3         6.7
# 19      布拉切     菲律宾    15.8       8.4     2.4      3.4    3.6       -24.4
# 20     渡边雄太      日本    15.6       5.6     0.8      1.6    1.8       -22.8
# 21    萨托兰斯基      捷克    15.5       5.6     0.9      8.5    1.8         1.9
# 22     博哈西克      捷克    15.3       4.0     0.3      2.4    3.1         0.6
# 23     贝里内利     意大利    15.0       4.0     1.2      3.2    1.6        11.6
# 24      约瑟夫     加拿大    15.0       3.6     1.4      4.8    2.6         5.0
# 25  G-阿德托昆博      希腊    14.8       8.8     2.4      2.4    3.6         6.6
# 26      哈达迪      伊朗    14.6      10.8     0.6      4.4    3.0        -2.0
# 27     武切维奇      黑山    14.6       6.4     0.8      1.2    1.2        -2.4
# 28       沃克      美国    14.4       3.0     0.9      5.4    2.3        11.3
# 29      加索尔     西班牙    14.4       5.5     1.1      4.1    1.9        13.6
# 30     费泽卡斯      日本    14.4       7.4     1.0      1.2    1.6       -18.8
# 31     胡尔塔斯    波多黎各    14.2       1.8     0.2      2.0    2.0        -5.6
# 32       罗尔     突尼斯    14.2       2.2     1.0      3.8    2.4         3.8
# 33    瓦兰丘纳斯     立陶宛    14.0       8.8     1.0      1.0    2.6        12.0
# 34     瓦奇斯基      波兰    13.9       2.6     0.6      2.8    1.8        -2.4
# 35       戴克     阿根廷    13.9       3.1     1.1      0.9    1.8         5.2
# 36      巴博萨      巴西    13.6       1.6     0.6      2.2    2.0        -2.0
# 37      波尼卡      波兰    13.5       6.8     1.4      1.6    2.4        -2.5
# 38     卡拉希斯      希腊    13.4       4.2     1.6      5.4    2.6         5.4
# 39      阿布沃    科特迪瓦    13.4       3.0     1.0      1.6    1.4        -8.2
# 40   T-韦伯斯特     新西兰    13.4       3.8     0.4      4.4    3.6         4.8
# 41     斯劳特尔      波兰    13.3       2.8     0.9      4.8    1.5        -3.1
# 42      坎帕佐     阿根廷    13.3       4.3     2.0      7.8    1.9        13.2
# 43      八村垒      日本    13.3       5.7     1.7      2.3    2.7       -23.7
# 44      汤普森    科特迪瓦    13.2       6.4     1.0      1.6    1.6       -14.4
# 45      米切尔      美国    13.1       4.3     1.1      5.0    2.0        12.0
# 46       利兹    多米尼加    13.0       2.8     1.4      2.0    1.4        -8.0
# 47    莱卡维丘斯     立陶宛    13.0       1.6     1.0      1.8    1.8         8.4
# 48       吉扬    委内瑞拉    13.0       2.0     1.0      6.2    1.4         2.2
# 49    本-鲁姆赞     突尼斯    13.0       7.2     1.8      3.6    3.2         6.0
#
#     blocked  goals_percentage  turnovers
# 0       1.2              49.5        2.4
# 1       0.3              55.6        1.4
# 2       0.0              54.2        1.6
# 3       0.3              49.6        3.5
# 4       0.2              42.1        3.0
# 5       0.4              50.0        1.4
# 6       0.1              42.0        1.9
# 7       0.2              41.4        3.4
# 8       0.0              57.8        0.8
# 9       0.0              66.7        1.6
# 10      0.4              43.4        1.9
# 11      0.6              51.7        2.6
# 12      0.4              53.1        1.0
# 13      0.0              54.5        2.3
# 14      0.0              43.6        3.5
# 15      0.0              48.3        1.0
# 16      0.0              60.5        2.0
# 17      3.2              54.4        2.2
# 18      1.0              36.4        1.7
# 19      0.6              40.0        4.4
# 20      0.4              44.6        1.2
# 21      0.4              45.7        2.8
# 22      0.1              44.6        1.5
# 23      0.0              40.0        1.6
# 24      0.0              46.0        1.8
# 25      0.6              52.2        2.6
# 26      1.2              47.5        4.4
# 27      0.6              47.6        1.6
# 28      0.3              48.6        1.7
# 29      1.1              42.5        1.8
# 30      0.2              48.3        1.8
# 31      0.2              47.4        1.6
# 32      0.0              46.0        1.4
# 33      1.6              64.3        1.0
# 34      0.1              42.5        1.8
# 35      0.1              56.0        0.9
# 36      0.2              43.6        1.6
# 37      0.9              50.0        2.4
# 38      0.0              49.1        2.6
# 39      0.0              44.6        1.6
# 40      0.0              43.6        4.0
# 41      0.1              39.8        2.0
# 42      0.1              41.8        2.6
# 43      0.0              43.3        1.3
# 44      0.6              47.2        2.2
# 45      0.4              46.6        1.0
# 46      0.2              37.7        3.4
# 47      0.0              64.9        1.2
# 48      0.0              42.6        1.6
# 49      0.4              51.0        1.6

# %%
bgdnwq = points[points['name'] == '博格达诺维奇']
fny = points[points['name'] == '富尼耶']
lba = points[points['name'] == '卢比奥']
skl = points[points['name'] == '斯科拉']
jse = points[points['name'] == '加索尔']

bgdnwq_goals_percentage = bgdnwq['goals_percentage'].values.tolist()[0]
fny_goals_percentage = fny['goals_percentage'].values.tolist()[0]
lba_goals_percentage = lba['goals_percentage'].values.tolist()[0]
skl_goals_percentage = skl['goals_percentage'].values.tolist()[0]
jse_goals_percentage = jse['goals_percentage'].values.tolist()[0]

bgdnwq_plus_minus = bgdnwq['plus_minus'].values.tolist()[0]
fny_plus_minus = fny['plus_minus'].values.tolist()[0]
lba_plus_minus = lba['plus_minus'].values.tolist()[0]
skl_plus_minus = skl['plus_minus'].values.tolist()[0]
jse_plus_minus = jse['plus_minus'].values.tolist()[0]

# %%
from pyecharts.charts import Radar

# %%
bgdnwq_list = [[bgdnwq['points'].values.tolist()[0], 
           bgdnwq['rebounds'].values.tolist()[0], 
           bgdnwq['assists'].values.tolist()[0], 
           bgdnwq['steals'].values.tolist()[0], 
           bgdnwq['blocked'].values.tolist()[0], 
           bgdnwq['fouls'].values.tolist()[0], 
           bgdnwq['turnovers'].values.tolist()[0]]]
fny_list = [[fny['points'].values.tolist()[0], 
           fny['rebounds'].values.tolist()[0], 
           fny['assists'].values.tolist()[0], 
           fny['steals'].values.tolist()[0], 
           fny['blocked'].values.tolist()[0], 
           fny['fouls'].values.tolist()[0], 
           fny['turnovers'].values.tolist()[0]]]
lba_list = [[lba['points'].values.tolist()[0], 
           lba['rebounds'].values.tolist()[0], 
           lba['assists'].values.tolist()[0], 
           lba['steals'].values.tolist()[0], 
           lba['blocked'].values.tolist()[0], 
           lba['fouls'].values.tolist()[0], 
           lba['turnovers'].values.tolist()[0]]]
skl_list = [[skl['points'].values.tolist()[0], 
           skl['rebounds'].values.tolist()[0], 
           skl['assists'].values.tolist()[0], 
           skl['steals'].values.tolist()[0], 
           skl['blocked'].values.tolist()[0], 
           skl['fouls'].values.tolist()[0], 
           skl['turnovers'].values.tolist()[0]]]
jse_list = [[jse['points'].values.tolist()[0], 
           jse['rebounds'].values.tolist()[0], 
           jse['assists'].values.tolist()[0], 
           jse['steals'].values.tolist()[0], 
           jse['blocked'].values.tolist()[0], 
           jse['fouls'].values.tolist()[0], 
           jse['turnovers'].values.tolist()[0]]]
radar = Radar()
radar.add_schema(
    schema=[
        opts.RadarIndicatorItem(name='得分', max_=30),
        opts.RadarIndicatorItem(name="篮板", max_=15),
        opts.RadarIndicatorItem(name="助攻", max_=10),
        opts.RadarIndicatorItem(name="抢断", max_=5),
        opts.RadarIndicatorItem(name="封盖", max_=5),
        opts.RadarIndicatorItem(name="犯规", max_=5),
        opts.RadarIndicatorItem(name="失误", max_=5),
    ]
)
radar.add("博格达诺维奇", bgdnwq_list)
radar.add("富尼耶", fny_list)
radar.add("卢比奥", lba_list)
radar.add("斯科拉", skl_list)
radar.add("加索尔", jse_list)
# radar.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
radar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="4833330dc0d1485aa9d892f3cc740591" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_4833330dc0d1485aa9d892f3cc740591 = echarts.init(
#             document.getElementById('4833330dc0d1485aa9d892f3cc740591'), 'white', {renderer: 'canvas'});
#         var option_4833330dc0d1485aa9d892f3cc740591 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "radar",
#             "name": "\u535a\u683c\u8fbe\u8bfa\u7ef4\u5947",
#             "data": [
#                 [
#                     22.9,
#                     4.1,
#                     4.4,
#                     1.3,
#                     0.3,
#                     1.3,
#                     1.4
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u5bcc\u5c3c\u8036",
#             "data": [
#                 [
#                     19.8,
#                     3.8,
#                     3.0,
#                     0.9,
#                     0.1,
#                     2.5,
#                     1.9
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u5362\u6bd4\u5965",
#             "data": [
#                 [
#                     16.4,
#                     4.6,
#                     6.0,
#                     1.5,
#                     0.0,
#                     2.3,
#                     3.5
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u65af\u79d1\u62c9",
#             "data": [
#                 [
#                     17.9,
#                     8.1,
#                     1.8,
#                     0.8,
#                     0.4,
#                     3.0,
#                     1.9
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u52a0\u7d22\u5c14",
#             "data": [
#                 [
#                     14.4,
#                     5.5,
#                     4.1,
#                     1.1,
#                     1.1,
#                     1.9,
#                     1.8
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u535a\u683c\u8fbe\u8bfa\u7ef4\u5947",
#                 "\u5bcc\u5c3c\u8036",
#                 "\u5362\u6bd4\u5965",
#                 "\u65af\u79d1\u62c9",
#                 "\u52a0\u7d22\u5c14"
#             ],
#             "selected": {
#                 "\u535a\u683c\u8fbe\u8bfa\u7ef4\u5947": true,
#                 "\u5bcc\u5c3c\u8036": true,
#                 "\u5362\u6bd4\u5965": true,
#                 "\u65af\u79d1\u62c9": true,
#                 "\u52a0\u7d22\u5c14": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "radar": {
#         "indicator": [
#             {
#                 "name": "\u5f97\u5206",
#                 "max": 30
#             },
#             {
#                 "name": "\u7bee\u677f",
#                 "max": 15
#             },
#             {
#                 "name": "\u52a9\u653b",
#                 "max": 10
#             },
#             {
#                 "name": "\u62a2\u65ad",
#                 "max": 5
#             },
#             {
#                 "name": "\u5c01\u76d6",
#                 "max": 5
#             },
#             {
#                 "name": "\u72af\u89c4",
#                 "max": 5
#             },
#             {
#                 "name": "\u5931\u8bef",
#                 "max": 5
#             }
#         ],
#         "name": {
#             "textStyle": {}
#         },
#         "splitLine": {
#             "show": true,
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             }
#         },
#         "splitArea": {
#             "show": true,
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         "axisLine": {
#             "show": true,
#             "onZero": true,
#             "onZeroAxisIndex": 0
#         }
#     }
# };
#         chart_4833330dc0d1485aa9d892f3cc740591.setOption(option_4833330dc0d1485aa9d892f3cc740591);
#     });
# </script>

# %%
points
# Out:
#        name country  points  rebounds  steals  assists  fouls  plus_minus  \
# 0       罗建儿      韩国    23.0      12.8     1.4      1.8    1.8       -14.2
# 1    博格达诺维奇    塞尔维亚    22.9       4.1     1.3      4.4    1.3        12.5
# 2    K-韦伯斯特     新西兰    22.8       4.6     1.0      5.6    2.0         8.0
# 3       米尔斯    澳大利亚    22.5       2.4     0.8      3.9    1.6         7.1
# 4        塔克      约旦    21.0       4.8     1.2      1.2    1.4       -20.2
# 5       奥斯曼     土耳其    20.4       3.2     1.4      2.6    2.8         4.4
# 6       富尼耶      法国    19.8       3.8     0.9      3.0    2.5         8.1
# 7       施罗德      德国    19.6       4.6     1.4      9.4    1.4         9.8
# 8     马穆托格鲁     土耳其    18.6       1.6     0.8      1.0    0.8         4.8
# 9        弗图     新西兰    18.4       6.0     0.2      1.6    2.4         9.8
# 10      斯科拉     阿根廷    17.9       8.1     0.8      1.8    3.0        12.9
# 11      易建联      中国    17.8       7.8     1.0      1.2    2.4         0.4
# 12     加里纳利     意大利    17.2       5.6     1.0      2.8    1.6        10.8
# 13     德-科洛      法国    16.5       1.6     0.9      3.4    2.3         5.9
# 14      卢比奥     西班牙    16.4       4.6     1.5      6.0    2.3        12.0
# 15      威尔彻     加拿大    16.4       3.0     0.6      1.0    1.2         4.0
# 16    阿尔迪瓦里      约旦    16.3       7.5     0.5      1.5    2.0       -25.2
# 17      梅杰里     突尼斯    16.2      10.2     1.0      2.4    2.8         1.0
# 18    伊利亚索瓦     土耳其    16.0       9.3     1.7      2.0    3.3         6.7
# 19      布拉切     菲律宾    15.8       8.4     2.4      3.4    3.6       -24.4
# 20     渡边雄太      日本    15.6       5.6     0.8      1.6    1.8       -22.8
# 21    萨托兰斯基      捷克    15.5       5.6     0.9      8.5    1.8         1.9
# 22     博哈西克      捷克    15.3       4.0     0.3      2.4    3.1         0.6
# 23     贝里内利     意大利    15.0       4.0     1.2      3.2    1.6        11.6
# 24      约瑟夫     加拿大    15.0       3.6     1.4      4.8    2.6         5.0
# 25  G-阿德托昆博      希腊    14.8       8.8     2.4      2.4    3.6         6.6
# 26      哈达迪      伊朗    14.6      10.8     0.6      4.4    3.0        -2.0
# 27     武切维奇      黑山    14.6       6.4     0.8      1.2    1.2        -2.4
# 28       沃克      美国    14.4       3.0     0.9      5.4    2.3        11.3
# 29      加索尔     西班牙    14.4       5.5     1.1      4.1    1.9        13.6
# 30     费泽卡斯      日本    14.4       7.4     1.0      1.2    1.6       -18.8
# 31     胡尔塔斯    波多黎各    14.2       1.8     0.2      2.0    2.0        -5.6
# 32       罗尔     突尼斯    14.2       2.2     1.0      3.8    2.4         3.8
# 33    瓦兰丘纳斯     立陶宛    14.0       8.8     1.0      1.0    2.6        12.0
# 34     瓦奇斯基      波兰    13.9       2.6     0.6      2.8    1.8        -2.4
# 35       戴克     阿根廷    13.9       3.1     1.1      0.9    1.8         5.2
# 36      巴博萨      巴西    13.6       1.6     0.6      2.2    2.0        -2.0
# 37      波尼卡      波兰    13.5       6.8     1.4      1.6    2.4        -2.5
# 38     卡拉希斯      希腊    13.4       4.2     1.6      5.4    2.6         5.4
# 39      阿布沃    科特迪瓦    13.4       3.0     1.0      1.6    1.4        -8.2
# 40   T-韦伯斯特     新西兰    13.4       3.8     0.4      4.4    3.6         4.8
# 41     斯劳特尔      波兰    13.3       2.8     0.9      4.8    1.5        -3.1
# 42      坎帕佐     阿根廷    13.3       4.3     2.0      7.8    1.9        13.2
# 43      八村垒      日本    13.3       5.7     1.7      2.3    2.7       -23.7
# 44      汤普森    科特迪瓦    13.2       6.4     1.0      1.6    1.6       -14.4
# 45      米切尔      美国    13.1       4.3     1.1      5.0    2.0        12.0
# 46       利兹    多米尼加    13.0       2.8     1.4      2.0    1.4        -8.0
# 47    莱卡维丘斯     立陶宛    13.0       1.6     1.0      1.8    1.8         8.4
# 48       吉扬    委内瑞拉    13.0       2.0     1.0      6.2    1.4         2.2
# 49    本-鲁姆赞     突尼斯    13.0       7.2     1.8      3.6    3.2         6.0
#
#     blocked  goals_percentage  turnovers
# 0       1.2              49.5        2.4
# 1       0.3              55.6        1.4
# 2       0.0              54.2        1.6
# 3       0.3              49.6        3.5
# 4       0.2              42.1        3.0
# 5       0.4              50.0        1.4
# 6       0.1              42.0        1.9
# 7       0.2              41.4        3.4
# 8       0.0              57.8        0.8
# 9       0.0              66.7        1.6
# 10      0.4              43.4        1.9
# 11      0.6              51.7        2.6
# 12      0.4              53.1        1.0
# 13      0.0              54.5        2.3
# 14      0.0              43.6        3.5
# 15      0.0              48.3        1.0
# 16      0.0              60.5        2.0
# 17      3.2              54.4        2.2
# 18      1.0              36.4        1.7
# 19      0.6              40.0        4.4
# 20      0.4              44.6        1.2
# 21      0.4              45.7        2.8
# 22      0.1              44.6        1.5
# 23      0.0              40.0        1.6
# 24      0.0              46.0        1.8
# 25      0.6              52.2        2.6
# 26      1.2              47.5        4.4
# 27      0.6              47.6        1.6
# 28      0.3              48.6        1.7
# 29      1.1              42.5        1.8
# 30      0.2              48.3        1.8
# 31      0.2              47.4        1.6
# 32      0.0              46.0        1.4
# 33      1.6              64.3        1.0
# 34      0.1              42.5        1.8
# 35      0.1              56.0        0.9
# 36      0.2              43.6        1.6
# 37      0.9              50.0        2.4
# 38      0.0              49.1        2.6
# 39      0.0              44.6        1.6
# 40      0.0              43.6        4.0
# 41      0.1              39.8        2.0
# 42      0.1              41.8        2.6
# 43      0.0              43.3        1.3
# 44      0.6              47.2        2.2
# 45      0.4              46.6        1.0
# 46      0.2              37.7        3.4
# 47      0.0              64.9        1.2
# 48      0.0              42.6        1.6
# 49      0.4              51.0        1.6

# %%
data_list = [
bgdnwq_goals_percentage,
fny_goals_percentage,
lba_goals_percentage,
skl_goals_percentage, 
jse_goals_percentage ] 
bar = Bar()
bar.add_xaxis(the_best_lineup)
bar.add_yaxis("", data_list, category_gap="60%")
bar.set_global_opts(title_opts=opts.TitleOpts(title='最佳阵容投篮命中率'),
                   xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-20)),
                   )
bar.set_series_opts(itemstyle_opts={
            "normal": {
                "color": JsCode("""new echarts.graphic.LinearGradient(0, 0, 0, 1, [{
                    offset: 0,
                    color: 'rgba(0, 244, 255, 1)'
                }, {
                    offset: 1,
                    color: 'rgba(0, 77, 167, 1)'
                }], false)"""),
                "barBorderRadius": [30, 30, 30, 30],
                "shadowColor": 'rgb(0, 160, 221)',
            }})
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="b4826ac99e8544b6be4d7d72838ec8e9" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_b4826ac99e8544b6be4d7d72838ec8e9 = echarts.init(
#             document.getElementById('b4826ac99e8544b6be4d7d72838ec8e9'), 'white', {renderer: 'canvas'});
#         var option_b4826ac99e8544b6be4d7d72838ec8e9 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 55.6,
#                 42.0,
#                 43.6,
#                 43.4,
#                 42.5
#             ],
#             "barCategoryGap": "60%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {
#                     "color": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{                    offset: 0,                    color: 'rgba(0, 244, 255, 1)'                }, {                    offset: 1,                    color: 'rgba(0, 77, 167, 1)'                }], false),
#                     "barBorderRadius": [
#                         30,
#                         30,
#                         30,
#                         30
#                     ],
#                     "shadowColor": "rgb(0, 160, 221)"
#                 }
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -20,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u535a\u683c\u8fbe\u8bfa\u7ef4\u5947",
#                 "\u5bcc\u5c3c\u8036",
#                 "\u5362\u6bd4\u5965",
#                 "\u65af\u79d1\u62c9",
#                 "\u52a0\u7d22\u5c14"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6700\u4f73\u9635\u5bb9\u6295\u7bee\u547d\u4e2d\u7387"
#         }
#     ]
# };
#         chart_b4826ac99e8544b6be4d7d72838ec8e9.setOption(option_b4826ac99e8544b6be4d7d72838ec8e9);
#     });
# </script>

# %%
data_list = [bgdnwq_plus_minus,
fny_plus_minus, 
lba_plus_minus, 
skl_plus_minus, 
jse_plus_minus]
bar = Bar()
bar.add_xaxis(the_best_lineup)
bar.add_yaxis("", data_list, category_gap="60%")
bar.set_global_opts(title_opts=opts.TitleOpts(title='最佳阵容投篮正负值'),
                   xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-20)),
                   )
bar.set_series_opts(itemstyle_opts={
            "normal": {
                "color": JsCode("""new echarts.graphic.LinearGradient(0, 0, 0, 1, [{
                    offset: 0,
                    color: 'rgba(0, 244, 255, 1)'
                }, {
                    offset: 1,
                    color: 'rgba(0, 77, 167, 1)'
                }], false)"""),
                "barBorderRadius": [30, 30, 30, 30],
                "shadowColor": 'rgb(0, 160, 221)',
            }})
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="471bf962e574482db7a3f87a253561a6" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_471bf962e574482db7a3f87a253561a6 = echarts.init(
#             document.getElementById('471bf962e574482db7a3f87a253561a6'), 'white', {renderer: 'canvas'});
#         var option_471bf962e574482db7a3f87a253561a6 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 12.5,
#                 8.1,
#                 12.0,
#                 12.9,
#                 13.6
#             ],
#             "barCategoryGap": "60%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {
#                     "color": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{                    offset: 0,                    color: 'rgba(0, 244, 255, 1)'                }, {                    offset: 1,                    color: 'rgba(0, 77, 167, 1)'                }], false),
#                     "barBorderRadius": [
#                         30,
#                         30,
#                         30,
#                         30
#                     ],
#                     "shadowColor": "rgb(0, 160, 221)"
#                 }
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -20,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u535a\u683c\u8fbe\u8bfa\u7ef4\u5947",
#                 "\u5bcc\u5c3c\u8036",
#                 "\u5362\u6bd4\u5965",
#                 "\u65af\u79d1\u62c9",
#                 "\u52a0\u7d22\u5c14"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6700\u4f73\u9635\u5bb9\u6295\u7bee\u6b63\u8d1f\u503c"
#         }
#     ]
# };
#         chart_471bf962e574482db7a3f87a253561a6.setOption(option_471bf962e574482db7a3f87a253561a6);
#     });
# </script>

# %%
alian = points[points['name'] == '易建联']
alian
# Out:
#    name country  points  rebounds  steals  assists  fouls  plus_minus  \
# 11  易建联      中国    17.8       7.8     1.0      1.2    2.4         0.4
#
#     blocked  goals_percentage  turnovers
# 11      0.6              51.7        2.6

# %%
alian_list = [[alian['points'].values.tolist()[0], 
           alian['rebounds'].values.tolist()[0], 
           alian['assists'].values.tolist()[0], 
           alian['steals'].values.tolist()[0], 
           alian['blocked'].values.tolist()[0], 
           alian['fouls'].values.tolist()[0], 
           alian['turnovers'].values.tolist()[0],
           alian['plus_minus'].values.tolist()[0],
           alian['goals_percentage'].values.tolist()[0]]]
radar = Radar()
radar.add_schema(
    schema=[
        opts.RadarIndicatorItem(name='得分', max_=30),
        opts.RadarIndicatorItem(name="篮板", max_=15),
        opts.RadarIndicatorItem(name="助攻", max_=10),
        opts.RadarIndicatorItem(name="抢断", max_=5),
        opts.RadarIndicatorItem(name="封盖", max_=5),
        opts.RadarIndicatorItem(name="犯规", max_=5),
        opts.RadarIndicatorItem(name="失误", max_=5),
        opts.RadarIndicatorItem(name="正负值", max_=10),
        opts.RadarIndicatorItem(name="命中率", max_=80)
    ]
)
radar.add("易建联", alian_list)

# radar.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
radar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="eb9c0c4228be431f80bec6c9021980c8" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_eb9c0c4228be431f80bec6c9021980c8 = echarts.init(
#             document.getElementById('eb9c0c4228be431f80bec6c9021980c8'), 'white', {renderer: 'canvas'});
#         var option_eb9c0c4228be431f80bec6c9021980c8 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "radar",
#             "name": "\u6613\u5efa\u8054",
#             "data": [
#                 [
#                     17.8,
#                     7.8,
#                     1.2,
#                     1.0,
#                     0.6,
#                     2.4,
#                     2.6,
#                     0.4,
#                     51.7
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6613\u5efa\u8054"
#             ],
#             "selected": {
#                 "\u6613\u5efa\u8054": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "radar": {
#         "indicator": [
#             {
#                 "name": "\u5f97\u5206",
#                 "max": 30
#             },
#             {
#                 "name": "\u7bee\u677f",
#                 "max": 15
#             },
#             {
#                 "name": "\u52a9\u653b",
#                 "max": 10
#             },
#             {
#                 "name": "\u62a2\u65ad",
#                 "max": 5
#             },
#             {
#                 "name": "\u5c01\u76d6",
#                 "max": 5
#             },
#             {
#                 "name": "\u72af\u89c4",
#                 "max": 5
#             },
#             {
#                 "name": "\u5931\u8bef",
#                 "max": 5
#             },
#             {
#                 "name": "\u6b63\u8d1f\u503c",
#                 "max": 10
#             },
#             {
#                 "name": "\u547d\u4e2d\u7387",
#                 "max": 80
#             }
#         ],
#         "name": {
#             "textStyle": {}
#         },
#         "splitLine": {
#             "show": true,
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             }
#         },
#         "splitArea": {
#             "show": true,
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         "axisLine": {
#             "show": true,
#             "onZero": true,
#             "onZeroAxisIndex": 0
#         }
#     }
# };
#         chart_eb9c0c4228be431f80bec6c9021980c8.setOption(option_eb9c0c4228be431f80bec6c9021980c8);
#     });
# </script>
