# %%
import pandas as pd
from wordcloud import WordCloud
import jieba
from PIL import Image
import numpy as np

from pyecharts.charts import Bar,Map,Line,Page,Scatter, Pie
from pyecharts import options as opts
from pyecharts.globals import SymbolType,ThemeType
from pyecharts.charts import Grid

font = r'C:\Windows\Fonts\FZSTK.TTF'

# %%
def get_data(num):
    data = pd.read_csv('maoyan_data_rings%s.csv' % str(num), encoding='utf-8')
    return data

# %%
def gender_pie(data, num):
    gender_list = []
    for i, j in enumerate(data['gender'].value_counts()):
        if i == 0:
            i = '未知'
        elif i == 1:
            i = '男'
        else:
            i = '女'
        gender_list.append([i, j])
    pie = Pie()
    pie.add("", gender_list)
    pie.set_global_opts(title_opts=opts.TitleOpts(title="性别分布"))
    pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    pie.render("性别分布%s.html" % str(num))

# %%
def level_pie(data, num):
    level_list = [[i, j] for i, j in enumerate(data['userlevel'].value_counts())]
    pie = Pie()
    pie.add("", level_list, radius=["40%", "75%"])
    pie.set_global_opts(
        title_opts=opts.TitleOpts(title="等级分布"),
        legend_opts=opts.LegendOpts(
            orient="vertical", pos_top="15%", pos_left="2%"
        ))
    pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    pie.render("等级分布%s.html" % str(num))


def score_pie(data, num):
    index = data['score'].value_counts().index.tolist()
    values = data['score'].value_counts().values.tolist()
    score_list = list(zip(index, values))

    pie = Pie()
    pie.add("", score_list, radius=["30%", "75%"], center=["50%", "50%"], rosetype="radius")
    pie.set_global_opts(
        title_opts=opts.TitleOpts(title="评分分布"),
        legend_opts=opts.LegendOpts(
            orient="vertical", pos_left="10%"
        ))
    pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}:{c}:{d}%"))
    pie.render("评分分布%s.html" % str(num))

# %%
def comment_wordcloud(data, num):
    df_list = data['content'].tolist()
    cut_word = "".join(jieba.cut(str(df_list), cut_all=False))
    img = Image.open('ciyun.jpg')
    img_array = np.array(img)
    wc = WordCloud(width=1800, height=1500, background_color='white', font_path=font, mask=img_array)
    wc.generate(cut_word)
    wc.to_file('word%s.png' % str(num))

# %%
r1 = pd.read_csv("maoyan_data_rings1.csv")

# %%
r1
# Out:
#                                                 content  gender  userlevel  \
# 0                                               无需赘言，经典       1          3
# 1                                          永远的经典，梦开始的地方       0          2
# 2                                  十多年前的特效在现在也是天花板级别的牛掰       2          2
# 3                               经典就是用来重温的！期待好久了！每个主角都喜欢       2          3
# 4                                                梦开始的地方       0          2
# ...                                                 ...     ...        ...
# 1015                                             太棒了！二刷       2          2
# 1016                               感觉太棒了，太震撼了！大片必须iMax！       1          3
# 1017                                    那些说看不懂的，回家测一测智商       1          1
# 1018                                    说不好看的估计是没带脑子出门的       0          2
# 1019  经典著作，终于等来了上映，大家有共同的使命去完成，互相的信任感，阿道夫的牺牲，真的太爱了，牺...       0          2
#
#       score  ticket
# 0        10       1
# 1        10       1
# 2        10       1
# 3        10       1
# 4        10       1
# ...     ...     ...
# 1015     10       1
# 1016     10       1
# 1017     10       0
# 1018     10       1
# 1019     10       1
#
# [1020 rows x 5 columns]

# %%
data1 = get_data(1)

# %%
gender_list = []
for i, j in enumerate(data1['gender'].value_counts()):
    if i == 0:
        i = '未知'
    elif i == 1:
        i = '男'
    else:
        i = '女'
    gender_list.append([i, j])
pie = Pie()
pie.add("", gender_list)
pie.set_global_opts(title_opts=opts.TitleOpts(title="性别分布"))
pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ed814847644042d0886a4571e131b8e1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ed814847644042d0886a4571e131b8e1 = echarts.init(
#                     document.getElementById('ed814847644042d0886a4571e131b8e1'), 'white', {renderer: 'canvas'});
#                 var option_ed814847644042d0886a4571e131b8e1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u672a\u77e5",
#                     "value": 597
#                 },
#                 {
#                     "name": "\u7537",
#                     "value": 259
#                 },
#                 {
#                     "name": "\u5973",
#                     "value": 164
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u672a\u77e5",
#                 "\u7537",
#                 "\u5973"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u6027\u522b\u5206\u5e03",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_ed814847644042d0886a4571e131b8e1.setOption(option_ed814847644042d0886a4571e131b8e1);
#         });
#     </script>

# %%
level_list = [[i, j] for i, j in enumerate(data1['userlevel'].value_counts())]
pie = Pie()
pie.add("", level_list, radius=["40%", "75%"])
pie.set_global_opts(
    title_opts=opts.TitleOpts(title="等级分布"),
    legend_opts=opts.LegendOpts(
        orient="vertical", pos_top="15%", pos_left="2%"
    ))
pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3df3c1951c58428da60ac13a74d31619" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3df3c1951c58428da60ac13a74d31619 = echarts.init(
#                     document.getElementById('3df3c1951c58428da60ac13a74d31619'), 'white', {renderer: 'canvas'});
#                 var option_3df3c1951c58428da60ac13a74d31619 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": 0,
#                     "value": 553
#                 },
#                 {
#                     "name": 1,
#                     "value": 357
#                 },
#                 {
#                     "name": 2,
#                     "value": 66
#                 },
#                 {
#                     "name": 3,
#                     "value": 38
#                 },
#                 {
#                     "name": 4,
#                     "value": 5
#                 },
#                 {
#                     "name": 5,
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 0,
#                 1,
#                 2,
#                 3,
#                 4,
#                 5
#             ],
#             "selected": {},
#             "show": true,
#             "left": "2%",
#             "top": "15%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u7b49\u7ea7\u5206\u5e03",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_3df3c1951c58428da60ac13a74d31619.setOption(option_3df3c1951c58428da60ac13a74d31619);
#         });
#     </script>

# %%
index = data1['score'].value_counts().index.tolist()
values = data1['score'].value_counts().values.tolist()
score_list = list(zip(index, values))

pie = Pie()
pie.add("", score_list, radius=["30%", "75%"], center=["50%", "50%"], rosetype="radius")
pie.set_global_opts(
    title_opts=opts.TitleOpts(title="评分分布"),
    legend_opts=opts.LegendOpts(
        orient="vertical", pos_left="10%"
    ))
pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}:{c}:{d}%"))
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="68f49fb7a99f447395964d67eac23abe" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_68f49fb7a99f447395964d67eac23abe = echarts.init(
#                     document.getElementById('68f49fb7a99f447395964d67eac23abe'), 'white', {renderer: 'canvas'});
#                 var option_68f49fb7a99f447395964d67eac23abe = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": 10,
#                     "value": 632
#                 },
#                 {
#                     "name": 9,
#                     "value": 186
#                 },
#                 {
#                     "name": 8,
#                     "value": 74
#                 },
#                 {
#                     "name": 7,
#                     "value": 48
#                 },
#                 {
#                     "name": 1,
#                     "value": 22
#                 },
#                 {
#                     "name": 6,
#                     "value": 16
#                 },
#                 {
#                     "name": 5,
#                     "value": 16
#                 },
#                 {
#                     "name": 3,
#                     "value": 9
#                 },
#                 {
#                     "name": 2,
#                     "value": 7
#                 },
#                 {
#                     "name": 0,
#                     "value": 7
#                 },
#                 {
#                     "name": 4,
#                     "value": 3
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}:{c}:{d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 10,
#                 9,
#                 8,
#                 7,
#                 1,
#                 6,
#                 5,
#                 3,
#                 2,
#                 0,
#                 4
#             ],
#             "selected": {},
#             "show": true,
#             "left": "10%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u8bc4\u5206\u5206\u5e03",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_68f49fb7a99f447395964d67eac23abe.setOption(option_68f49fb7a99f447395964d67eac23abe);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import WordCloud
from pyecharts.globals import SymbolType
def wordcloud_base(words) -> WordCloud:

    c = (
        WordCloud(init_opts=opts.InitOpts(theme=ThemeType.VINTAGE))
        .add("", words, word_size_range=[20, 100], shape="star")
        .set_global_opts(title_opts=opts.TitleOpts(title=""))
    )
    return c

# %%
# from wordcloud import WordCloud,STOPWORDS
# import matplotlib.pyplot as plt
# from imageio import imread
# plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
# plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

count_list = []
for i in data1['content'].tolist():
    result = jieba.lcut(i)
    for x in result:
        count_list.append(x)

ring_counts = {}
stopword = [' ', '的', '，', '了', '。', '我', '都', '是', '！', '不', '给', '人', '也', '就', '你', '还', '？', '说',
           '就是', '在', '让', '有', '买', '一个', '到', '多', '又', '这', '要', '这个', '吧', '个', '没', '用', '']
for w in count_list:
    if w not in stopword:
        ring_counts[w] = ring_counts.get(w, 0) + 1

sort_counts = sorted(ring_counts.items(), key=lambda item: item[1], reverse=True)
wordcloud_base(zip([x[0] for x in sort_counts[:100]], [x[1] for x in sort_counts[:100]])).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="f9215c2380f1489f837882b1960905eb" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud', 'vintage'], function(echarts) {
#                 var chart_f9215c2380f1489f837882b1960905eb = echarts.init(
#                     document.getElementById('f9215c2380f1489f837882b1960905eb'), 'vintage', {renderer: 'canvas'});
#                 var option_f9215c2380f1489f837882b1960905eb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "star",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u770b",
#                     "value": 230,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(127,65,34)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7ecf\u5178",
#                     "value": 212,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(93,47,45)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u597d\u770b",
#                     "value": 212,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(150,8,61)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7535\u5f71",
#                     "value": 146,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(109,104,30)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f88",
#                     "value": 125,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(90,136,106)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0d\u9519",
#                     "value": 94,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(127,45,102)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u975e\u5e38",
#                     "value": 81,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(18,79,149)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8fd8\u662f",
#                     "value": 75,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(132,30,94)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u597d",
#                     "value": 75,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(19,144,107)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6307\u73af\u738b",
#                     "value": 71,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(110,20,8)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u548c",
#                     "value": 58,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(14,111,39)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53ef\u4ee5",
#                     "value": 52,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(160,110,95)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u592a",
#                     "value": 49,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,43,46)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53f2\u8bd7",
#                     "value": 47,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(59,18,26)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u771f\u7684",
#                     "value": 43,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(29,102,27)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9707\u64bc",
#                     "value": 43,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(8,20,19)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6c38\u8fdc",
#                     "value": 42,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(71,142,71)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5267\u60c5",
#                     "value": 42,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(78,52,81)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u611f\u89c9",
#                     "value": 42,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(1,3,4)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u3001",
#                     "value": 41,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(89,18,49)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a",
#                     "value": 41,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(152,65,23)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6ca1\u6709",
#                     "value": 39,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(25,39,142)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u554a",
#                     "value": 37,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(28,137,96)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u91cd\u6e29",
#                     "value": 36,
#                     "textSt

# %%
data2 = get_data(2)

# %%
count_list = []
for i in data2['content'].tolist():
    result = jieba.lcut(i)
    for x in result:
        count_list.append(x)

ring_counts = {}
stopword = [' ', '的', '，', '了', '。', '我', '都', '是', '！', '不', '给', '人', '也', '就', '你', '还', '？', '说',
           '就是', '在', '让', '有', '买', '一个', '到', '多', '又', '这', '要', '这个', '吧', '个', '没', '用', '']
for w in count_list:
    if w not in stopword:
        ring_counts[w] = ring_counts.get(w, 0) + 1

sort_counts = sorted(ring_counts.items(), key=lambda item: item[1], reverse=True)
wordcloud_base(zip([x[0] for x in sort_counts[:100]], [x[1] for x in sort_counts[:100]])).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="d2ec260bdcdd420db582531b3777a975" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud', 'vintage'], function(echarts) {
#                 var chart_d2ec260bdcdd420db582531b3777a975 = echarts.init(
#                     document.getElementById('d2ec260bdcdd420db582531b3777a975'), 'vintage', {renderer: 'canvas'});
#                 var option_d2ec260bdcdd420db582531b3777a975 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "star",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u770b",
#                     "value": 228,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(34,149,53)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7ecf\u5178",
#                     "value": 186,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(15,30,64)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u597d\u770b",
#                     "value": 177,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(31,26,97)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7535\u5f71",
#                     "value": 146,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(52,38,15)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f88",
#                     "value": 115,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(126,105,153)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6307\u73af\u738b",
#                     "value": 88,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(127,28,124)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u597d",
#                     "value": 87,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(30,69,91)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u548c",
#                     "value": 81,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(112,98,121)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0d\u9519",
#                     "value": 72,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(154,25,67)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8fd8\u662f",
#                     "value": 62,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(160,41,23)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u975e\u5e38",
#                     "value": 59,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(121,150,82)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u559c\u6b22",
#                     "value": 53,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(145,27,132)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6c38\u8fdc",
#                     "value": 53,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(77,4,52)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9707\u64bc",
#                     "value": 48,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(58,117,40)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5267\u60c5",
#                     "value": 47,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(54,49,18)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6ca1\u6709",
#                     "value": 46,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(102,92,49)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53ef\u4ee5",
#                     "value": 45,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(134,15,20)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7b2c\u4e09\u90e8",
#                     "value": 43,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(114,44,12)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53f2\u8bd7",
#                     "value": 42,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(57,18,99)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u771f\u7684",
#                     "value": 41,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(9,126,88)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u592a",
#                     "value": 40,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(51,61,35)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u80fd",
#                     "value": 40,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(99,19,52)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u611f\u89c9",
#                     "value": 38,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(87,44,17)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53bb",
#                     "value": 38,

# %%
data3 = get_data(3)
count_list = []
for i in data3['content'].tolist():
    result = jieba.lcut(i)
    for x in result:
        count_list.append(x)

ring_counts = {}
stopword = [' ', '的', '，', '了', '。', '我', '都', '是', '！', '不', '给', '人', '也', '就', '你', '还', '？', '说',
           '就是', '在', '让', '有', '买', '一个', '到', '多', '又', '这', '要', '这个', '吧', '个', '没', '用', '']
for w in count_list:
    if w not in stopword:
        ring_counts[w] = ring_counts.get(w, 0) + 1

sort_counts = sorted(ring_counts.items(), key=lambda item: item[1], reverse=True)
wordcloud_base(zip([x[0] for x in sort_counts[:100]], [x[1] for x in sort_counts[:100]])).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="6a5a9a7e751845e882b796c1b514bac9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud', 'vintage'], function(echarts) {
#                 var chart_6a5a9a7e751845e882b796c1b514bac9 = echarts.init(
#                     document.getElementById('6a5a9a7e751845e882b796c1b514bac9'), 'vintage', {renderer: 'canvas'});
#                 var option_6a5a9a7e751845e882b796c1b514bac9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "star",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u770b",
#                     "value": 275,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(139,37,85)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7535\u5f71",
#                     "value": 195,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(134,94,13)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7ecf\u5178",
#                     "value": 176,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(51,19,56)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6307\u73af\u738b",
#                     "value": 148,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(116,43,59)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u548c",
#                     "value": 126,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(32,59,51)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f88",
#                     "value": 115,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(155,154,140)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u597d\u770b",
#                     "value": 112,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(101,131,74)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53f2\u8bd7",
#                     "value": 95,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(93,82,137)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9707\u64bc",
#                     "value": 91,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(152,131,121)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8fd8\u662f",
#                     "value": 86,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(3,89,94)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u571f",
#                     "value": 85,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(59,60,38)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6ca1\u6709",
#                     "value": 84,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(13,107,80)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6c38\u8fdc",
#                     "value": 84,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(83,136,122)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u3001",
#                     "value": 81,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(124,63,145)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u597d",
#                     "value": 80,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(128,18,11)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e09\u90e8\u66f2",
#                     "value": 79,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(2,112,155)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u771f\u7684",
#                     "value": 74,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(90,109,24)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u592a",
#                     "value": 74,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(92,135,136)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u738b\u8005",
#                     "value": 73,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(13,144,93)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u80fd",
#                     "value": 71,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(95,104,55)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6700\u540e",
#                     "value": 68,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(9,60,96)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e16\u754c",
#                     "value": 67,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(115,139,123)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9b54\u6212",
#                     "value": 67,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(145,70,80)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f46",
#                     "value": 65,
